# %% [markdown]
# ## Python for Finance 6 - Best Stocks to Buy Now

# %%
# Provides ways to work with large multidimensional arrays
import numpy as np 
# Allows for further data manipulation and analysis
import pandas as pd
from pandas_datareader import data as web # Reads stock data 
import matplotlib.pyplot as plt # Plotting
import matplotlib.dates as mdates # Styling dates
# %matplotlib inline

import datetime as dt # For defining dates
import mplfinance as mpf # Matplotlib finance

import time

# Used to get data from a directory
import os
from os import listdir
from os.path import isfile, join

#Statsmodels is a great library we can use to run regressions.
import statsmodels.api as sm
# Seaborn extends the capabilities of Matplotlib
import seaborn as sns
# Used for calculating regressions
from statsmodels.tsa.ar_model import AutoReg, ar_select_order

# %% [markdown]
# #### Dates & Other Constants

# %%
# Define path to files
PATH = "../data/stock-list/"

# Start date defaults
ST_YEAR = 2017
ST_MONTH = 1
ST_DAY = 1
ST_DATE_STR = f"{ST_YEAR}-{ST_MONTH}-{ST_DAY}"
ST_DATE_DATETIME = dt.datetime(ST_YEAR, ST_MONTH, ST_DAY)

# End date defaults
EN_YEAR = 2021
EN_MONTH = 12
EN_DAY = 31
EN_DATE_STR = f"{EN_YEAR}-{EN_MONTH}-{EN_DAY}"
EN_DATE_DATETIME = dt.datetime(EN_YEAR, EN_MONTH, EN_DAY)

# %% [markdown]
# #### Hold Stocks not Downloaded

# %%
stocks_not_downloaded = []
missing_stocks = []

# %% [markdown]
# #### Get Stock File Names in a List

# %%
files = [x for x in listdir(PATH) if isfile(join(PATH, x))]
tickers = [os.path.splitext(x)[0] for x in files]
tickers

tickers.sort()
len(tickers)
# Out:
# 2862

# %% [markdown]
# #### Save Stock Data to CSV

# %%
# Function that gets a dataframe by providing a ticker and starting date
def save_to_csv_from_yahoo(ticker, syear, smonth, sday, eyear, emonth, eday):
    # Defines the time periods to use
    start = dt.datetime(syear, smonth, sday)
    end = dt.datetime(eyear, emonth, eday)
    
    try:
        print("Get Data for : ", ticker)
        # Reads data into a dataframe
        df = web.DataReader(ticker, 'yahoo', start, end)['Adj Close']
    
        # Wait 10 seconds
        time.sleep(5)
    
        # Save data to a CSV file Windows
        df.to_csv('../data/update/' + ticker + '.csv')
        
    except Exception as ex:
        stocks_not_downloaded.append(ticker)
        print("Couldn't Get Data for :", ticker)

# %%
for x in range(0, 500):
    save_to_csv_from_yahoo(tickers[x], 2022, 1, 1, 2022, 1, 20)
print("Finished")
stocks_not_downloaded
# Out:
# Get Data for :  A
# Get Data for :  AA
# Get Data for :  AAL
# Get Data for :  AAME
# Get Data for :  AAN
# Get Data for :  AAOI
# Get Data for :  AAON
# Get Data for :  AAP
# Get Data for :  AAPL
# Get Data for :  AAT
# Get Data for :  AAWW
# Get Data for :  ABBV
# Get Data for :  ABC
# Get Data for :  ABCB
# Get Data for :  ABEO
# Get Data for :  ABG
# Get Data for :  ABIO
# Get Data for :  ABM
# Get Data for :  ABMD
# Get Data for :  ABR
# Get Data for :  ABT
# Get Data for :  ABTX
# Get Data for :  AC
# Get Data for :  ACA
# Get Data for :  ACAD
# Get Data for :  ACBI
# Get Data for :  ACC
# Get Data for :  ACCO
# Get Data for :  ACER
# Get Data for :  ACGL
# Get Data for :  ACHC
# Get Data for :  ACHV
# Get Data for :  ACIW
# Get Data for :  ACLS
# Get Data for :  ACM
# Get Data for :  ACMR
# Get Data for :  ACN
# Get Data for :  ACNB
# Get Data for :  ACOR
# Get Data for :  ACRE
# Get Data for :  ACRS
# Get Data for :  ACRX
# Get Data for :  ACTG
# Get Data for :  ACU
# Get Data for :  ADBE
# Get Data for :  ADC
# Get Data for :  ADES
# Get Data for :  ADI
# Get Data for :  ADM
# Get Data for :  ADMA
# Get Data for :  ADMP
# Get Data for :  ADNT
# Get Data for :  ADP
# Get Data for :  ADSK
# Get Data for :  ADT
# Get Data for :  ADTN
# Get Data for :  ADUS
# Get Data for :  ADVM
# Get Data for :  ADXS
# Get Data for :  AE
# Get Data for :  AEE
# Get Data for :  AEHR
# Get Data for :  AEIS
# Get Data for :  AEL
# Get Data for :  AEMD
# Get Data for :  AEO
# Get Data for :  AEP
# Get Data for :  AERI
# Get Data for :  AES
# Get Data for :  AEY
# Get Data for :  AFG
# Get Data for :  AFI
# Get Data for :  AFL
# Get Data for :  AGCO
# Get Data for :  AGE
# Get Data for :  AGEN
# Get Data for :  AGFS
# Get Data for :  AGIO
# Get Data for :  AGLE
# Get Data for :  AGM
# Get Data for :  AGNC
# Get Data for :  AGO
# Get Data for :  AGR
# Get Data for :  AGRX
# Get Data for :  AGS
# Get Data for :  AGTC
# Get Data for :  AGX
# Get Data for :  AGYS
# Get Data for :  AHH
# Get Data for :  AHT
# Get Data for :  AIG
# Get Data for :  AIMC
# Get Data for :  AIN
# Get Data for :  AINC
# Get Data for :  AIR
# Get Data for :  AIRG
# Get Data for :  AIRI
# Get Data for :  AIRT
# Get Data for :  AIT
# Get Data for :  AIV
# Get Data for :  AIZ
# Get Data for :  AJG
# Get Data for :  AJRD
# Get Data for :  AJX
# Get Data for :  AKAM
# Get Data for :  AKBA
# Get Data for :  AKR
# Get Data for :  AKTS
# Get Data for :  AL
# Get Data for :  ALB
# Get Data for :  ALBO
# Get Data for :  ALCO
# Get Data for :  ALDX
# Get Data for :  ALE
# Get Data for :  ALEC
# Get Data for :  ALEX
# Get Data for :  ALG
# Get Data for :  ALGN
# Get Data for :  ALGT
# Get Data for :  ALIM
# Get Data for :  ALJJ
# Get Data for :  ALK
# Get Data for :  ALKS
# Get Data for :  ALL
# Get Data for :  ALLE
# Get Data for :  ALLK
# Get Data for :  ALLO
# Get Data for :  ALLY
# Get Data for :  ALNA
# Get Data for :  ALNY
# Get Data for :  ALOT
# Get Data for :  ALPN
# Get Data for :  ALRM
# Get Data for :  ALSN
# Get Data for :  ALT
# Get Data for :  ALTR
# Get Data for :  ALV
# Get Data for :  ALX
# Get Data for :  AM
# Get Data for :  AMAL
# Get Data for :  AMAT
# Get Data for :  AMBC
# Get Data for :  AMC
# Get Data for :  AMCX
# Get Data for :  AMD
# Get Data for :  AME
# Get Data for :  AMED
# Get Data for :  AMG
# Get Data for :  AMGN
# Get Data for :  AMH
# Get Data for :  AMKR
# Get Data for :  AMN
# Get Data for :  AMNB
# Get Data for :  AMOT
# Get Data for :  AMP
# Get Data for :  AMPE
# Get Data for :  AMPH
# Get Data for :  AMRC
# Get Data for :  AMRK
# Get Data for :  AMRS
# Get Data for :  AMRX
# Get Data for :  AMS
# Get Data for :  AMSC
# Get Data for :  AMSF
# Get Data for :  AMSWA
# Get Data for :  AMT
# Get Data for :  AMTD
# Get Data for :  AMTX
# Get Data for :  AMWD
# Get Data for :  AMZN
# Get Data for :  AN
# Get Data for :  ANAB
# Get Data for :  ANAT
# Get Data for :  ANDE
# Get Data for :  ANET
# Get Data for :  ANF
# Get Data for :  ANGI
# Get Data for :  ANGO
# Get Data for :  ANIK
# Get Data for :  ANIP
# Get Data for :  ANIX
# Get Data for :  ANSS
# Get Data for :  ANTM
# Get Data for :  AON
# Get Data for :  AOS
# Get Data for :  AOSL
# Get Data for :  AP
# Get Data for :  APA
# Get Data for :  APAM
# Get Data for :  APD
# Get Data for :  APDN
# Get Data for :  APEI
# Get Data for :  APEN
# Get Data for :  APH
# Get Data for :  APLE
# Get Data for :  APLS
# Get Data for :  APOG
# Get Data for :  APPF
# Get Data for :  APPN
# Get Data for :  APPS
# Get Data for :  APRN
# Get Data for :  APT
# Get Data for :  APTS
# Get Data for :  APTV
# Get Data for :  APVO
# Get Data for :  APYX
# Get Data for :  AQB
# Get Data for :  AQMS
# Get Data for :  AQUA
# Get Data for :  AR
# Get Data for :  ARAV
# Get Data for :  ARAY
# Couldn't Get Data for : ARAY
# Get Data for :  ARC
# Get Data for :  ARCB
# Get Data for :  ARCH
# Get Data for :  ARDX
# Get Data for :  ARE
# Get Data for :  ARES
# Get Data for :  ARGO
# Get Data for :  ARI
# Get Data for :  ARKR
# Get Data for :  ARL
# Get Data for :  ARLO
# Get Data for :  ARMK
# Get Data for :  ARNA
# Get Data for :  ARNC
# Get Data for :  AROC
# Get Data for :  AROW
# Get Data for :  ARR
# Get Data for :  ARTNA
# Get Data for :  ARTW
# Get Data for :  ARVN
# Get Data for :  ARW
# Get Data for :  ARWR
# Get Data for :  ASB
# Get Data for :  ASGN
# Get Data for :  ASH
# Get Data for :  ASIX
# Get Data for :  ASMB
# Get Data for :  ASPN
# Get Data for :  ASRV
# Get Data for :  ASTC
# Get Data for :  ASTE
# Get Data for :  ASUR
# Get Data for :  ASYS
# Get Data for :  ATEC
# Get Data for :  ATEN
# Get Data for :  ATGE
# Get Data for :  ATHX
# Get Data for :  ATI
# Get Data for :  ATKR
# Get Data for :  ATLC
# Get Data for :  ATLO
# Get Data for :  ATNI
# Get Data for :  ATNM
# Get Data for :  ATNX
# Get Data for :  ATO
# Get Data for :  ATOS
# Get Data for :  ATR
# Get Data for :  ATRA
# Get Data for :  ATRC
# Get Data for :  ATRI
# Get Data for :  ATRO
# Get Data for :  ATRS
# Get Data for :  ATSG
# Get Data for :  ATUS
# Get Data for :  ATVI
# Get Data for :  AUBN
# Get Data for :  AUMN
# Get Data for :  AUTO
# Get Data for :  AVA
# Get Data for :  AVAV
# Get Data for :  AVB
# Get Data for :  AVD
# Get Data for :  AVEO
# Get Data for :  AVGO
# Get Data for :  AVGR
# Get Data for :  AVID
# Get Data for :  AVLR
# Get Data for :  AVNS
# Get Data for :  AVNW
# Get Data for :  AVRO
# Get Data for :  AVT
# Get Data for :  AVTR
# Get Data for :  AVXL
# Get Data for :  AVY
# Get Data for :  AVYA
# Get Data for :  AWI
# Get Data for :  AWK
# Get Data for :  AWR
# Get Data for :  AWRE
# Get Data for :  AX
# Get Data for :  AXAS
# Get Data for :  AXDX
# Get Data for :  AXGN
# Get Data for :  AXL
# Get Data for :  AXNX
# Get Data for :  AXP
# Get Data for :  AXR
# Get Data for :  AXS
# Get Data for :  AXSM
# Get Data for :  AXTA
# Get Data for :  AXTI
# Get Data for :  AYI
# Get Data for :  AYX
# Get Data for :  AZO
# Get Data for :  AZPN
# Get Data for :  AZZ
# Get Data for :  B
# Get Data for :  BA
# Get Data for :  BAC
# Get Data for :  BAH
# Get Data for :  BANC
# Get Data for :  BAND
# Get Data for :  BANF
# Get Data for :  BANR
# Get Data for :  BATRA
# Get Data for :  BATRK
# Get Data for :  BAX
# Get Data for :  BBBY
# Get Data for :  BBCP
# Get Data for :  BBGI
# Get Data for :  BBSI
# Get Data for :  BBW
# Get Data for :  BBY
# Get Data for :  BC
# Get Data for :  BCBP
# Get Data for :  BCC
# Get Data for :  BCLI
# Get Data for :  BCO
# Get Data for :  BCOR
# Get Data for :  BCOV
# Get Data for :  BCPC
# Get Data for :  BCRX
# Get Data for :  BDC
# Get Data for :  BDL
# Get Data for :  BDN
# Get Data for :  BDSI
# Get Data for :  BDX
# Get Data for :  BECN
# Get Data for :  BELFA
# Get Data for :  BEN
# Get Data for :  BERY
# Get Data for :  BFAM
# Get Data for :  BFIN
# Get Data for :  BFS
# Get Data for :  BFST
# Get Data for :  BGFV
# Get Data for :  BGS
# Get Data for :  BGSF
# Get Data for :  BH
# Get Data for :  BHB
# Get Data for :  BHE
# Get Data for :  BHF
# Get Data for :  BHLB
# Get Data for :  BHR
# Get Data for :  BHVN
# Get Data for :  BIG
# Get Data for :  BIIB
# Get Data for :  BIO
# Get Data for :  BIOC
# Get Data for :  BIOL
# Get Data for :  BJ
# Get Data for :  BJRI
# Get Data for :  BK
# Get Data for :  BKD
# Get Data for :  BKE
# Get Data for :  BKH
# Get Data for :  BKI
# Get Data for :  BKNG
# Get Data for :  BKSC
# Get Data for :  BKTI
# Get Data for :  BKU
# Get Data for :  BL
# Get Data for :  BLBD
# Couldn't Get Data for : BLBD
# Get Data for :  BLCM
# Get Data for :  BLD
# Get Data for :  BLDR
# Get Data for :  BLFS
# Get Data for :  BLK
# Get Data for :  BLKB
# Get Data for :  BLL
# Get Data for :  BLMN
# Get Data for :  BLUE
# Get Data for :  BMI
# Get Data for :  BMRC
# Get Data for :  BMRN
# Get Data for :  BMY
# Get Data for :  BNED
# Get Data for :  BNFT
# Get Data for :  BOH
# Get Data for :  BOKF
# Get Data for :  BOOM
# Get Data for :  BOOT
# Get Data for :  BOTJ
# Get Data for :  BOX
# Get Data for :  BPMC
# Get Data for :  BPOP
# Get Data for :  BPRN
# Get Data for :  BPTH
# Get Data for :  BR
# Get Data for :  BRC
# Get Data for :  BRG
# Get Data for :  BRID
# Get Data for :  BRKL
# Get Data for :  BRKR
# Get Data for :  BRN
# Get Data for :  BRO
# Get Data for :  BRT
# Get Data for :  BRX
# Get Data for :  BRY
# Get Data for :  BSET
# Get Data for :  BSGM
# Get Data for :  BSQR
# Get Data for :  BSRR
# Get Data for :  BSX
# Get Data for :  BTN
# Get Data for :  BTU
# Get Data for :  BURL
# Get Data for :  BUSE
# Get Data for :  BV
# Get Data for :  BW
# Get Data for :  BWA
# Get Data for :  BWEN
# Get Data for :  BWFG
# Get Data for :  BWXT
# Get Data for :  BXC
# Get Data for :  BXMT
# Get Data for :  BXP
# Get Data for :  BY
# Get Data for :  BYD
# Get Data for :  BYFC
# Get Data for :  BYND
# Get Data for :  BZH
# Get Data for :  C
# Get Data for :  CABO
# Get Data for :  CAC
# Get Data for :  CACC
# Get Data for :  CACI
# Get Data for :  CADE
# Get Data for :  CAG
# Get Data for :  CAH
# Get Data for :  CAKE
# Get Data for :  CAL
# Get Data for :  CALA
# Get Data for :  CALM
# Get Data for :  CALX
# Get Data for :  CAMP
# Get Data for :  CAPR
# Get Data for :  CAR
# Get Data for :  CARA
# Get Data for :  CARG
# Get Data for :  CARS
# Get Data for :  CASA
# Get Data for :  CASH
# Get Data for :  CASI
# Get Data for :  CASS
# Get Data for :  CASY
# Get Data for :  CAT
# Get Data for :  CATC
# Get Data for :  CATO
# Get Data for :  CATY
# Get Data for :  CB
# Get Data for :  CBAN
# Get Data for :  CBAY
# Get Data for :  CBFV
# Get Data for :  CBIO
# Get Data for :  CBOE
# Get Data for :  CBRE
# Get Data for :  CBRL
# Get Data for :  CBSH
# Get Data for :  CBT
# Get Data for :  CBTX
# Get Data for :  CBU
# Get Data for :  CBZ
# Get Data for :  CC
# Get Data for :  CCBG
# Get Data for :  CCF
# Get Data for :  CCI
# Get Data for :  CCK
# Get Data for :  CCL
# Get Data for :  CCMP
# Get Data for :  CCNE
# Get Data for :  CCO
# Get Data for :  CCOI
# Get Data for :  CCRN
# Get Data for :  CCS
# Get Data for :  CCXI
# Get Data for :  CDAY
# Get Data for :  CDE
# Get Data for :  CDEV
# Get Data for :  CDK
# Get Data for :  CDLX
# Get Data for :  CDMO
# Get Data for :  CDNA
# Get Data for :  CDNS
# Get Data for :  CDR
# Get Data for :  CDTX
# Get Data for :  CDW
# Get Data for :  CDXC
# Finished
# ['ARAY', 'BLBD']

# %%
for x in range(500, 1000):
    save_to_csv_from_yahoo(tickers[x], 2022, 1, 1, 2022, 1, 20)
print("Finished")
stocks_not_downloaded
# Out:
# Get Data for :  CDXS
# Get Data for :  CDZI
# Get Data for :  CE
# Get Data for :  CECE
# Get Data for :  CEI
# Get Data for :  CEIX
# Get Data for :  CELC
# Get Data for :  CELH
# Get Data for :  CEMI
# Get Data for :  CENT
# Get Data for :  CENTA
# Get Data for :  CENX
# Get Data for :  CERN
# Get Data for :  CERS
# Get Data for :  CETX
# Get Data for :  CEVA
# Get Data for :  CF
# Get Data for :  CFBK
# Get Data for :  CFFI
# Get Data for :  CFFN
# Get Data for :  CFG
# Get Data for :  CFMS
# Get Data for :  CFR
# Get Data for :  CGNX
# Get Data for :  CHCI
# Get Data for :  CHCO
# Get Data for :  CHCT
# Get Data for :  CHD
# Get Data for :  CHDN
# Get Data for :  CHE
# Get Data for :  CHEF
# Get Data for :  CHGG
# Get Data for :  CHH
# Get Data for :  CHMA
# Couldn't Get Data for : CHMA
# Get Data for :  CHMG
# Get Data for :  CHMI
# Get Data for :  CHRS
# Get Data for :  CHRW
# Get Data for :  CHS
# Get Data for :  CHTR
# Get Data for :  CHUY
# Get Data for :  CI
# Get Data for :  CIA
# Get Data for :  CIDM
# Get Data for :  CIEN
# Get Data for :  CIM
# Get Data for :  CINF
# Get Data for :  CIO
# Get Data for :  CIR
# Get Data for :  CIVB
# Get Data for :  CIX
# Get Data for :  CIZN
# Get Data for :  CKX
# Get Data for :  CL
# Get Data for :  CLAR
# Get Data for :  CLB
# Get Data for :  CLBS
# Get Data for :  CLDT
# Get Data for :  CLDX
# Get Data for :  CLF
# Get Data for :  CLFD
# Get Data for :  CLH
# Get Data for :  CLIR
# Get Data for :  CLNE
# Get Data for :  CLPR
# Get Data for :  CLR
# Get Data for :  CLRB
# Get Data for :  CLRO
# Get Data for :  CLSN
# Get Data for :  CLVS
# Get Data for :  CLW
# Get Data for :  CLX
# Get Data for :  CLXT
# Get Data for :  CMA
# Get Data for :  CMC
# Get Data for :  CMCO
# Get Data for :  CMCSA
# Get Data for :  CMCT
# Get Data for :  CME
# Get Data for :  CMG
# Get Data for :  CMI
# Get Data for :  CMP
# Get Data for :  CMRX
# Get Data for :  CMS
# Get Data for :  CMT
# Get Data for :  CMTL
# Get Data for :  CNA
# Get Data for :  CNC
# Get Data for :  CNCE
# Get Data for :  CNDT
# Get Data for :  CNFR
# Get Data for :  CNK
# Get Data for :  CNMD
# Get Data for :  CNNE
# Get Data for :  CNO
# Get Data for :  CNOB
# Get Data for :  CNP
# Get Data for :  CNS
# Get Data for :  CNSL
# Get Data for :  CNTY
# Get Data for :  CNX
# Get Data for :  CNXN
# Get Data for :  CODA
# Get Data for :  COF
# Get Data for :  COHN
# Get Data for :  COHR
# Get Data for :  COHU
# Get Data for :  COKE
# Get Data for :  COLB
# Get Data for :  COLD
# Get Data for :  COLL
# Get Data for :  COLM
# Get Data for :  COMM
# Get Data for :  CONE
# Get Data for :  CONN
# Get Data for :  COO
# Get Data for :  COOP
# Get Data for :  COP
# Get Data for :  CORR
# Get Data for :  CORT
# Get Data for :  COST
# Get Data for :  COTY
# Get Data for :  COUP
# Get Data for :  COWN
# Get Data for :  CPB
# Get Data for :  CPE
# Get Data for :  CPF
# Get Data for :  CPHC
# Get Data for :  CPIX
# Get Data for :  CPK
# Get Data for :  CPRI
# Get Data for :  CPRT
# Get Data for :  CPRX
# Get Data for :  CPS
# Get Data for :  CPSH
# Get Data for :  CPSI
# Get Data for :  CPSS
# Get Data for :  CPT
# Get Data for :  CR
# Get Data for :  CRAI
# Get Data for :  CRBP
# Get Data for :  CRC
# Get Data for :  CRI
# Get Data for :  CRIS
# Get Data for :  CRK
# Get Data for :  CRL
# Get Data for :  CRM
# Get Data for :  CRMD
# Get Data for :  CRMT
# Get Data for :  CRNX
# Get Data for :  CROX
# Get Data for :  CRS
# Get Data for :  CRTX
# Get Data for :  CRUS
# Get Data for :  CRVL
# Get Data for :  CRVS
# Get Data for :  CRWS
# Get Data for :  CSCO
# Get Data for :  CSGP
# Get Data for :  CSGS
# Get Data for :  CSII
# Get Data for :  CSL
# Get Data for :  CSPI
# Get Data for :  CSTR
# Get Data for :  CSV
# Get Data for :  CSWI
# Get Data for :  CSX
# Get Data for :  CTAS
# Get Data for :  CTBI
# Get Data for :  CTG
# Get Data for :  CTHR
# Get Data for :  CTIB
# Get Data for :  CTIC
# Get Data for :  CTLT
# Get Data for :  CTMX
# Get Data for :  CTO
# Get Data for :  CTRE
# Get Data for :  CTRN
# Get Data for :  CTS
# Get Data for :  CTSH
# Get Data for :  CTSO
# Get Data for :  CTT
# Get Data for :  CTXS
# Get Data for :  CUBE
# Get Data for :  CUBI
# Get Data for :  CUE
# Get Data for :  CULP
# Get Data for :  CURO
# Get Data for :  CUTR
# Get Data for :  CUZ
# Get Data for :  CVBF
# Get Data for :  CVCO
# Get Data for :  CVCY
# Get Data for :  CVGI
# Get Data for :  CVGW
# Get Data for :  CVI
# Get Data for :  CVLT
# Get Data for :  CVLY
# Get Data for :  CVM
# Get Data for :  CVNA
# Get Data for :  CVR
# Get Data for :  CVS
# Get Data for :  CVU
# Get Data for :  CVV
# Get Data for :  CVX
# Get Data for :  CW
# Get Data for :  CWBC
# Get Data for :  CWBR
# Get Data for :  CWEN
# Get Data for :  CWH
# Get Data for :  CWST
# Get Data for :  CWT
# Get Data for :  CXW
# Get Data for :  CYAN
# Get Data for :  CYBE
# Get Data for :  CYCC
# Get Data for :  CYH
# Get Data for :  CYRX
# Get Data for :  CYTK
# Get Data for :  CYTR
# Get Data for :  CZNC
# Get Data for :  CZR
# Get Data for :  CZWI
# Get Data for :  D
# Get Data for :  DAIO
# Get Data for :  DAKT
# Get Data for :  DAL
# Get Data for :  DAN
# Get Data for :  DAR
# Get Data for :  DARE
# Get Data for :  DBD
# Get Data for :  DBI
# Get Data for :  DBX
# Get Data for :  DCI
# Get Data for :  DCO
# Get Data for :  DCOM
# Get Data for :  DCPH
# Get Data for :  DD
# Get Data for :  DDD
# Get Data for :  DDS
# Get Data for :  DE
# Get Data for :  DEA
# Get Data for :  DECK
# Get Data for :  DEI
# Get Data for :  DELL
# Get Data for :  DENN
# Get Data for :  DFIN
# Get Data for :  DFS
# Get Data for :  DG
# Get Data for :  DGICA
# Get Data for :  DGII
# Get Data for :  DGLY
# Get Data for :  DGX
# Get Data for :  DHI
# Get Data for :  DHIL
# Get Data for :  DHR
# Get Data for :  DHX
# Get Data for :  DIN
# Get Data for :  DIOD
# Get Data for :  DIS
# Get Data for :  DISCA
# Get Data for :  DISCK
# Get Data for :  DISH
# Get Data for :  DIT
# Get Data for :  DJCO
# Get Data for :  DK
# Get Data for :  DKS
# Get Data for :  DLA
# Get Data for :  DLB
# Get Data for :  DLHC
# Get Data for :  DLR
# Get Data for :  DLTH
# Get Data for :  DLTR
# Get Data for :  DLX
# Get Data for :  DMRC
# Get Data for :  DNLI
# Get Data for :  DNOW
# Get Data for :  DOC
# Get Data for :  DOCU
# Get Data for :  DOMO
# Get Data for :  DOOR
# Get Data for :  DORM
# Get Data for :  DOV
# Get Data for :  DOW
# Get Data for :  DPZ
# Get Data for :  DRE
# Get Data for :  DRH
# Get Data for :  DRI
# Get Data for :  DRQ
# Get Data for :  DRRX
# Get Data for :  DS
# Get Data for :  DSKE
# Get Data for :  DSS
# Get Data for :  DTE
# Get Data for :  DUK
# Get Data for :  DVA
# Get Data for :  DVAX
# Get Data for :  DVN
# Get Data for :  DWSN
# Get Data for :  DX
# Get Data for :  DXC
# Get Data for :  DXCM
# Get Data for :  DXLG
# Get Data for :  DXPE
# Get Data for :  DXYN
# Get Data for :  DY
# Get Data for :  DZSI
# Get Data for :  EA
# Get Data for :  EAF
# Get Data for :  EARN
# Get Data for :  EAT
# Get Data for :  EB
# Get Data for :  EBAY
# Get Data for :  EBF
# Get Data for :  EBIX
# Get Data for :  EBMT
# Get Data for :  EBS
# Get Data for :  EBTC
# Get Data for :  ECL
# Get Data for :  ECOL
# Get Data for :  ECOM
# Get Data for :  ECPG
# Get Data for :  ED
# Get Data for :  EDIT
# Get Data for :  EDUC
# Get Data for :  EEFT
# Get Data for :  EEX
# Get Data for :  EFC
# Get Data for :  EFOI
# Get Data for :  EFSC
# Get Data for :  EFX
# Get Data for :  EGAN
# Get Data for :  EGBN
# Get Data for :  EGHT
# Get Data for :  EGLE
# Couldn't Get Data for : EGLE
# Get Data for :  EGP
# Get Data for :  EGRX
# Get Data for :  EGY
# Get Data for :  EHC
# Couldn't Get Data for : EHC
# Get Data for :  EHTH
# Get Data for :  EIG
# Get Data for :  EIGR
# Get Data for :  EIX
# Get Data for :  EKSO
# Get Data for :  EL
# Get Data for :  ELAN
# Get Data for :  ELF
# Get Data for :  ELMD
# Get Data for :  ELOX
# Get Data for :  ELS
# Get Data for :  ELSE
# Get Data for :  ELVT
# Get Data for :  ELY
# Get Data for :  EMAN
# Get Data for :  EMCF
# Get Data for :  EME
# Get Data for :  EMKR
# Get Data for :  EML
# Get Data for :  EMMS
# Get Data for :  EMN
# Get Data for :  EMR
# Get Data for :  ENDP
# Get Data for :  ENG
# Get Data for :  ENOB
# Get Data for :  ENPH
# Get Data for :  ENR
# Get Data for :  ENS
# Get Data for :  ENSG
# Get Data for :  ENSV
# Get Data for :  ENTA
# Get Data for :  ENTG
# Get Data for :  ENV
# Get Data for :  ENVA
# Get Data for :  ENZ
# Get Data for :  EPAY
# Get Data for :  EPC
# Get Data for :  EPM
# Get Data for :  EPR
# Get Data for :  EPRT
# Get Data for :  EPZM
# Get Data for :  EQBK
# Get Data for :  EQC
# Get Data for :  EQH
# Get Data for :  EQIX
# Get Data for :  EQR
# Get Data for :  EQT
# Get Data for :  ERIE
# Get Data for :  ERII
# Get Data for :  ES
# Get Data for :  ESBK
# Get Data for :  ESCA
# Get Data for :  ESE
# Get Data for :  ESGR
# Get Data for :  ESNT
# Get Data for :  ESP
# Get Data for :  ESPR
# Get Data for :  ESRT
# Get Data for :  ESS
# Get Data for :  ESSA
# Get Data for :  ESTC
# Get Data for :  ESTE
# Get Data for :  ETN
# Get Data for :  ETR
# Get Data for :  ETRN
# Get Data for :  ETSY
# Get Data for :  EVBG
# Get Data for :  EVBN
# Get Data for :  EVC
# Get Data for :  EVER
# Get Data for :  EVFM
# Get Data for :  EVH
# Get Data for :  EVI
# Get Data for :  EVOK
# Get Data for :  EVOL
# Get Data for :  EVOP
# Get Data for :  EVR
# Get Data for :  EVRG
# Get Data for :  EVRI
# Get Data for :  EVTC
# Get Data for :  EW
# Get Data for :  EWBC
# Get Data for :  EXAS
# Get Data for :  EXC
# Get Data for :  EXEL
# Get Data for :  EXLS
# Get Data for :  EXP
# Get Data for :  EXPD
# Get Data for :  EXPE
# Get Data for :  EXPI
# Get Data for :  EXPO
# Get Data for :  EXPR
# Get Data for :  EXR
# Get Data for :  EXTN
# Get Data for :  EXTR
# Get Data for :  EYE
# Get Data for :  EYES
# Get Data for :  EYPT
# Get Data for :  EZPW
# Get Data for :  F
# Get Data for :  FAF
# Get Data for :  FANG
# Get Data for :  FARM
# Get Data for :  FARO
# Get Data for :  FAST
# Get Data for :  FATE
# Get Data for :  FB
# Get Data for :  FBC
# Get Data for :  FBHS
# Get Data for :  FBIO
# Get Data for :  FBIZ
# Get Data for :  FBK
# Get Data for :  FBMS
# Get Data for :  FBNC
# Get Data for :  FBP
# Get Data for :  FC
# Get Data for :  FCAP
# Get Data for :  FCBC
# Get Data for :  FCCO
# Get Data for :  FCEL
# Get Data for :  FCF
# Get Data for :  FCFS
# Get Data for :  FCN
# Get Data for :  FCNCA
# Get Data for :  FCPT
# Get Data for :  FCX
# Get Data for :  FDBC
# Get Data for :  FDP
# Get Data for :  FDS
# Get Data for :  FDX
# Get Data for :  FE
# Get Data for :  FEIM
# Get Data for :  FELE
# Get Data for :  FET
# Get Data for :  FF
# Get Data for :  FFBC
# Get Data for :  FFIC
# Get Data for :  FFIN
# Get Data for :  FFIV
# Get Data for :  FFNW
# Get Data for :  FFWM
# Get Data for :  FGBI
# Get Data for :  FGEN
# Get Data for :  FHB
# Get Data for :  FHN
# Get Data for :  FIBK
# Get Data for :  FICO
# Get Data for :  FIS
# Get Data for :  FISI
# Get Data for :  FISV
# Get Data for :  FITB
# Get Data for :  FIVE
# Get Data for :  FIVN
# Get Data for :  FIX
# Get Data for :  FIXX
# Get Data for :  FIZZ
# Get Data for :  FL
# Get Data for :  FLIC
# Get Data for :  FLL
# Get Data for :  FLMN
# Get Data for :  FLNT
# Finished
# ['ARAY', 'BLBD', 'CHMA', 'EGLE', 'EHC']

# %%
for x in range(1000, 1500):
    save_to_csv_from_yahoo(tickers[x], 2022, 1, 1, 2022, 1, 20)
print("Finished")
stocks_not_downloaded
# Out:
# Get Data for :  FLO
# Get Data for :  FLR
# Get Data for :  FLS
# Get Data for :  FLT
# Couldn't Get Data for : FLT
# Get Data for :  FLWS
# Get Data for :  FLXS
# Get Data for :  FMAO
# Get Data for :  FMBH
# Get Data for :  FMC
# Get Data for :  FMNB
# Get Data for :  FN
# Get Data for :  FNB
# Get Data for :  FNCB
# Get Data for :  FND
# Get Data for :  FNF
# Get Data for :  FNHC
# Get Data for :  FNKO
# Get Data for :  FNLC
# Get Data for :  FNWB
# Get Data for :  FOCS
# Get Data for :  FOLD
# Get Data for :  FONR
# Get Data for :  FOR
# Get Data for :  FORD
# Get Data for :  FORM
# Get Data for :  FORR
# Get Data for :  FOSL
# Get Data for :  FOX
# Get Data for :  FOXA
# Get Data for :  FOXF
# Get Data for :  FPI
# Get Data for :  FR
# Get Data for :  FRBA
# Get Data for :  FRBK
# Get Data for :  FRC
# Get Data for :  FRD
# Get Data for :  FRGI
# Get Data for :  FRME
# Get Data for :  FRPH
# Get Data for :  FRPT
# Get Data for :  FRT
# Get Data for :  FRTA
# Get Data for :  FSBW
# Get Data for :  FSFG
# Get Data for :  FSLR
# Get Data for :  FSLY
# Get Data for :  FSP
# Get Data for :  FSS
# Get Data for :  FSTR
# Get Data for :  FTDR
# Get Data for :  FTEK
# Get Data for :  FTI
# Get Data for :  FTK
# Get Data for :  FTNT
# Get Data for :  FTV
# Get Data for :  FUL
# Get Data for :  FULT
# Get Data for :  FUNC
# Get Data for :  FUSB
# Get Data for :  FWONA
# Get Data for :  FWONK
# Get Data for :  FWRD
# Get Data for :  G
# Get Data for :  GABC
# Get Data for :  GAIA
# Get Data for :  GALT
# Get Data for :  GATX
# Get Data for :  GBCI
# Get Data for :  GBL
# Get Data for :  GBLI
# Get Data for :  GBT
# Get Data for :  GBX
# Get Data for :  GCBC
# Get Data for :  GCI
# Get Data for :  GCO
# Get Data for :  GCP
# Get Data for :  GD
# Get Data for :  GDDY
# Get Data for :  GDEN
# Get Data for :  GDOT
# Get Data for :  GE
# Get Data for :  GEF
# Get Data for :  GENC
# Get Data for :  GEO
# Get Data for :  GEOS
# Get Data for :  GERN
# Get Data for :  GES
# Get Data for :  GEVO
# Get Data for :  GFED
# Get Data for :  GFF
# Get Data for :  GGG
# Get Data for :  GH
# Get Data for :  GHC
# Get Data for :  GHL
# Get Data for :  GHM
# Get Data for :  GIFI
# Get Data for :  GIII
# Get Data for :  GILD
# Get Data for :  GIS
# Get Data for :  GKOS
# Get Data for :  GLBZ
# Get Data for :  GLDD
# Get Data for :  GLPI
# Get Data for :  GLRE
# Get Data for :  GLT
# Get Data for :  GLW
# Get Data for :  GLYC
# Get Data for :  GM
# Get Data for :  GME
# Get Data for :  GMED
# Get Data for :  GMRE
# Get Data for :  GMS
# Get Data for :  GNCA
# Get Data for :  GNE
# Get Data for :  GNK
# Get Data for :  GNL
# Get Data for :  GNRC
# Get Data for :  GNTX
# Get Data for :  GNTY
# Get Data for :  GNW
# Get Data for :  GOGO
# Get Data for :  GOLF
# Get Data for :  GOOD
# Get Data for :  GOOG
# Get Data for :  GOOGL
# Get Data for :  GORO
# Get Data for :  GOSS
# Get Data for :  GPC
# Get Data for :  GPI
# Get Data for :  GPK
# Get Data for :  GPMT
# Get Data for :  GPN
# Get Data for :  GPRE
# Get Data for :  GPRO
# Get Data for :  GPS
# Get Data for :  GRBK
# Get Data for :  GRC
# Get Data for :  GRMN
# Get Data for :  GROW
# Get Data for :  GRPN
# Get Data for :  GRTS
# Get Data for :  GS
# Get Data for :  GSBC
# Get Data for :  GSHD
# Get Data for :  GSIT
# Get Data for :  GSKY
# Get Data for :  GT
# Get Data for :  GTES
# Get Data for :  GTHX
# Get Data for :  GTIM
# Get Data for :  GTLS
# Get Data for :  GTN
# Get Data for :  GTX
# Get Data for :  GTY
# Get Data for :  GTYH
# Get Data for :  GVA
# Get Data for :  GVP
# Get Data for :  GWRE
# Get Data for :  GWRS
# Get Data for :  GWW
# Get Data for :  H
# Get Data for :  HA
# Get Data for :  HAE
# Get Data for :  HAFC
# Get Data for :  HAIN
# Get Data for :  HAL
# Get Data for :  HALL
# Get Data for :  HALO
# Get Data for :  HAS
# Get Data for :  HASI
# Get Data for :  HAYN
# Get Data for :  HBAN
# Get Data for :  HBB
# Get Data for :  HBCP
# Get Data for :  HBI
# Get Data for :  HBIO
# Get Data for :  HBNC
# Get Data for :  HBP
# Get Data for :  HCA
# Get Data for :  HCC
# Get Data for :  HCCI
# Get Data for :  HCI
# Get Data for :  HCKT
# Get Data for :  HCSG
# Get Data for :  HD
# Get Data for :  HDSN
# Get Data for :  HE
# Get Data for :  HEAR
# Get Data for :  HEES
# Get Data for :  HEI
# Get Data for :  HELE
# Get Data for :  HES
# Get Data for :  HFBL
# Get Data for :  HFWA
# Get Data for :  HGV
# Get Data for :  HHC
# Get Data for :  HHS
# Get Data for :  HI
# Get Data for :  HIBB
# Get Data for :  HIFS
# Get Data for :  HIG
# Get Data for :  HII
# Get Data for :  HIL
# Get Data for :  HIW
# Get Data for :  HL
# Get Data for :  HLF
# Get Data for :  HLI
# Get Data for :  HLIT
# Get Data for :  HLNE
# Get Data for :  HLT
# Get Data for :  HLX
# Get Data for :  HMN
# Get Data for :  HMNF
# Get Data for :  HMST
# Get Data for :  HMTV
# Get Data for :  HNI
# Get Data for :  HNRG
# Get Data for :  HOFT
# Get Data for :  HOG
# Get Data for :  HOLX
# Get Data for :  HOMB
# Get Data for :  HON
# Get Data for :  HONE
# Get Data for :  HOPE
# Get Data for :  HOV
# Get Data for :  HP
# Get Data for :  HPE
# Get Data for :  HPP
# Get Data for :  HPQ
# Get Data for :  HQY
# Get Data for :  HR
# Get Data for :  HRB
# Get Data for :  HRI
# Get Data for :  HRL
# Get Data for :  HROW
# Get Data for :  HRTG
# Get Data for :  HRTX
# Get Data for :  HSC
# Get Data for :  HSIC
# Get Data for :  HSII
# Get Data for :  HSKA
# Get Data for :  HSON
# Get Data for :  HST
# Get Data for :  HSTM
# Get Data for :  HSY
# Get Data for :  HTA
# Get Data for :  HTBI
# Get Data for :  HTBK
# Get Data for :  HTBX
# Get Data for :  HTGM
# Get Data for :  HTH
# Get Data for :  HTLD
# Get Data for :  HTLF
# Get Data for :  HUBB
# Get Data for :  HUBG
# Get Data for :  HUBS
# Get Data for :  HUM
# Get Data for :  HUN
# Get Data for :  HURC
# Get Data for :  HURN
# Get Data for :  HUSA
# Get Data for :  HVT
# Get Data for :  HWBK
# Get Data for :  HWC
# Get Data for :  HWKN
# Get Data for :  HXL
# Get Data for :  HY
# Get Data for :  HZN
# Get Data for :  HZNP
# Get Data for :  HZO
# Get Data for :  IAC
# Get Data for :  IART
# Get Data for :  IBCP
# Get Data for :  IBIO
# Couldn't Get Data for : IBIO
# Get Data for :  IBKR
# Get Data for :  IBM
# Couldn't Get Data for : IBM
# Get Data for :  IBOC
# Couldn't Get Data for : IBOC
# Get Data for :  IBP
# Get Data for :  IBTX
# Get Data for :  ICAD
# Get Data for :  ICCC
# Get Data for :  ICD
# Get Data for :  ICE
# Get Data for :  ICFI
# Get Data for :  ICHR
# Get Data for :  ICPT
# Get Data for :  ICUI
# Get Data for :  IDA
# Get Data for :  IDCC
# Get Data for :  IDN
# Get Data for :  IDRA
# Get Data for :  IDT
# Get Data for :  IDXG
# Get Data for :  IDXX
# Get Data for :  IESC
# Get Data for :  IEX
# Get Data for :  IFF
# Get Data for :  III
# Get Data for :  IIIN
# Get Data for :  IIIV
# Get Data for :  IIN
# Get Data for :  IIPR
# Get Data for :  IIVI
# Get Data for :  ILMN
# Get Data for :  ILPT
# Get Data for :  IMGN
# Get Data for :  IMH
# Get Data for :  IMKTA
# Get Data for :  IMMR
# Get Data for :  IMXI
# Get Data for :  INBK
# Get Data for :  INCY
# Get Data for :  INDB
# Get Data for :  INFI
# Get Data for :  INFN
# Get Data for :  INFU
# Get Data for :  INGN
# Get Data for :  INGR
# Get Data for :  INN
# Get Data for :  INO
# Get Data for :  INOD
# Get Data for :  INPX
# Get Data for :  INSE
# Get Data for :  INSG
# Get Data for :  INSM
# Get Data for :  INSP
# Get Data for :  INSW
# Get Data for :  INT
# Get Data for :  INTC
# Get Data for :  INTG
# Get Data for :  INTT
# Get Data for :  INTU
# Get Data for :  INUV
# Get Data for :  INVA
# Get Data for :  INVE
# Get Data for :  INVH
# Get Data for :  IO
# Get Data for :  IONS
# Get Data for :  IOR
# Get Data for :  IOSP
# Get Data for :  IOVA
# Get Data for :  IP
# Get Data for :  IPAR
# Get Data for :  IPG
# Get Data for :  IPGP
# Get Data for :  IPI
# Get Data for :  IPWR
# Get Data for :  IQV
# Get Data for :  IR
# Get Data for :  IRBT
# Get Data for :  IRDM
# Get Data for :  IRIX
# Get Data for :  IRM
# Get Data for :  IRMD
# Get Data for :  IROQ
# Get Data for :  IRT
# Get Data for :  IRTC
# Get Data for :  IRWD
# Get Data for :  ISBC
# Get Data for :  ISDR
# Get Data for :  ISIG
# Get Data for :  ISR
# Get Data for :  ISRG
# Get Data for :  ISSC
# Get Data for :  ISTR
# Get Data for :  IT
# Get Data for :  ITCI
# Get Data for :  ITGR
# Get Data for :  ITI
# Get Data for :  ITIC
# Get Data for :  ITRI
# Get Data for :  ITT
# Get Data for :  ITW
# Get Data for :  IVAC
# Get Data for :  IVC
# Get Data for :  IVR
# Get Data for :  IVZ
# Get Data for :  IZEA
# Get Data for :  JACK
# Get Data for :  JAGX
# Get Data for :  JAKK
# Get Data for :  JAZZ
# Get Data for :  JBGS
# Get Data for :  JBHT
# Get Data for :  JBL
# Get Data for :  JBLU
# Get Data for :  JBSS
# Get Data for :  JBT
# Get Data for :  JCI
# Get Data for :  JCS
# Get Data for :  JCTCF
# Get Data for :  JEF
# Get Data for :  JELD
# Get Data for :  JHG
# Get Data for :  JILL
# Get Data for :  JJSF
# Get Data for :  JKHY
# Get Data for :  JLL
# Get Data for :  JNCE
# Get Data for :  JNJ
# Get Data for :  JNPR
# Get Data for :  JOB
# Get Data for :  JOE
# Get Data for :  JOUT
# Get Data for :  JPM
# Get Data for :  JRVR
# Get Data for :  JVA
# Get Data for :  JWN
# Get Data for :  JYNT
# Get Data for :  K
# Get Data for :  KAI
# Get Data for :  KALA
# Get Data for :  KALU
# Get Data for :  KALV
# Get Data for :  KAMN
# Get Data for :  KAR
# Get Data for :  KBAL
# Get Data for :  KBH
# Get Data for :  KBR
# Get Data for :  KDP
# Get Data for :  KE
# Get Data for :  KELYA
# Get Data for :  KEQU
# Get Data for :  KEX
# Get Data for :  KEY
# Get Data for :  KEYS
# Get Data for :  KFFB
# Get Data for :  KFRC
# Get Data for :  KFY
# Get Data for :  KHC
# Get Data for :  KIDS
# Get Data for :  KIM
# Get Data for :  KINS
# Get Data for :  KIRK
# Get Data for :  KKR
# Get Data for :  KLAC
# Get Data for :  KLIC
# Couldn't Get Data for : KLIC
# Get Data for :  KLXE
# Get Data for :  KMB
# Get Data for :  KMI
# Get Data for :  KMPH
# Get Data for :  KMPR
# Get Data for :  KMT
# Get Data for :  KMX
# Get Data for :  KN
# Get Data for :  KNSA
# Get Data for :  KNSL
# Get Data for :  KNX
# Get Data for :  KO
# Get Data for :  KOD
# Get Data for :  KODK
# Get Data for :  KOP
# Get Data for :  KOPN
# Get Data for :  KOS
# Get Data for :  KPTI
# Get Data for :  KR
# Get Data for :  KRC
# Get Data for :  KREF
# Get Data for :  KRG
# Get Data for :  KRNY
# Get Data for :  KRO
# Get Data for :  KRYS
# Get Data for :  KSS
# Get Data for :  KTCC
# Get Data for :  KTOS
# Get Data for :  KURA
# Get Data for :  KVHI
# Get Data for :  KW
# Get Data for :  KWR
# Get Data for :  KZR
# Get Data for :  L
# Get Data for :  LAD
# Get Data for :  LADR
# Get Data for :  LAKE
# Get Data for :  LAMR
# Get Data for :  LANC
# Get Data for :  LAND
# Get Data for :  LARK
# Get Data for :  LASR
# Get Data for :  LAUR
# Get Data for :  LAWS
# Get Data for :  LAZ
# Get Data for :  LBAI
# Get Data for :  LBC
# Get Data for :  LBRDA
# Get Data for :  LBRDK
# Get Data for :  LBRT
# Get Data for :  LBTYA
# Get Data for :  LBTYK
# Get Data for :  LC
# Get Data for :  LCI
# Get Data for :  LCII
# Get Data for :  LCNB
# Get Data for :  LCUT
# Get Data for :  LDOS
# Get Data for :  LE
# Get Data for :  LEA
# Get Data for :  LECO
# Get Data for :  LEE
# Get Data for :  LEG
# Finished
# ['ARAY', 'BLBD', 'CHMA', 'EGLE', 'EHC', 'FLT', 'IBIO', 'IBM', 'IBOC', 'KLIC']

# %%
for x in range(1500, 2000):
    save_to_csv_from_yahoo(tickers[x], 2022, 1, 1, 2022, 1, 20)
print("Finished")
stocks_not_downloaded
# Out:
# Get Data for :  LEGH
# Get Data for :  LEN
# Get Data for :  LEU
# Get Data for :  LEVI
# Get Data for :  LFUS
# Get Data for :  LFVN
# Get Data for :  LGIH
# Get Data for :  LGL
# Get Data for :  LGND
# Get Data for :  LH
# Get Data for :  LHCG
# Get Data for :  LIFE
# Get Data for :  LII
# Get Data for :  LILA
# Get Data for :  LILAK
# Get Data for :  LIN
# Get Data for :  LINC
# Get Data for :  LIND
# Get Data for :  LIQT
# Get Data for :  LITE
# Get Data for :  LIVE
# Get Data for :  LIVN
# Get Data for :  LJPC
# Get Data for :  LKFN
# Get Data for :  LKQ
# Get Data for :  LL
# Get Data for :  LLNW
# Get Data for :  LLY
# Get Data for :  LMAT
# Get Data for :  LMFA
# Get Data for :  LMNR
# Get Data for :  LMT
# Get Data for :  LNC
# Get Data for :  LNDC
# Get Data for :  LNG
# Get Data for :  LNN
# Get Data for :  LNT
# Get Data for :  LNTH
# Get Data for :  LOAN
# Get Data for :  LOB
# Get Data for :  LOCO
# Get Data for :  LODE
# Get Data for :  LOOP
# Get Data for :  LOPE
# Get Data for :  LOVE
# Get Data for :  LOW
# Get Data for :  LPCN
# Get Data for :  LPG
# Get Data for :  LPI
# Get Data for :  LPLA
# Get Data for :  LPSN
# Get Data for :  LPTH
# Get Data for :  LPX
# Get Data for :  LQDA
# Get Data for :  LQDT
# Get Data for :  LRCX
# Get Data for :  LRN
# Get Data for :  LSBK
# Get Data for :  LSCC
# Get Data for :  LSI
# Get Data for :  LSTR
# Get Data for :  LSXMA
# Get Data for :  LSXMK
# Get Data for :  LTBR
# Get Data for :  LTC
# Get Data for :  LTHM
# Get Data for :  LTRPA
# Get Data for :  LTRX
# Get Data for :  LUB
# Get Data for :  LULU
# Get Data for :  LUNA
# Get Data for :  LUV
# Get Data for :  LVS
# Get Data for :  LW
# Get Data for :  LWAY
# Get Data for :  LXP
# Get Data for :  LXRX
# Get Data for :  LXU
# Get Data for :  LYB
# Get Data for :  LYFT
# Get Data for :  LYTS
# Get Data for :  LYV
# Get Data for :  LZB
# Get Data for :  M
# Get Data for :  MA
# Get Data for :  MAA
# Get Data for :  MAC
# Get Data for :  MACK
# Get Data for :  MAN
# Get Data for :  MANH
# Get Data for :  MANT
# Get Data for :  MAR
# Get Data for :  MARA
# Get Data for :  MARK
# Get Data for :  MAS
# Get Data for :  MASI
# Get Data for :  MAT
# Get Data for :  MATW
# Get Data for :  MATX
# Get Data for :  MAYS
# Get Data for :  MBCN
# Get Data for :  MBI
# Get Data for :  MBII
# Get Data for :  MBIN
# Get Data for :  MBIO
# Get Data for :  MBOT
# Get Data for :  MBUU
# Get Data for :  MBWM
# Get Data for :  MC
# Get Data for :  MCB
# Get Data for :  MCBC
# Get Data for :  MCD
# Get Data for :  MCFT
# Get Data for :  MCHP
# Get Data for :  MCHX
# Get Data for :  MCK
# Get Data for :  MCO
# Get Data for :  MCRB
# Get Data for :  MCRI
# Get Data for :  MCS
# Get Data for :  MCY
# Get Data for :  MD
# Get Data for :  MDB
# Get Data for :  MDC
# Get Data for :  MDGL
# Get Data for :  MDLZ
# Get Data for :  MDRX
# Get Data for :  MDT
# Get Data for :  MDU
# Get Data for :  MED
# Get Data for :  MEDP
# Get Data for :  MEI
# Get Data for :  MEIP
# Get Data for :  MERC
# Get Data for :  MESA
# Get Data for :  MET
# Get Data for :  MFA
# Get Data for :  MG
# Get Data for :  MGEE
# Get Data for :  MGI
# Get Data for :  MGM
# Get Data for :  MGNX
# Get Data for :  MGPI
# Get Data for :  MGRC
# Get Data for :  MGTA
# Get Data for :  MGY
# Get Data for :  MGYR
# Get Data for :  MHH
# Get Data for :  MHK
# Get Data for :  MHLD
# Get Data for :  MHO
# Get Data for :  MIC
# Get Data for :  MICR
# Get Data for :  MICT
# Get Data for :  MIDD
# Get Data for :  MIND
# Get Data for :  MITK
# Get Data for :  MITT
# Get Data for :  MKC
# Get Data for :  MKL
# Get Data for :  MKSI
# Get Data for :  MKTX
# Get Data for :  MLAB
# Get Data for :  MLI
# Get Data for :  MLM
# Get Data for :  MLP
# Get Data for :  MLR
# Get Data for :  MLSS
# Get Data for :  MLVF
# Get Data for :  MMC
# Get Data for :  MMI
# Get Data for :  MMM
# Get Data for :  MMS
# Get Data for :  MMSI
# Get Data for :  MN
# Get Data for :  MNKD
# Get Data for :  MNOV
# Get Data for :  MNRL
# Get Data for :  MNRO
# Get Data for :  MNST
# Get Data for :  MNTX
# Get Data for :  MO
# Get Data for :  MOBL
# Couldn't Get Data for : MOBL
# Get Data for :  MOD
# Get Data for :  MODN
# Get Data for :  MOFG
# Get Data for :  MOH
# Get Data for :  MORN
# Get Data for :  MOS
# Get Data for :  MOTS
# Get Data for :  MOV
# Get Data for :  MPAA
# Get Data for :  MPB
# Get Data for :  MPC
# Get Data for :  MPW
# Get Data for :  MPWR
# Get Data for :  MPX
# Get Data for :  MRAM
# Get Data for :  MRC
# Get Data for :  MRCY
# Get Data for :  MRIN
# Get Data for :  MRK
# Get Data for :  MRKR
# Get Data for :  MRNS
# Get Data for :  MRO
# Get Data for :  MRSN
# Get Data for :  MRTN
# Get Data for :  MRTX
# Get Data for :  MRVL
# Get Data for :  MS
# Get Data for :  MSA
# Couldn't Get Data for : MSA
# Get Data for :  MSBI
# Get Data for :  MSCI
# Get Data for :  MSEX
# Get Data for :  MSFT
# Get Data for :  MSI
# Get Data for :  MSM
# Get Data for :  MSN
# Get Data for :  MSTR
# Get Data for :  MTB
# Get Data for :  MTCH
# Get Data for :  MTD
# Get Data for :  MTDR
# Get Data for :  MTEM
# Get Data for :  MTEX
# Get Data for :  MTG
# Get Data for :  MTH
# Get Data for :  MTN
# Get Data for :  MTNB
# Get Data for :  MTOR
# Get Data for :  MTRN
# Get Data for :  MTRX
# Get Data for :  MTSI
# Get Data for :  MTW
# Get Data for :  MTX
# Get Data for :  MTZ
# Get Data for :  MU
# Get Data for :  MUR
# Get Data for :  MUSA
# Get Data for :  MUX
# Get Data for :  MVBF
# Get Data for :  MVIS
# Get Data for :  MWA
# Get Data for :  MXL
# Get Data for :  MYE
# Get Data for :  MYGN
# Get Data for :  MYRG
# Get Data for :  NAII
# Get Data for :  NATH
# Get Data for :  NATI
# Get Data for :  NATR
# Get Data for :  NAVB
# Get Data for :  NAVI
# Get Data for :  NBHC
# Get Data for :  NBIX
# Get Data for :  NBN
# Get Data for :  NBR
# Get Data for :  NBTB
# Get Data for :  NBY
# Get Data for :  NC
# Get Data for :  NCBS
# Get Data for :  NCLH
# Get Data for :  NCMI
# Get Data for :  NCR
# Get Data for :  NCSM
# Get Data for :  NDAQ
# Get Data for :  NDLS
# Get Data for :  NDSN
# Get Data for :  NEE
# Get Data for :  NEM
# Get Data for :  NEO
# Get Data for :  NEOG
# Get Data for :  NEON
# Get Data for :  NERV
# Get Data for :  NEU
# Get Data for :  NEWR
# Get Data for :  NFBK
# Get Data for :  NFG
# Get Data for :  NFLX
# Get Data for :  NGS
# Get Data for :  NGVC
# Get Data for :  NGVT
# Get Data for :  NHC
# Get Data for :  NHI
# Get Data for :  NHTC
# Get Data for :  NI
# Get Data for :  NICK
# Get Data for :  NINE
# Get Data for :  NJR
# Get Data for :  NKE
# Get Data for :  NKSH
# Get Data for :  NKTR
# Get Data for :  NL
# Get Data for :  NLS
# Get Data for :  NLSN
# Get Data for :  NLY
# Get Data for :  NMIH
# Get Data for :  NMRK
# Get Data for :  NNBR
# Get Data for :  NNI
# Get Data for :  NNN
# Get Data for :  NNVC
# Get Data for :  NOC
# Get Data for :  NODK
# Get Data for :  NOG
# Get Data for :  NOV
# Get Data for :  NOVT
# Get Data for :  NOW
# Get Data for :  NP
# Get Data for :  NPK
# Get Data for :  NPO
# Get Data for :  NPTN
# Get Data for :  NR
# Get Data for :  NRC
# Get Data for :  NRG
# Get Data for :  NRIM
# Get Data for :  NRZ
# Get Data for :  NSA
# Get Data for :  NSC
# Get Data for :  NSEC
# Get Data for :  NSIT
# Get Data for :  NSP
# Get Data for :  NSSC
# Get Data for :  NSTG
# Get Data for :  NTAP
# Get Data for :  NTCT
# Get Data for :  NTGR
# Get Data for :  NTIC
# Get Data for :  NTIP
# Get Data for :  NTLA
# Get Data for :  NTNX
# Get Data for :  NTRA
# Get Data for :  NTRS
# Get Data for :  NTWK
# Get Data for :  NUAN
# Get Data for :  NUE
# Get Data for :  NURO
# Get Data for :  NUS
# Get Data for :  NUVA
# Get Data for :  NVAX
# Get Data for :  NVDA
# Get Data for :  NVEC
# Get Data for :  NVEE
# Get Data for :  NVFY
# Get Data for :  NVIV
# Get Data for :  NVR
# Get Data for :  NVRO
# Get Data for :  NVT
# Get Data for :  NVTA
# Get Data for :  NWBI
# Get Data for :  NWE
# Get Data for :  NWFL
# Get Data for :  NWL
# Get Data for :  NWLI
# Get Data for :  NWN
# Get Data for :  NWPX
# Get Data for :  NWS
# Get Data for :  NWSA
# Get Data for :  NX
# Get Data for :  NXGN
# Get Data for :  NXRT
# Get Data for :  NXST
# Get Data for :  NYCB
# Get Data for :  NYMT
# Get Data for :  NYT
# Get Data for :  O
# Get Data for :  OAS
# Get Data for :  OBCI
# Get Data for :  OBNK
# Get Data for :  OC
# Get Data for :  OCC
# Get Data for :  OCFC
# Get Data for :  OCN
# Get Data for :  OCUL
# Get Data for :  OCX
# Get Data for :  ODC
# Get Data for :  ODFL
# Get Data for :  ODP
# Get Data for :  OESX
# Get Data for :  OFC
# Get Data for :  OFED
# Get Data for :  OFG
# Get Data for :  OFIX
# Get Data for :  OFLX
# Get Data for :  OGE
# Get Data for :  OGEN
# Get Data for :  OGS
# Get Data for :  OHI
# Get Data for :  OI
# Get Data for :  OII
# Get Data for :  OIS
# Get Data for :  OKE
# Get Data for :  OKTA
# Get Data for :  OLED
# Get Data for :  OLLI
# Couldn't Get Data for : OLLI
# Get Data for :  OLP
# Get Data for :  OMC
# Couldn't Get Data for : OMC
# Get Data for :  OMCL
# Get Data for :  OMER
# Get Data for :  OMEX
# Get Data for :  OMF
# Get Data for :  OMI
# Get Data for :  ON
# Get Data for :  ONB
# Get Data for :  ONCS
# Get Data for :  ONTX
# Get Data for :  ONVO
# Get Data for :  OOMA
# Get Data for :  OPGN
# Get Data for :  OPI
# Get Data for :  OPK
# Get Data for :  OPOF
# Get Data for :  OPRX
# Get Data for :  OPTN
# Get Data for :  OPTT
# Get Data for :  OPY
# Get Data for :  ORA
# Get Data for :  ORC
# Get Data for :  ORCL
# Get Data for :  ORGO
# Get Data for :  ORI
# Get Data for :  ORLY
# Get Data for :  ORN
# Get Data for :  ORRF
# Get Data for :  OSBC
# Get Data for :  OSG
# Get Data for :  OSIS
# Get Data for :  OSK
# Get Data for :  OSPN
# Get Data for :  OSTK
# Get Data for :  OSUR
# Get Data for :  OTIC
# Get Data for :  OTTR
# Get Data for :  OUT
# Get Data for :  OVBC
# Get Data for :  OVLY
# Get Data for :  OXM
# Get Data for :  OXY
# Get Data for :  OZK
# Get Data for :  PACB
# Get Data for :  PACW
# Get Data for :  PAG
# Get Data for :  PAHC
# Get Data for :  PANL
# Get Data for :  PANW
# Get Data for :  PAR
# Get Data for :  PARR
# Get Data for :  PATI
# Get Data for :  PATK
# Get Data for :  PAYC
# Get Data for :  PAYX
# Get Data for :  PB
# Get Data for :  PBF
# Get Data for :  PBH
# Get Data for :  PBHC
# Get Data for :  PBI
# Get Data for :  PBIP
# Get Data for :  PBPB
# Get Data for :  PBYI
# Get Data for :  PCAR
# Get Data for :  PCH
# Get Data for :  PCRX
# Get Data for :  PCSB
# Get Data for :  PCTI
# Get Data for :  PCTY
# Get Data for :  PCYG
# Get Data for :  PCYO
# Get Data for :  PD
# Get Data for :  PDCE
# Get Data for :  PDCO
# Get Data for :  PDEX
# Get Data for :  PDFS
# Get Data for :  PDLB
# Get Data for :  PDM
# Get Data for :  PEB
# Get Data for :  PEBK
# Get Data for :  PEBO
# Get Data for :  PED
# Get Data for :  PEG
# Get Data for :  PEGA
# Get Data for :  PEI
# Get Data for :  PEN
# Get Data for :  PENN
# Get Data for :  PEP
# Get Data for :  PESI
# Get Data for :  PETQ
# Get Data for :  PETS
# Get Data for :  PFBC
# Get Data for :  PFE
# Get Data for :  PFG
# Get Data for :  PFGC
# Get Data for :  PFIE
# Get Data for :  PFIN
# Get Data for :  PFIS
# Get Data for :  PFMT
# Get Data for :  PFS
# Get Data for :  PFSW
# Get Data for :  PGC
# Get Data for :  PGR
# Get Data for :  PGRE
# Finished
# ['ARAY',
#  'BLBD',
#  'CHMA',
#  'EGLE',
#  'EHC',
#  'FLT',
#  'IBIO',
#  'IBM',
#  'IBOC',
#  'KLIC',
#  'MOBL',
#  'MSA',
#  'OLLI',
#  'OMC']

# %%
for x in range(2000, 2862):
    save_to_csv_from_yahoo(tickers[x], 2022, 1, 1, 2022, 1, 20)
print("Finished")
stocks_not_downloaded
# Out:
# Get Data for :  PGTI
# Get Data for :  PH
# Get Data for :  PHAS
# Get Data for :  PHIO
# Get Data for :  PHM
# Get Data for :  PHX
# Get Data for :  PI
# Get Data for :  PII
# Get Data for :  PINC
# Get Data for :  PINS
# Get Data for :  PJT
# Get Data for :  PK
# Get Data for :  PKBK
# Get Data for :  PKG
# Get Data for :  PKI
# Get Data for :  PKOH
# Get Data for :  PLAB
# Get Data for :  PLAN
# Get Data for :  PLAY
# Get Data for :  PLBC
# Get Data for :  PLCE
# Get Data for :  PLD
# Get Data for :  PLNT
# Get Data for :  PLOW
# Get Data for :  PLPC
# Get Data for :  PLSE
# Get Data for :  PLUS
# Get Data for :  PLYA
# Get Data for :  PLYM
# Get Data for :  PM
# Get Data for :  PMD
# Get Data for :  PMT
# Get Data for :  PMTS
# Get Data for :  PNBK
# Get Data for :  PNC
# Get Data for :  PNFP
# Get Data for :  PNM
# Get Data for :  PNR
# Get Data for :  PNRG
# Get Data for :  PNW
# Get Data for :  PODD
# Get Data for :  POOL
# Get Data for :  POR
# Get Data for :  POST
# Get Data for :  POWI
# Get Data for :  POWL
# Get Data for :  PPBI
# Get Data for :  PPC
# Get Data for :  PPG
# Get Data for :  PPIH
# Get Data for :  PPL
# Get Data for :  PPSI
# Get Data for :  PRA
# Get Data for :  PRAA
# Get Data for :  PRFT
# Get Data for :  PRGO
# Get Data for :  PRGS
# Get Data for :  PRI
# Get Data for :  PRIM
# Get Data for :  PRK
# Get Data for :  PRLB
# Get Data for :  PRMW
# Get Data for :  PRO
# Get Data for :  PROV
# Get Data for :  PRPH
# Couldn't Get Data for : PRPH
# Get Data for :  PRTA
# Get Data for :  PRTK
# Get Data for :  PRTS
# Couldn't Get Data for : PRTS
# Get Data for :  PRTY
# Couldn't Get Data for : PRTY
# Get Data for :  PRU
# Get Data for :  PRVB
# Get Data for :  PSA
# Get Data for :  PSB
# Get Data for :  PSMT
# Get Data for :  PSN
# Get Data for :  PSTG
# Get Data for :  PSX
# Get Data for :  PTC
# Get Data for :  PTCT
# Get Data for :  PTE
# Get Data for :  PTEN
# Get Data for :  PTGX
# Get Data for :  PTN
# Get Data for :  PTSI
# Get Data for :  PULM
# Get Data for :  PUMP
# Get Data for :  PVBC
# Get Data for :  PVH
# Get Data for :  PW
# Get Data for :  PWOD
# Get Data for :  PWR
# Get Data for :  PXD
# Get Data for :  PXLW
# Get Data for :  PYPL
# Get Data for :  PZG
# Get Data for :  PZN
# Get Data for :  PZZA
# Get Data for :  QCOM
# Get Data for :  QCRH
# Get Data for :  QDEL
# Get Data for :  QLYS
# Get Data for :  QNST
# Get Data for :  QRHC
# Get Data for :  QRTEA
# Get Data for :  QRVO
# Get Data for :  QTRX
# Get Data for :  QTWO
# Get Data for :  QUAD
# Get Data for :  QUIK
# Get Data for :  QUMU
# Get Data for :  QUOT
# Get Data for :  R
# Get Data for :  RAD
# Get Data for :  RAIL
# Get Data for :  RAMP
# Get Data for :  RARE
# Get Data for :  RAVE
# Get Data for :  RBB
# Get Data for :  RBBN
# Get Data for :  RBCAA
# Get Data for :  RBCN
# Get Data for :  RC
# Get Data for :  RCII
# Get Data for :  RCKY
# Get Data for :  RCL
# Get Data for :  RCM
# Get Data for :  RCMT
# Get Data for :  RCUS
# Get Data for :  RDFN
# Get Data for :  RDI
# Get Data for :  RDN
# Get Data for :  RDNT
# Get Data for :  RDUS
# Get Data for :  RDVT
# Get Data for :  RE
# Get Data for :  REED
# Get Data for :  REFR
# Get Data for :  REG
# Get Data for :  REGI
# Get Data for :  REGN
# Get Data for :  REI
# Get Data for :  RELL
# Get Data for :  RELV
# Get Data for :  REPH
# Get Data for :  REPL
# Get Data for :  RES
# Get Data for :  RESN
# Get Data for :  RETA
# Get Data for :  REV
# Get Data for :  REVG
# Get Data for :  REX
# Get Data for :  REXR
# Get Data for :  REZI
# Get Data for :  RF
# Get Data for :  RFIL
# Get Data for :  RFL
# Get Data for :  RFP
# Get Data for :  RGA
# Get Data for :  RGCO
# Get Data for :  RGEN
# Get Data for :  RGLD
# Get Data for :  RGLS
# Get Data for :  RGNX
# Get Data for :  RGR
# Get Data for :  RGS
# Get Data for :  RH
# Get Data for :  RHE
# Get Data for :  RHI
# Get Data for :  RHP
# Get Data for :  RIBT
# Get Data for :  RICK
# Get Data for :  RIG
# Get Data for :  RIGL
# Get Data for :  RILY
# Get Data for :  RIOT
# Get Data for :  RJF
# Get Data for :  RKDA
# Get Data for :  RL
# Get Data for :  RLGT
# Get Data for :  RLGY
# Get Data for :  RLI
# Get Data for :  RLJ
# Get Data for :  RM
# Get Data for :  RMAX
# Get Data for :  RMBS
# Get Data for :  RMCF
# Get Data for :  RMD
# Get Data for :  RMR
# Get Data for :  RMTI
# Get Data for :  RNDB
# Get Data for :  RNG
# Get Data for :  RNR
# Get Data for :  RNST
# Get Data for :  RNWK
# Get Data for :  ROCK
# Get Data for :  ROG
# Get Data for :  ROIC
# Get Data for :  ROK
# Get Data for :  ROKU
# Get Data for :  ROL
# Get Data for :  ROLL
# Get Data for :  ROP
# Get Data for :  ROST
# Get Data for :  RPD
# Get Data for :  RPM
# Get Data for :  RPT
# Get Data for :  RRC
# Get Data for :  RRGB
# Get Data for :  RRR
# Get Data for :  RRTS
# Get Data for :  RS
# Get Data for :  RSG
# Get Data for :  RUBY
# Get Data for :  RUN
# Get Data for :  RUSHA
# Get Data for :  RUSHB
# Get Data for :  RUTH
# Get Data for :  RVI
# Get Data for :  RVNC
# Get Data for :  RVP
# Get Data for :  RVSB
# Get Data for :  RWT
# Get Data for :  RYAM
# Get Data for :  RYI
# Get Data for :  RYN
# Get Data for :  RYTM
# Get Data for :  SABR
# Get Data for :  SACH
# Get Data for :  SAFE
# Get Data for :  SAFM
# Get Data for :  SAFT
# Get Data for :  SAGE
# Get Data for :  SAH
# Get Data for :  SAIA
# Get Data for :  SAIC
# Get Data for :  SAIL
# Get Data for :  SAL
# Get Data for :  SALM
# Get Data for :  SAM
# Get Data for :  SAMG
# Get Data for :  SANM
# Get Data for :  SANW
# Get Data for :  SASR
# Get Data for :  SATS
# Get Data for :  SAVE
# Get Data for :  SBAC
# Get Data for :  SBCF
# Get Data for :  SBFG
# Get Data for :  SBGI
# Get Data for :  SBH
# Get Data for :  SBNY
# Get Data for :  SBOW
# Get Data for :  SBRA
# Get Data for :  SBSI
# Get Data for :  SBT
# Get Data for :  SBUX
# Get Data for :  SCHL
# Get Data for :  SCHN
# Get Data for :  SCHW
# Get Data for :  SCI
# Get Data for :  SCL
# Get Data for :  SCOR
# Get Data for :  SCPL
# Get Data for :  SCS
# Get Data for :  SCSC
# Get Data for :  SCVL
# Get Data for :  SCWX
# Get Data for :  SCX
# Get Data for :  SCYX
# Get Data for :  SD
# Get Data for :  SDPI
# Get Data for :  SEAC
# Get Data for :  SEAS
# Get Data for :  SEB
# Get Data for :  SEE
# Get Data for :  SEIC
# Get Data for :  SELB
# Get Data for :  SELF
# Get Data for :  SEM
# Get Data for :  SENEA
# Get Data for :  SENEB
# Get Data for :  SESN
# Get Data for :  SF
# Get Data for :  SFBC
# Get Data for :  SFBS
# Get Data for :  SFE
# Get Data for :  SFIX
# Get Data for :  SFM
# Get Data for :  SFNC
# Get Data for :  SFST
# Get Data for :  SGA
# Get Data for :  SGC
# Get Data for :  SGEN
# Get Data for :  SGH
# Get Data for :  SGMA
# Get Data for :  SGMO
# Get Data for :  SGRP
# Get Data for :  SGRY
# Get Data for :  SHAK
# Get Data for :  SHBI
# Get Data for :  SHEN
# Get Data for :  SHO
# Get Data for :  SHOO
# Get Data for :  SHW
# Get Data for :  SIBN
# Get Data for :  SIEB
# Get Data for :  SIEN
# Get Data for :  SIF
# Get Data for :  SIG
# Get Data for :  SIGA
# Get Data for :  SIGI
# Get Data for :  SILK
# Get Data for :  SINT
# Get Data for :  SIRI
# Get Data for :  SITC
# Get Data for :  SITE
# Get Data for :  SIVB
# Get Data for :  SIX
# Get Data for :  SJI
# Get Data for :  SJM
# Get Data for :  SJW
# Get Data for :  SKT
# Get Data for :  SKX
# Get Data for :  SKY
# Get Data for :  SKYW
# Get Data for :  SLAB
# Get Data for :  SLB
# Get Data for :  SLCA
# Get Data for :  SLDB
# Get Data for :  SLG
# Get Data for :  SLGN
# Get Data for :  SLM
# Get Data for :  SLNO
# Get Data for :  SLP
# Couldn't Get Data for : SLP
# Get Data for :  SLS
# Get Data for :  SM
# Get Data for :  SMAR
# Get Data for :  SMBC
# Get Data for :  SMBK
# Get Data for :  SMED
# Couldn't Get Data for : SMED
# Get Data for :  SMG
# Get Data for :  SMIT
# Get Data for :  SMMF
# Get Data for :  SMP
# Get Data for :  SMPL
# Get Data for :  SMSI
# Get Data for :  SMTC
# Get Data for :  SNA
# Get Data for :  SNAP
# Get Data for :  SNBR
# Get Data for :  SNCR
# Get Data for :  SND
# Get Data for :  SNDR
# Get Data for :  SNDX
# Get Data for :  SNFCA
# Get Data for :  SNOA
# Get Data for :  SNPS
# Get Data for :  SNV
# Get Data for :  SNX
# Get Data for :  SO
# Get Data for :  SOHO
# Get Data for :  SOI
# Get Data for :  SON
# Get Data for :  SONO
# Get Data for :  SP
# Get Data for :  SPB
# Get Data for :  SPG
# Get Data for :  SPGI
# Get Data for :  SPLK
# Get Data for :  SPOK
# Get Data for :  SPPI
# Get Data for :  SPR
# Get Data for :  SPRO
# Get Data for :  SPSC
# Get Data for :  SPTN
# Get Data for :  SPWH
# Get Data for :  SPWR
# Get Data for :  SPXC
# Get Data for :  SQ
# Get Data for :  SR
# Get Data for :  SRC
# Get Data for :  SRCE
# Get Data for :  SRCL
# Get Data for :  SRDX
# Get Data for :  SRE
# Get Data for :  SREV
# Get Data for :  SRG
# Get Data for :  SRI
# Get Data for :  SRNE
# Get Data for :  SRPT
# Get Data for :  SRRK
# Get Data for :  SRT
# Get Data for :  SRTS
# Get Data for :  SSB
# Get Data for :  SSBI
# Get Data for :  SSD
# Get Data for :  SSKN
# Get Data for :  SSNC
# Get Data for :  SSP
# Get Data for :  SSTI
# Get Data for :  SSTK
# Get Data for :  ST
# Get Data for :  STAA
# Get Data for :  STAG
# Get Data for :  STAR
# Get Data for :  STBA
# Get Data for :  STC
# Get Data for :  STCN
# Get Data for :  STE
# Get Data for :  STIM
# Get Data for :  STKS
# Get Data for :  STLD
# Get Data for :  STOR
# Get Data for :  STRA
# Get Data for :  STRL
# Get Data for :  STRM
# Get Data for :  STRS
# Get Data for :  STRT
# Get Data for :  STT
# Get Data for :  STWD
# Get Data for :  STX
# Get Data for :  STXB
# Get Data for :  STZ
# Get Data for :  SUI
# Get Data for :  SUM
# Get Data for :  SUMR
# Get Data for :  SUNW
# Get Data for :  SUP
# Get Data for :  SUPN
# Get Data for :  SVRA
# Get Data for :  SVT
# Get Data for :  SWAV
# Get Data for :  SWCH
# Get Data for :  SWK
# Get Data for :  SWKS
# Get Data for :  SWM
# Get Data for :  SWN
# Get Data for :  SWX
# Get Data for :  SXC
# Get Data for :  SXI
# Get Data for :  SXT
# Get Data for :  SYBT
# Get Data for :  SYBX
# Get Data for :  SYF
# Get Data for :  SYK
# Get Data for :  SYN
# Get Data for :  SYNA
# Get Data for :  SYNH
# Get Data for :  SYNL
# Get Data for :  SYPR
# Get Data for :  SYRS
# Get Data for :  SYY
# Get Data for :  T
# Get Data for :  TACO
# Get Data for :  TACT
# Get Data for :  TAIT
# Get Data for :  TALO
# Get Data for :  TAP
# Get Data for :  TAST
# Get Data for :  TAYD
# Get Data for :  TBBK
# Get Data for :  TBI
# Get Data for :  TBK
# Get Data for :  TBNK
# Get Data for :  TBPH
# Get Data for :  TCBI
# Get Data for :  TCBK
# Get Data for :  TCDA
# Get Data for :  TCFC
# Get Data for :  TCI
# Get Data for :  TCMD
# Get Data for :  TCON
# Get Data for :  TCS
# Get Data for :  TDC
# Get Data for :  TDG
# Get Data for :  TDOC
# Get Data for :  TDS
# Get Data for :  TDW
# Get Data for :  TDY
# Get Data for :  TEL
# Get Data for :  TELL
# Get Data for :  TEN
# Get Data for :  TENB
# Get Data for :  TENX
# Get Data for :  TER
# Get Data for :  TESS
# Get Data for :  TEUM
# Get Data for :  TEX
# Get Data for :  TFSL
# Get Data for :  TFX
# Get Data for :  TG
# Get Data for :  TGEN
# Get Data for :  TGI
# Get Data for :  TGLS
# Get Data for :  TGNA
# Get Data for :  TGT
# Get Data for :  TGTX
# Get Data for :  THC
# Get Data for :  THFF
# Get Data for :  THG
# Get Data for :  THO
# Get Data for :  THR
# Get Data for :  THRM
# Get Data for :  THS
# Get Data for :  TILE
# Get Data for :  TIPT
# Get Data for :  TISI
# Get Data for :  TITN
# Get Data for :  TJX
# Get Data for :  TKR
# Get Data for :  TLYS
# Get Data for :  TMDX
# Get Data for :  TMHC
# Get Data for :  TMO
# Get Data for :  TMP
# Get Data for :  TMST
# Get Data for :  TMUS
# Get Data for :  TNC
# Get Data for :  TNDM
# Get Data for :  TNET
# Get Data for :  TNXP
# Get Data for :  TOL
# Get Data for :  TOWN
# Get Data for :  TPB
# Get Data for :  TPC
# Get Data for :  TPH
# Get Data for :  TPHS
# Get Data for :  TPIC
# Get Data for :  TPR
# Get Data for :  TPTX
# Get Data for :  TPX
# Get Data for :  TR
# Get Data for :  TRC
# Get Data for :  TREC
# Get Data for :  TREE
# Get Data for :  TREX
# Get Data for :  TRGP
# Get Data for :  TRHC
# Get Data for :  TRIP
# Get Data for :  TRMB
# Get Data for :  TRMK
# Get Data for :  TRN
# Get Data for :  TRNO
# Get Data for :  TRNS
# Get Data for :  TROW
# Get Data for :  TROX
# Get Data for :  TRS
# Get Data for :  TRST
# Get Data for :  TRT
# Get Data for :  TRTN
# Get Data for :  TRTX
# Get Data for :  TRU
# Get Data for :  TRUP
# Get Data for :  TRV
# Get Data for :  TRVN
# Get Data for :  TSBK
# Get Data for :  TSC
# Get Data for :  TSCO
# Get Data for :  TSE
# Get Data for :  TSLA
# Get Data for :  TSN
# Get Data for :  TSQ
# Get Data for :  TTC
# Get Data for :  TTD
# Get Data for :  TTEC
# Get Data for :  TTEK
# Get Data for :  TTGT
# Get Data for :  TTI
# Get Data for :  TTMI
# Get Data for :  TTNP
# Get Data for :  TTOO
# Get Data for :  TUP
# Get Data for :  TUSK
# Get Data for :  TVTY
# Get Data for :  TW
# Get Data for :  TWI
# Get Data for :  TWIN
# Get Data for :  TWLO
# Get Data for :  TWNK
# Get Data for :  TWO
# Get Data for :  TWOU
# Get Data for :  TWST
# Get Data for :  TWTR
# Get Data for :  TXMD
# Get Data for :  TXN
# Get Data for :  TXRH
# Get Data for :  TXT
# Get Data for :  TYL
# Get Data for :  TYME
# Get Data for :  TZOO
# Get Data for :  UA
# Get Data for :  UAA
# Get Data for :  UAL
# Get Data for :  UAMY
# Get Data for :  UBA
# Get Data for :  UBCP
# Get Data for :  UBER
# Get Data for :  UBFO
# Get Data for :  UBOH
# Get Data for :  UBSI
# Get Data for :  UCBI
# Get Data for :  UCTT
# Get Data for :  UDR
# Get Data for :  UE
# Get Data for :  UEC
# Get Data for :  UEIC
# Get Data for :  UFAB
# Get Data for :  UFCS
# Get Data for :  UFI
# Get Data for :  UFPI
# Get Data for :  UFPT
# Get Data for :  UG
# Get Data for :  UGI
# Get Data for :  UHAL
# Get Data for :  UHS
# Get Data for :  UHT
# Get Data for :  UIHC
# Get Data for :  UIS
# Get Data for :  ULBI
# Get Data for :  ULH
# Get Data for :  ULTA
# Get Data for :  UMBF
# Get Data for :  UMH
# Get Data for :  UMPQ
# Get Data for :  UNAM
# Get Data for :  UNB
# Get Data for :  UNF
# Get Data for :  UNFI
# Get Data for :  UNH
# Get Data for :  UNIT
# Get Data for :  UNP
# Get Data for :  UNTY
# Get Data for :  UNVR
# Get Data for :  UONE
# Get Data for :  UONEK
# Get Data for :  UPLD
# Get Data for :  UPS
# Get Data for :  UPWK
# Get Data for :  URBN
# Get Data for :  URI
# Get Data for :  USAK
# Get Data for :  USAP
# Get Data for :  USB
# Get Data for :  USEG
# Get Data for :  USFD
# Get Data for :  USIO
# Get Data for :  USLM
# Get Data for :  USM
# Get Data for :  USNA
# Get Data for :  USPH
# Get Data for :  USWS
# Get Data for :  USX
# Get Data for :  UTHR
# Get Data for :  UTI
# Get Data for :  UTL
# Get Data for :  UTMD
# Get Data for :  UUU
# Get Data for :  UVE
# Get Data for :  UVSP
# Get Data for :  UVV
# Get Data for :  V
# Get Data for :  VAC
# Get Data for :  VALU
# Get Data for :  VAPO
# Get Data for :  VBFC
# Get Data for :  VBIV
# Get Data for :  VBTX
# Get Data for :  VC
# Get Data for :  VCEL
# Get Data for :  VCTR
# Get Data for :  VCYT
# Get Data for :  VEC
# Get Data for :  VECO
# Get Data for :  VEEV
# Get Data for :  VERI
# Get Data for :  VERU
# Get Data for :  VFC
# Get Data for :  VG
# Get Data for :  VGR
# Get Data for :  VHC
# Get Data for :  VIAV
# Get Data for :  VICI
# Get Data for :  VICR
# Get Data for :  VIRC
# Get Data for :  VIRT
# Get Data for :  VISL
# Get Data for :  VIVO
# Get Data for :  VKTX
# Get Data for :  VLGEA
# Get Data for :  VLO
# Get Data for :  VLY
# Get Data for :  VMC
# Get Data for :  VMI
# Get Data for :  VMW
# Get Data for :  VNCE
# Get Data for :  VNDA
# Get Data for :  VNE
# Get Data for :  VNO
# Get Data for :  VNRX
# Get Data for :  VNTR
# Get Data for :  VOXX
# Get Data for :  VOYA
# Get Data for :  VPG
# Get Data for :  VRA
# Get Data for :  VRAY
# Get Data for :  VREX
# Get Data for :  VRNS
# Get Data for :  VRNT
# Get Data for :  VRRM
# Get Data for :  VRS
# Get Data for :  VRSK
# Get Data for :  VRSN
# Get Data for :  VRTS
# Get Data for :  VRTV
# Get Data for :  VRTX
# Get Data for :  VSAT
# Get Data for :  VSEC
# Get Data for :  VSH
# Get Data for :  VST
# Get Data for :  VSTM
# Get Data for :  VSTO
# Get Data for :  VTNR
# Get Data for :  VTR
# Get Data for :  VTVT
# Get Data for :  VUZI
# Get Data for :  VVI
# Get Data for :  VVV
# Get Data for :  VXRT
# Get Data for :  VYGR
# Get Data for :  VZ
# Get Data for :  W
# Get Data for :  WAB
# Get Data for :  WABC
# Get Data for :  WAFD
# Get Data for :  WAL
# Get Data for :  WASH
# Get Data for :  WAT
# Get Data for :  WATT
# Get Data for :  WBA
# Get Data for :  WBS
# Get Data for :  WBT
# Get Data for :  WCC
# Get Data for :  WD
# Get Data for :  WDAY
# Get Data for :  WDC
# Get Data for :  WDFC
# Get Data for :  WEC
# Get Data for :  WELL
# Get Data for :  WEN
# Get Data for :  WERN
# Get Data for :  WETF
# Get Data for :  WEX
# Get Data for :  WEYS
# Get Data for :  WFC
# Get Data for :  WGO
# Get Data for :  WH
# Get Data for :  WHD
# Get Data for :  WHG
# Get Data for :  WHLM
# Get Data for :  WHLR
# Get Data for :  WHR
# Get Data for :  WINA
# Get Data for :  WING
# Get Data for :  WIRE
# Get Data for :  WK
# Get Data for :  WKHS
# Get Data for :  WLDN
# Get Data for :  WLFC
# Get Data for :  WLK
# Get Data for :  WLL
# Get Data for :  WM
# Get Data for :  WMB
# Get Data for :  WMC
# Get Data for :  WMK
# Get Data for :  WMS
# Get Data for :  WMT
# Get Data for :  WNC
# Get Data for :  WNEB
# Get Data for :  WOR
# Get Data for :  WOW
# Couldn't Get Data for : WOW
# Get Data for :  WPC
# Get Data for :  WRB
# Get Data for :  WRE
# Get Data for :  WRK
# Get Data for :  WRLD
# Get Data for :  WSBC
# Get Data for :  WSBF
# Get Data for :  WSC
# Get Data for :  WSFS
# Get Data for :  WSM
# Get Data for :  WSO
# Get Data for :  WSR
# Get Data for :  WST
# Get Data for :  WSTG
# Get Data for :  WSTL
# Get Data for :  WTBA
# Get Data for :  WTFC
# Get Data for :  WTI
# Get Data for :  WTM
# Get Data for :  WTRH
# Get Data for :  WTS
# Get Data for :  WTT
# Get Data for :  WTTR
# Get Data for :  WU
# Get Data for :  WVE
# Get Data for :  WVFC
# Get Data for :  WVVI
# Get Data for :  WW
# Get Data for :  WWD
# Get Data for :  WWE
# Get Data for :  WWR
# Get Data for :  WWW
# Get Data for :  WY
# Get Data for :  WYNN
# Get Data for :  WYY
# Get Data for :  X
# Get Data for :  XBIT
# Get Data for :  XEL
# Get Data for :  XELA
# Get Data for :  XELB
# Get Data for :  XENT
# Get Data for :  XERS
# Get Data for :  XFOR
# Get Data for :  XHR
# Get Data for :  XNCR
# Get Data for :  XOM
# Get Data for :  XOMA
# Get Data for :  XPER
# Get Data for :  XPL
# Get Data for :  XPO
# Get Data for :  XRAY
# Get Data for :  XRX
# Get Data for :  XSPA
# Get Data for :  XTNT
# Get Data for :  XXII
# Get Data for :  XYL
# Get Data for :  Y
# Get Data for :  YELP
# Get Data for :  YETI
# Get Data for :  YEXT
# Get Data for :  YMAB
# Get Data for :  YORW
# Get Data for :  YTEN
# Get Data for :  YUM
# Get Data for :  Z
# Get Data for :  ZBH
# Get Data for :  ZBRA
# Get Data for :  ZDGE
# Get Data for :  ZEN
# Get Data for :  ZEUS
# Get Data for :  ZG
# Get Data for :  ZION
# Get Data for :  ZM
# Get Data for :  ZNGA
# Get Data for :  ZS
# Get Data for :  ZSAN
# Get Data for :  ZTS
# Get Data for :  ZUMZ
# Get Data for :  ZUO
# Get Data for :  ZVO
# Get Data for :  ZYNE
# Get Data for :  ZYXI
# Finished
# ['ARAY',
#  'BLBD',
#  'CHMA',
#  'EGLE',
#  'EHC',
#  'FLT',
#  'IBIO',
#  'IBM',
#  'IBOC',
#  'KLIC',
#  'MOBL',
#  'MSA',
#  'OLLI',
#  'OMC',
#  'PRPH',
#  'PRTS',
#  'PRTY',
#  'SLP',
#  'SMED',
#  'WOW']

# %%
for x in missing_stocks:
    save_to_csv_from_yahoo(x, 2022, 1, 1, 2022, 1, 20)
print("Finished")
stocks_not_downloaded
# Out:
# Finished
# ['ARAY',
#  'BLBD',
#  'CHMA',
#  'EGLE',
#  'EHC',
#  'FLT',
#  'IBIO',
#  'IBM',
#  'IBOC',
#  'KLIC',
#  'MOBL',
#  'MSA',
#  'OLLI',
#  'OMC',
#  'PRPH',
#  'PRTS',
#  'PRTY',
#  'SLP',
#  'SMED',
#  'WOW']

# %% [markdown]
# #### Function that Returns a Dataframe from a CSV

# %%
def get_df_from_csv(folder, ticker):
    try:
        df = pd.read_csv(folder + ticker + '.csv', index_col='Date', 
                         parse_dates=True)
    except FileNotFoundError:
        pass
        print("File Doesn't Exist")
    else:
        return df

# %% [markdown]
# #### Merge New Data

# %%
def update_stock_data(ticker):
    # For Windows 
    up_folder = '../data/update/'

    # For Windows 
    stock_folder = PATH

    update_df = get_df_from_csv(up_folder, ticker)
    update_df

    # Get original dataframe
    orig_df = get_df_from_csv(stock_folder, ticker)

    # Drop the unnamed column
    orig_df.drop(orig_df.columns[orig_df.columns.str.contains('unnamed',case = False)],
          axis = 1, inplace = True)

    # Drop the daily_return column
    orig_df = orig_df.drop('daily_return', 1)

    join_df = pd.concat([orig_df, update_df])
    return join_df

# %% [markdown]
# #### Save Dataframe to CSV

# %%
def save_dataframe_to_csv(df, folder, ticker):
    df.to_csv(folder + ticker + '.csv')

# %% [markdown]
# #### Update Files with New Data

# %%
def update_stocks(stock_folder):
    
    for x in tickers:
        try:
            print("Working on :", x)
            new_df = update_stock_data(x)
            save_dataframe_to_csv(new_df, stock_folder, x)
        except Exception as ex:
            print(ex)

# %%
# For Windows
update_stocks(PATH)
# Out:
# Working on : A
# Working on : AA
# Working on : AAL
# Working on : AAME
# Working on : AAN
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# Working on : AAOI
# Working on : AAON
# Working on : AAP
# Working on : AAPL
# Working on : AAT
# Working on : AAWW
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# Working on : ABBV
# Working on : ABC
# Working on : ABCB
# Working on : ABEO
# Working on : ABG
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# Working on : ABIO
# Working on : ABM
# Working on : ABMD
# Working on : ABR
# Working on : ABT
# Working on : ABTX
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# Working on : AC
# Working on : ACA
# Working on : ACAD
# Working on : ACBI
# Working on : ACC
# Working on : ACCO
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# Working on : ACER
# Working on : ACGL
# Working on : ACHC
# Working on : ACHV
# Working on : ACIW
# Working on : ACLS
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# Working on : ACM
# Working on : ACMR
# Working on : ACN
# Working on : ACNB
# Working on : ACOR
# Working on : ACRE
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# Working on : ACRS
# Working on : ACRX
# Working on : ACTG
# Working on : ACU
# Working on : ADBE
# Working on : ADC
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# Working on : ADES
# Working on : ADI
# Working on : ADM
# Working on : ADMA
# Working on : ADMP
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# Working on : ADNT
# Working on : ADP
# Working on : ADSK
# Working on : ADT
# Working on : ADTN
# Working on : ADUS
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# Working on : ADVM
# Working on : ADXS
# Working on : AE
# Working on : AEE
# Working on : AEHR
# Working on :
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
#  AEIS
# Working on : AEL
# Working on : AEMD
# Working on : AEO
# Working on : AEP
# Working on : AERI
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# Working on : AES
# Working on : AEY
# Working on : AFG
# Working on : AFI
# Working on : AFL
# Working on : AGCO
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# Working on : AGE
# Working on : AGEN
# Working on : AGFS
# Working on : AGIO
# Working on : AGLE
# Working on : AGM
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# Working on : AGNC
# Working on : AGO
# Working on : AGR
# Working on : AGRX
# Working on : AGS
# Working on : AGTC
# Working on : AGX
# Working on : AGYS
# Working on : AHH
# Working on : AHT
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# Working on : AIG
# Working on : AIMC
# Working on : AIN
# Working on : AINC
# Working on : AIR
# Working on : AIRG
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# Working on : AIRI
# Working on : AIRT
# Working on : AIT
# Working on : AIV
# Working on : AIZ
# Working on : AJG
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# Working on : AJRD
# Working on : AJX
# Working on : AKAM
# Working on : AKBA
# Working on : AKR
# Working on : AKTS
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# Working on : AL
# Working on : ALB
# Working on : ALBO
# Working on : ALCO
# Working on : ALDX
# Working on : ALE
# Working on : ALEC
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# Working on : ALEX
# Working on : ALG
# Working on : ALGN
# Working on : ALGT
# Working on : ALIM
# Working on : ALJJ
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# Working on : ALK
# Working on : ALKS
# Working on : ALL
# Working on : ALLE
# Working on : ALLK
# Working on : ALLO
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# Working on : ALLY
# Working on : ALNA
# Working on : ALNY
# Working on : ALOT
# Working on : ALPN
# Working on : ALRM
# Working on : ALSN
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# Working on : ALT
# Working on : ALTR
# Working on : ALV
# Working on : ALX
# Working on : AM
# Working on : AMAL
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# Working on : AMAT
# Working on : AMBC
# Working on : AMC
# Working on : AMCX
# Working on : AMD
# Working on : AME
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# Working on : AMED
# Working on : AMG
# Working on : AMGN
# Working on : AMH
# Working on : AMKR
# Working on : AMN
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# Working on : AMNB
# Working on : AMOT
# Working on : AMP
# Working on : AMPE
# Working on : AMPH
# Working on : AMRC
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# Working on : AMRK
# Working on : AMRS
# Working on : AMRX
# Working on : AMS
# Working on : AMSC
# Working on : AMSF
# Working on : AMSWA
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# Working on : AMT
# Working on : AMTD
# Working on : AMTX
# Working on : AMWD
# Working on : AMZN
# Working on : AN
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# Working on : ANAB
# Working on : ANAT
# Working on : ANDE
# Working on : ANET
# Working on : ANF
# Working on : ANGI
# Working on : ANGO
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# Working on : ANIK
# Working on : ANIP
# Working on : ANIX
# Working on : ANSS
# Working on : ANTM
# Working on : AON
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# ...
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# Working on : WVFC
# Working on : WVVI
# Working on : WW
# Working on : WWD
# Working on : WWE
# Working on : WWR
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# Working on : WWW
# Working on : WY
# Working on : WYNN
# Working on : WYY
# Working on : X
# Working on : XBIT
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# Working on : XEL
# Working on : XELA
# Working on : XELB
# Working on : XENT
# Working on : XERS
# Working on : XFOR
# Working on : XHR
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# Working on : XNCR
# Working on : XOM
# Working on : XOMA
# Working on : XPER
# Working on : XPL
# Working on : XPO
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# Working on : XRAY
# Working on : XRX
# Working on : XSPA
# Working on : XTNT
# Working on : XXII
# Working on : XYL
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# Working on : Y
# Working on : YELP
# Working on : YETI
# Working on : YEXT
# Working on : YMAB
# Working on : YORW
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# Working on : YTEN
# Working on : YUM
# Working on : Z
# Working on : ZBH
# Working on : ZBRA
# Working on : ZDGE
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# Working on : ZEN
# Working on : ZEUS
# Working on : ZG
# Working on : ZION
# Working on : ZM
# Working on : ZNGA
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# Working on : ZS
# Working on : ZSAN
# Working on : ZTS
# Working on : ZUMZ
# Working on : ZUO
# Working on : ZVO
# Working on : ZYNE
# Working on : ZYXI
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)
# C:\Users\FC\AppData\Local\Temp\ipykernel_672\3915858256.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   orig_df = orig_df.drop('daily_return', 1)

# %% [markdown]
# #### Add Daily Return to Dataframe

# %%
# We calculate a percentage rate of return for each day to compare investments.
# Simple Rate of Return = (End Price - Beginning Price) / Beginning Price OR (EP / BP) - 1

# Shift provides the value from the previous day
# NaN is displayed because there was no previous day price for the 1st calculation
def add_daily_return_to_df(df, ticker):
    df['daily_return'] = (df['Adj Close'] / df['Adj Close'].shift(1)) - 1
    # Save data to a CSV file
    # For Windows
    df.to_csv(PATH + ticker + '.csv')
    
    return df

# %% [markdown]
# #### Update Daily Returns

# %%
for x in tickers:
    try:
        print("Working on :", x)
        new_df = get_df_from_csv(PATH, x)
        new_df = add_daily_return_to_df(new_df, x)
        save_dataframe_to_csv(new_df, PATH, x)
    except Exception as ex:
        print(ex)
# Out:
# Working on : A
# Working on : AA
# Working on : AAL
# Working on : AAME
# Working on : AAN
# Working on : AAOI
# Working on : AAON
# Working on : AAP
# Working on : AAPL
# Working on : AAT
# Working on : AAWW
# Working on : ABBV
# Working on : ABC
# Working on : ABCB
# Working on : ABEO
# Working on : ABG
# Working on : ABIO
# Working on : ABM
# Working on : ABMD
# Working on : ABR
# Working on : ABT
# Working on : ABTX
# Working on : AC
# Working on : ACA
# Working on : ACAD
# Working on : ACBI
# Working on : ACC
# Working on : ACCO
# Working on : ACER
# Working on : ACGL
# Working on : ACHC
# Working on : ACHV
# Working on : ACIW
# Working on : ACLS
# Working on : ACM
# Working on : ACMR
# Working on : ACN
# Working on : ACNB
# Working on : ACOR
# Working on : ACRE
# Working on : ACRS
# Working on : ACRX
# Working on : ACTG
# Working on : ACU
# Working on : ADBE
# Working on : ADC
# Working on : ADES
# Working on : ADI
# Working on : ADM
# Working on : ADMA
# Working on : ADMP
# Working on : ADNT
# Working on : ADP
# Working on : ADSK
# Working on : ADT
# Working on : ADTN
# Working on : ADUS
# Working on : ADVM
# Working on : ADXS
# Working on : AE
# Working on : AEE
# Working on : AEHR
# Working on : AEIS
# Working on : AEL
# Working on : AEMD
# Working on : AEO
# Working on : AEP
# Working on : AERI
# Working on : AES
# Working on : AEY
# Working on : AFG
# Working on : AFI
# Working on : AFL
# Working on : AGCO
# Working on : AGE
# Working on : AGEN
# Working on : AGFS
# Working on : AGIO
# Working on : AGLE
# Working on : AGM
# Working on : AGNC
# Working on : AGO
# Working on : AGR
# Working on : AGRX
# Working on : AGS
# Working on : AGTC
# Working on : AGX
# Working on : AGYS
# Working on : AHH
# Working on : AHT
# Working on : AIG
# Working on : AIMC
# Working on : AIN
# Working on : AINC
# Working on : AIR
# Working on : AIRG
# Working on : AIRI
# Working on : AIRT
# Working on : AIT
# Working on : AIV
# Working on : AIZ
# Working on : AJG
# Working on : AJRD
# Working on : AJX
# Working on : AKAM
# Working on : AKBA
# Working on : AKR
# Working on : AKTS
# Working on : AL
# Working on : ALB
# Working on : ALBO
# Working on : ALCO
# Working on : ALDX
# Working on : ALE
# Working on : ALEC
# Working on : ALEX
# Working on : ALG
# Working on : ALGN
# Working on : ALGT
# Working on : ALIM
# Working on : ALJJ
# Working on : ALK
# Working on : ALKS
# Working on : ALL
# Working on : ALLE
# Working on : ALLK
# Working on : ALLO
# Working on : ALLY
# Working on : ALNA
# Working on : ALNY
# Working on : ALOT
# Working on : ALPN
# Working on : ALRM
# Working on : ALSN
# Working on : ALT
# Working on : ALTR
# Working on : ALV
# Working on : ALX
# Working on : AM
# Working on : AMAL
# Working on : AMAT
# Working on : AMBC
# Working on : AMC
# Working on : AMCX
# Working on : AMD
# Working on : AME
# Working on : AMED
# Working on : AMG
# Working on : AMGN
# Working on : AMH
# Working on : AMKR
# Working on : AMN
# Working on : AMNB
# Working on : AMOT
# Working on : AMP
# Working on : AMPE
# Working on : AMPH
# Working on : AMRC
# Working on : AMRK
# Working on : AMRS
# Working on : AMRX
# Working on : AMS
# Working on : AMSC
# Working on : AMSF
# Working on : AMSWA
# Working on : AMT
# Working on : AMTD
# Working on : AMTX
# Working on : AMWD
# Working on : AMZN
# Working on : AN
# Working on : ANAB
# Working on : ANAT
# Working on : ANDE
# Working on : ANET
# Working on : ANF
# Working on : ANGI
# Working on : ANGO
# Working on : ANIK
# Working on : ANIP
# Working on : ANIX
# Working on : ANSS
# Working on : ANTM
# Working on : AON
# Working on : AOS
# Working on : AOSL
# Working on : AP
# Working on : APA
# Working on : APAM
# Working on : APD
# Working on : APDN
# Working on : APEI
# Working on : APEN
# Working on : APH
# Working on : APLE
# Working on : APLS
# Working on : APOG
# Working on : APPF
# Working on : APPN
# Working on : APPS
# Working on : APRN
# Working on : APT
# Working on : APTS
# Working on : APTV
# Working on : APVO
# Working on : APYX
# Working on : AQB
# Working on : AQMS
# Working on : AQUA
# Working on : AR
# Working on : ARAV
# Working on : ARAY
# Working on : ARC
# Working on : ARCB
# Working on : ARCH
# Working on : ARDX
# Working on : ARE
# Working on : ARES
# Working on : ARGO
# Working on : ARI
# Working on : ARKR
# Working on : ARL
# Working on : ARLO
# Working on : ARMK
# Working on : ARNA
# Working on : ARNC
# Working on : AROC
# Working on : AROW
# Working on : ARR
# Working on : ARTNA
# Working on : ARTW
# Working on : ARVN
# Working on : ARW
# Working on : ARWR
# Working on : ASB
# Working on : ASGN
# Working on : ASH
# Working on : ASIX
# Working on : ASMB
# Working on : ASPN
# Working on : ASRV
# Working on : ASTC
# Working on : ASTE
# Working on : ASUR
# Working on : ASYS
# Working on : ATEC
# Working on : ATEN
# Working on : ATGE
# Working on : ATHX
# Working on : ATI
# Working on : ATKR
# Working on : ATLC
# Working on : ATLO
# Working on : ATNI
# Working on : ATNM
# Working on : ATNX
# Working on : ATO
# Working on : ATOS
# Working on : ATR
# Working on : ATRA
# Working on : ATRC
# Working on : ATRI
# Working on : ATRO
# Working on : ATRS
# Working on : ATSG
# Working on : ATUS
# Working on : ATVI
# Working on : AUBN
# Working on : AUMN
# Working on : AUTO
# Working on : AVA
# Working on : AVAV
# Working on : AVB
# Working on : AVD
# Working on : AVEO
# Working on : AVGO
# Working on : AVGR
# Working on : AVID
# Working on : AVLR
# Working on : AVNS
# Working on : AVNW
# Working on : AVRO
# Working on : AVT
# Working on : AVTR
# Working on : AVXL
# Working on : AVY
# Working on : AVYA
# Working on : AWI
# Working on : AWK
# Working on : AWR
# Working on : AWRE
# Working on : AX
# Working on : AXAS
# Working on : AXDX
# Working on : AXGN
# Working on : AXL
# Working on : AXNX
# Working on : AXP
# Working on : AXR
# Working on : AXS
# Working on : AXSM
# Working on : AXTA
# Working on : AXTI
# Working on : AYI
# Working on : AYX
# Working on : AZO
# Working on : AZPN
# Working on : AZZ
# Working on : B
# Working on : BA
# Working on : BAC
# Working on : BAH
# Working on : BANC
# Working on : BAND
# Working on : BANF
# Working on : BANR
# Working on : BATRA
# Working on : BATRK
# Working on : BAX
# Working on : BBBY
# Working on : BBCP
# Working on : BBGI
# Working on : BBSI
# Working on : BBW
# Working on : BBY
# Working on : BC
# Working on : BCBP
# Working on : BCC
# Working on : BCLI
# Working on : BCO
# Working on : BCOR
# Working on : BCOV
# Working on : BCPC
# Working on : BCRX
# Working on : BDC
# Working on : BDL
# Working on : BDN
# Working on : BDSI
# Working on : BDX
# Working on : BECN
# Working on : BELFA
# Working on : BEN
# Working on : BERY
# Working on : BFAM
# Working on : BFIN
# Working on : BFS
# Working on : BFST
# Working on : BGFV
# Working on : BGS
# Working on : BGSF
# Working on : BH
# Working on : BHB
# Working on : BHE
# Working on : BHF
# Working on : BHLB
# Working on : BHR
# Working on : BHVN
# Working on : BIG
# Working on : BIIB
# Working on : BIO
# Working on : BIOC
# Working on : BIOL
# Working on : BJ
# Working on : BJRI
# Working on : BK
# Working on : BKD
# Working on : BKE
# Working on : BKH
# Working on : BKI
# Working on : BKNG
# Working on : BKSC
# Working on : BKTI
# Working on : BKU
# Working on : BL
# Working on : BLBD
# Working on : BLCM
# Working on : BLD
# Working on : BLDR
# Working on : BLFS
# Working on : BLK
# Working on : BLKB
# Working on : BLL
# Working on : BLMN
# Working on : BLUE
# Working on : BMI
# Working on : BMRC
# Working on : BMRN
# Working on : BMY
# Working on : BNED
# Working on : BNFT
# Working on : BOH
# Working on : BOKF
# Working on : BOOM
# Working on : BOOT
# Working on : BOTJ
# Working on : BOX
# Working on : BPMC
# Working on : BPOP
# Working on : BPRN
# Working on : BPTH
# Working on : BR
# Working on : BRC
# Working on : BRG
# Working on : BRID
# Working on : BRKL
# Working on : BRKR
# Working on : BRN
# Working on : BRO
# Working on : BRT
# Working on : BRX
# Working on : BRY
# Working on : BSET
# Working on : BSGM
# Working on : BSQR
# Working on : BSRR
# Working on : BSX
# Working on : BTN
# Working on : BTU
# Working on : BURL
# Working on : BUSE
# Working on : BV
# Working on : BW
# Working on : BWA
# Working on : BWEN
# Working on : BWFG
# Working on : BWXT
# Working on : BXC
# Working on : BXMT
# Working on : BXP
# Working on : BY
# Working on : BYD
# Working on : BYFC
# Working on : BYND
# Working on : BZH
# Working on : C
# Working on : CABO
# Working on : CAC
# Working on : CACC
# Working on : CACI
# Working on : CADE
# Working on : CAG
# Working on : CAH
# Working on : CAKE
# Working on : CAL
# Working on : CALA
# Working on : CALM
# Working on : CALX
# Working on : CAMP
# Working on : CAPR
# Working on : CAR
# Working on : CARA
# Working on : CARG
# Working on : CARS
# Working on : CASA
# Working on : CASH
# Working on : CASI
# Working on : CASS
# Working on : CASY
# Working on : CAT
# Working on : CATC
# Working on : CATO
# Working on : CATY
# Working on : CB
# Working on : CBAN
# Working on : CBAY
# Working on : CBFV
# Working on : CBIO
# Working on : CBOE
# Working on : CBRE
# Working on : CBRL
# Working on : CBSH
# Working on : CBT
# Working on : CBTX
# Working on : CBU
# Working on : CBZ
# Working on : CC
# Working on : CCBG
# Working on : CCF
# Working on : CCI
# Working on : CCK
# Working on : CCL
# Working on : CCMP
# Working on : CCNE
# Working on : CCO
# Working on : CCOI
# Working on : CCRN
# Working on : CCS
# Working on : CCXI
# Working on : CDAY
# Working on : CDE
# Working on : CDEV
# Working on : CDK
# Working on : CDLX
# Working on : CDMO
# Working on : CDNA
# Working on : CDNS
# Working on : CDR
# Working on : CDTX
# Working on : CDW
# Working on : CDXC
# Working on : CDXS
# Working on : CDZI
# Working on : CE
# Working on : CECE
# Working on : CEI
# Working on : CEIX
# Working on : CELC
# Working on : CELH
# Working on : CEMI
# Working on : CENT
# Working on : CENTA
# Working on : CENX
# Working on : CERN
# Working on : CERS
# Working on : CETX
# Working on : CEVA
# Working on : CF
# Working on : CFBK
# Working on : CFFI
# Working on : CFFN
# Working on : CFG
# Working on : CFMS
# Working on : CFR
# Working on : CGNX
# Working on : CHCI
# Working on : CHCO
# Working on : CHCT
# Working on : CHD
# Working on : CHDN
# Working on : CHE
# Working on : CHEF
# Working on : CHGG
# Working on : CHH
# Working on : CHMA
# Working on : CHMG
# Working on : CHMI
# Working on : CHRS
# Working on : CHRW
# Working on : CHS
# Working on : CHTR
# Working on : CHUY
# Working on : CI
# Working on : CIA
# Working on : CIDM
# Working on : CIEN
# Working on : CIM
# Working on : CINF
# Working on : CIO
# Working on : CIR
# Working on : CIVB
# Working on : CIX
# Working on : CIZN
# Working on : CKX
# Working on : CL
# Working on : CLAR
# Working on : CLB
# Working on : CLBS
# Working on : CLDT
# Working on : CLDX
# Working on : CLF
# Working on : CLFD
# Working on : CLH
# Working on : CLIR
# Working on : CLNE
# Working on : CLPR
# Working on : CLR
# Working on : CLRB
# Working on : CLRO
# Working on : CLSN
# Working on : CLVS
# Working on : CLW
# Working on : CLX
# Working on : CLXT
# Working on : CMA
# Working on : CMC
# Working on : CMCO
# Working on : CMCSA
# Working on : CMCT
# Working on : CME
# Working on : CMG
# Working on : CMI
# Working on : CMP
# Working on : CMRX
# Working on : CMS
# Working on : CMT
# Working on : CMTL
# Working on : CNA
# Working on : CNC
# Working on : CNCE
# Working on : CNDT
# Working on : CNFR
# Working on : CNK
# Working on : CNMD
# Working on : CNNE
# Working on : CNO
# Working on : CNOB
# Working on : CNP
# Working on : CNS
# Working on : CNSL
# Working on : CNTY
# Working on : CNX
# Working on : CNXN
# Working on : CODA
# Working on : COF
# Working on : COHN
# Working on : COHR
# Working on : COHU
# Working on : COKE
# Working on : COLB
# Working on : COLD
# Working on : COLL
# Working on : COLM
# Working on : COMM
# Working on : CONE
# Working on : CONN
# Working on : COO
# Working on : COOP
# Working on : COP
# Working on : CORR
# Working on : CORT
# Working on : COST
# Working on : COTY
# Working on : COUP
# Working on : COWN
# Working on : CPB
# Working on : CPE
# Working on : CPF
# Working on : CPHC
# Working on : CPIX
# Working on : CPK
# Working on : CPRI
# Working on : CPRT
# Working on : CPRX
# Working on : CPS
# Working on : CPSH
# Working on : CPSI
# Working on : CPSS
# Working on : CPT
# Working on : CR
# Working on : CRAI
# Working on : CRBP
# Working on : CRC
# Working on : CRI
# Working on : CRIS
# Working on : CRK
# Working on : CRL
# Working on : CRM
# Working on : CRMD
# Working on : CRMT
# Working on : CRNX
# Working on : CROX
# Working on : CRS
# Working on : CRTX
# Working on : CRUS
# Working on : CRVL
# Working on : CRVS
# Working on : CRWS
# Working on : CSCO
# Working on : CSGP
# Working on : CSGS
# Working on : CSII
# Working on : CSL
# Working on : CSPI
# Working on : CSTR
# Working on : CSV
# Working on : CSWI
# Working on : CSX
# Working on : CTAS
# Working on : CTBI
# Working on : CTG
# Working on : CTHR
# Working on : CTIB
# Working on : CTIC
# Working on : CTLT
# Working on : CTMX
# Working on : CTO
# Working on : CTRE
# Working on : CTRN
# Working on : CTS
# Working on : CTSH
# Working on : CTSO
# Working on : CTT
# Working on : CTXS
# Working on : CUBE
# Working on : CUBI
# Working on : CUE
# Working on : CULP
# Working on : CURO
# Working on : CUTR
# Working on : CUZ
# Working on : CVBF
# Working on : CVCO
# Working on : CVCY
# Working on : CVGI
# Working on : CVGW
# Working on : CVI
# Working on : CVLT
# Working on : CVLY
# Working on : CVM
# Working on : CVNA
# Working on : CVR
# Working on : CVS
# Working on : CVU
# Working on : CVV
# Working on : CVX
# Working on : CW
# Working on : CWBC
# Working on : CWBR
# Working on : CWEN
# Working on : CWH
# Working on : CWST
# Working on : CWT
# Working on : CXW
# Working on : CYAN
# Working on : CYBE
# Working on : CYCC
# Working on : CYH
# Working on : CYRX
# Working on : CYTK
# Working on : CYTR
# Working on : CZNC
# Working on : CZR
# Working on : CZWI
# Working on : D
# Working on : DAIO
# Working on : DAKT
# Working on : DAL
# Working on : DAN
# Working on : DAR
# Working on : DARE
# Working on : DBD
# Working on : DBI
# Working on : DBX
# Working on : DCI
# Working on : DCO
# Working on : DCOM
# Working on : DCPH
# Working on : DD
# Working on : DDD
# Working on : DDS
# Working on : DE
# Working on : DEA
# Working on : DECK
# Working on : DEI
# Working on : DELL
# Working on : DENN
# Working on : DFIN
# Working on : DFS
# Working on : DG
# Working on : DGICA
# Working on : DGII
# Working on : DGLY
# Working on : DGX
# Working on : DHI
# Working on : DHIL
# Working on : DHR
# Working on : DHX
# Working on : DIN
# Working on : DIOD
# Working on : DIS
# Working on : DISCA
# Working on : DISCK
# Working on : DISH
# Working on : DIT
# Working on : DJCO
# Working on : DK
# Working on : DKS
# Working on : DLA
# Working on : DLB
# Working on : DLHC
# Working on : DLR
# Working on : DLTH
# Working on : DLTR
# Working on : DLX
# Working on : DMRC
# Working on : DNLI
# Working on : DNOW
# Working on : DOC
# Working on : DOCU
# Working on : DOMO
# Working on : DOOR
# Working on : DORM
# Working on : DOV
# Working on : DOW
# Working on : DPZ
# Working on : DRE
# Working on : DRH
# Working on : DRI
# Working on : DRQ
# Working on : DRRX
# Working on : DS
# Working on : DSKE
# Working on : DSS
# Working on : DTE
# Working on : DUK
# Working on : DVA
# Working on : DVAX
# Working on : DVN
# Working on : DWSN
# Working on : DX
# Working on : DXC
# Working on : DXCM
# Working on : DXLG
# Working on : DXPE
# Working on : DXYN
# Working on : DY
# Working on : DZSI
# Working on : EA
# Working on : EAF
# Working on : EARN
# Working on : EAT
# Working on : EB
# Working on : EBAY
# Working on : EBF
# Working on : EBIX
# Working on : EBMT
# Working on : EBS
# Working on : EBTC
# Working on : ECL
# Working on : ECOL
# Working on : ECOM
# Working on : ECPG
# Working on : ED
# Working on : EDIT
# Working on : EDUC
# Working on : EEFT
# Working on : EEX
# Working on : EFC
# Working on : EFOI
# Working on : EFSC
# Working on : EFX
# Working on : EGAN
# Working on : EGBN
# Working on : EGHT
# Working on : EGLE
# Working on : EGP
# Working on : EGRX
# Working on : EGY
# Working on : EHC
# Working on : EHTH
# Working on : EIG
# Working on : EIGR
# Working on : EIX
# Working on : EKSO
# Working on : EL
# Working on : ELAN
# Working on : ELF
# Working on : ELMD
# Working on : ELOX
# Working on : ELS
# Working on : ELSE
# Working on : ELVT
# Working on : ELY
# Working on : EMAN
# Working on : EMCF
# Working on : EME
# Working on : EMKR
# Working on : EML
# Working on : EMMS
# Working on : EMN
# Working on : EMR
# Working on : ENDP
# Working on : ENG
# Working on : ENOB
# Working on : ENPH
# Working on : ENR
# Working on : ENS
# Working on : ENSG
# Working on : ENSV
# Working on : ENTA
# Working on : ENTG
# Working on : ENV
# Working on : ENVA
# Working on : ENZ
# Working on : EPAY
# Working on : EPC
# Working on : EPM
# Working on : EPR
# Working on : EPRT
# Working on : EPZM
# Working on : EQBK
# Working on : EQC
# Working on : EQH
# Working on : EQIX
# Working on : EQR
# Working on : EQT
# Working on : ERIE
# Working on : ERII
# Working on : ES
# Working on : ESBK
# Working on : ESCA
# Working on : ESE
# Working on : ESGR
# Working on : ESNT
# Working on : ESP
# Working on : ESPR
# Working on : ESRT
# Working on : ESS
# Working on : ESSA
# Working on : ESTC
# Working on : ESTE
# Working on : ETN
# Working on : ETR
# Working on : ETRN
# Working on : ETSY
# Working on : EVBG
# Working on : EVBN
# Working on : EVC
# Working on : EVER
# Working on : EVFM
# Working on : EVH
# Working on : EVI
# Working on : EVOK
# Working on : EVOL
# Working on : EVOP
# Working on : EVR
# Working on : EVRG
# Working on : EVRI
# Working on : EVTC
# Working on : EW
# Working on : EWBC
# Working on : EXAS
# Working on : EXC
# Working on : EXEL
# Working on : EXLS
# Working on : EXP
# Working on : EXPD
# Working on : EXPE
# Working on : EXPI
# Working on : EXPO
# Working on : EXPR
# Working on : EXR
# Working on : EXTN
# Working on : EXTR
# Working on : EYE
# Working on : EYES
# Working on : EYPT
# Working on : EZPW
# Working on : F
# Working on : FAF
# Working on : FANG
# Working on : FARM
# Working on : FARO
# Working on : FAST
# Working on : FATE
# Working on : FB
# Working on : FBC
# Working on : FBHS
# Working on : FBIO
# Working on : FBIZ
# Working on : FBK
# Working on : FBMS
# Working on : FBNC
# Working on : FBP
# Working on : FC
# Working on : FCAP
# Working on : FCBC
# Working on : FCCO
# Working on : FCEL
# Working on : FCF
# Working on : FCFS
# Working on : FCN
# Working on : FCNCA
# Working on : FCPT
# Working on : FCX
# Working on : FDBC
# Working on : FDP
# Working on : FDS
# Working on : FDX
# Working on : FE
# Working on : FEIM
# Working on : FELE
# Working on : FET
# Working on : FF
# Working on : FFBC
# Working on : FFIC
# Working on : FFIN
# Working on : FFIV
# Working on : FFNW
# Working on : FFWM
# Working on : FGBI
# Working on : FGEN
# Working on : FHB
# Working on : FHN
# Working on : FIBK
# Working on : FICO
# Working on : FIS
# Working on : FISI
# Working on : FISV
# Working on : FITB
# Working on : FIVE
# Working on : FIVN
# Working on : FIX
# Working on : FIXX
# Working on : FIZZ
# Working on : FL
# Working on : FLIC
# Working on : FLL
# Working on : FLMN
# Working on : FLNT
# Working on : FLO
# Working on : FLR
# Working on : FLS
# Working on : FLT
# Working on : FLWS
# Working on : FLXS
# Working on : FMAO
# Working on : FMBH
# Working on : FMC
# Working on : FMNB
# Working on : FN
# Working on : FNB
# Working on : FNCB
# Working on : FND
# Working on : FNF
# Working on : FNHC
# Working on : FNKO
# Working on : FNLC
# Working on : FNWB
# Working on : FOCS
# Working on : FOLD
# Working on : FONR
# Working on : FOR
# Working on : FORD
# Working on : FORM
# Working on : FORR
# Working on : FOSL
# Working on : FOX
# Working on : FOXA
# Working on : FOXF
# Working on : FPI
# Working on : FR
# Working on : FRBA
# Working on : FRBK
# Working on : FRC
# Working on : FRD
# Working on : FRGI
# Working on : FRME
# Working on : FRPH
# Working on : FRPT
# Working on : FRT
# Working on : FRTA
# Working on : FSBW
# Working on : FSFG
# Working on : FSLR
# Working on : FSLY
# Working on : FSP
# Working on : FSS
# Working on : FSTR
# Working on : FTDR
# Working on : FTEK
# Working on : FTI
# Working on : FTK
# Working on : FTNT
# Working on : FTV
# Working on : FUL
# Working on : FULT
# Working on : FUNC
# Working on : FUSB
# Working on : FWONA
# Working on : FWONK
# Working on : FWRD
# Working on : G
# Working on : GABC
# Working on : GAIA
# Working on : GALT
# Working on : GATX
# Working on : GBCI
# Working on : GBL
# Working on : GBLI
# Working on : GBT
# Working on : GBX
# Working on : GCBC
# Working on : GCI
# Working on : GCO
# Working on : GCP
# Working on : GD
# Working on : GDDY
# Working on : GDEN
# Working on : GDOT
# Working on : GE
# Working on : GEF
# Working on : GENC
# Working on : GEO
# Working on : GEOS
# Working on : GERN
# Working on : GES
# Working on : GEVO
# Working on : GFED
# Working on : GFF
# Working on : GGG
# Working on : GH
# Working on : GHC
# Working on : GHL
# Working on : GHM
# Working on : GIFI
# Working on : GIII
# Working on : GILD
# Working on : GIS
# Working on : GKOS
# Working on : GLBZ
# Working on : GLDD
# Working on : GLPI
# Working on : GLRE
# Working on : GLT
# Working on : GLW
# Working on : GLYC
# Working on : GM
# Working on : GME
# Working on : GMED
# Working on : GMRE
# Working on : GMS
# Working on : GNCA
# Working on : GNE
# Working on : GNK
# Working on : GNL
# Working on : GNRC
# Working on : GNTX
# Working on : GNTY
# Working on : GNW
# Working on : GOGO
# Working on : GOLF
# Working on : GOOD
# Working on : GOOG
# Working on : GOOGL
# Working on : GORO
# Working on : GOSS
# Working on : GPC
# Working on : GPI
# Working on : GPK
# Working on : GPMT
# Working on : GPN
# Working on : GPRE
# Working on : GPRO
# Working on : GPS
# Working on : GRBK
# Working on : GRC
# Working on : GRMN
# Working on : GROW
# Working on : GRPN
# Working on : GRTS
# Working on : GS
# Working on : GSBC
# Working on : GSHD
# Working on : GSIT
# Working on : GSKY
# Working on : GT
# Working on : GTES
# Working on : GTHX
# Working on : GTIM
# Working on : GTLS
# Working on : GTN
# Working on : GTX
# Working on : GTY
# Working on : GTYH
# Working on : GVA
# Working on : GVP
# Working on : GWRE
# Working on : GWRS
# Working on : GWW
# Working on : H
# Working on : HA
# Working on : HAE
# Working on : HAFC
# Working on : HAIN
# Working on : HAL
# Working on : HALL
# Working on : HALO
# Working on : HAS
# Working on : HASI
# Working on : HAYN
# Working on : HBAN
# Working on : HBB
# Working on : HBCP
# Working on : HBI
# Working on : HBIO
# Working on : HBNC
# Working on : HBP
# Working on : HCA
# Working on : HCC
# Working on : HCCI
# Working on : HCI
# Working on : HCKT
# Working on : HCSG
# Working on : HD
# Working on : HDSN
# Working on : HE
# Working on : HEAR
# Working on : HEES
# Working on : HEI
# Working on : HELE
# Working on : HES
# Working on : HFBL
# Working on : HFWA
# Working on : HGV
# Working on : HHC
# Working on : HHS
# Working on : HI
# Working on : HIBB
# Working on : HIFS
# Working on : HIG
# Working on : HII
# Working on : HIL
# Working on : HIW
# Working on : HL
# Working on : HLF
# Working on : HLI
# Working on : HLIT
# Working on : HLNE
# Working on : HLT
# Working on : HLX
# Working on : HMN
# Working on : HMNF
# Working on : HMST
# Working on : HMTV
# Working on : HNI
# Working on : HNRG
# Working on : HOFT
# Working on : HOG
# Working on : HOLX
# Working on : HOMB
# Working on : HON
# Working on : HONE
# Working on : HOPE
# Working on : HOV
# Working on : HP
# Working on : HPE
# Working on : HPP
# Working on : HPQ
# Working on : HQY
# Working on : HR
# Working on : HRB
# Working on : HRI
# Working on : HRL
# Working on : HROW
# Working on : HRTG
# Working on : HRTX
# Working on : HSC
# Working on : HSIC
# Working on : HSII
# Working on : HSKA
# Working on : HSON
# Working on : HST
# Working on : HSTM
# Working on : HSY
# Working on : HTA
# Working on : HTBI
# Working on : HTBK
# Working on : HTBX
# Working on : HTGM
# Working on : HTH
# Working on : HTLD
# Working on : HTLF
# Working on : HUBB
# Working on : HUBG
# Working on : HUBS
# Working on : HUM
# Working on : HUN
# Working on : HURC
# Working on : HURN
# Working on : HUSA
# Working on : HVT
# Working on : HWBK
# Working on : HWC
# Working on : HWKN
# Working on : HXL
# Working on : HY
# Working on : HZN
# Working on : HZNP
# Working on : HZO
# Working on : IAC
# Working on : IART
# Working on : IBCP
# Working on : IBIO
# Working on : IBKR
# Working on : IBM
# Working on : IBOC
# Working on : IBP
# Working on : IBTX
# Working on : ICAD
# Working on : ICCC
# Working on : ICD
# Working on : ICE
# Working on : ICFI
# Working on : ICHR
# Working on : ICPT
# Working on : ICUI
# Working on : IDA
# Working on : IDCC
# Working on : IDN
# Working on : IDRA
# Working on : IDT
# Working on : IDXG
# Working on : IDXX
# Working on : IESC
# Working on : IEX
# Working on : IFF
# Working on : III
# Working on : IIIN
# Working on : IIIV
# Working on : IIN
# Working on : IIPR
# Working on : IIVI
# Working on : ILMN
# Working on : ILPT
# Working on : IMGN
# Working on : IMH
# Working on : IMKTA
# Working on : IMMR
# Working on : IMXI
# Working on : INBK
# Working on : INCY
# Working on : INDB
# Working on : INFI
# Working on : INFN
# Working on : INFU
# Working on : INGN
# Working on : INGR
# Working on : INN
# Working on : INO
# Working on : INOD
# Working on : INPX
# Working on : INSE
# Working on : INSG
# Working on : INSM
# Working on : INSP
# Working on : INSW
# Working on : INT
# Working on : INTC
# Working on : INTG
# Working on : INTT
# Working on : INTU
# Working on : INUV
# Working on : INVA
# Working on : INVE
# Working on : INVH
# Working on : IO
# Working on : IONS
# Working on : IOR
# Working on : IOSP
# Working on : IOVA
# Working on : IP
# Working on : IPAR
# Working on : IPG
# Working on : IPGP
# Working on : IPI
# Working on : IPWR
# Working on : IQV
# Working on : IR
# Working on : IRBT
# Working on : IRDM
# Working on : IRIX
# Working on : IRM
# Working on : IRMD
# Working on : IROQ
# Working on : IRT
# Working on : IRTC
# Working on : IRWD
# Working on : ISBC
# Working on : ISDR
# Working on : ISIG
# Working on : ISR
# Working on : ISRG
# Working on : ISSC
# Working on : ISTR
# Working on : IT
# Working on : ITCI
# Working on : ITGR
# Working on : ITI
# Working on : ITIC
# Working on : ITRI
# Working on : ITT
# Working on : ITW
# Working on : IVAC
# Working on : IVC
# Working on : IVR
# Working on : IVZ
# Working on : IZEA
# Working on : JACK
# Working on : JAGX
# Working on : JAKK
# Working on : JAZZ
# Working on : JBGS
# Working on : JBHT
# Working on : JBL
# Working on : JBLU
# Working on : JBSS
# Working on : JBT
# Working on : JCI
# Working on : JCS
# Working on : JCTCF
# Working on : JEF
# Working on : JELD
# Working on : JHG
# Working on : JILL
# Working on : JJSF
# Working on : JKHY
# Working on : JLL
# Working on : JNCE
# Working on : JNJ
# Working on : JNPR
# Working on : JOB
# Working on : JOE
# Working on : JOUT
# Working on : JPM
# Working on : JRVR
# Working on : JVA
# Working on : JWN
# Working on : JYNT
# Working on : K
# Working on : KAI
# Working on : KALA
# Working on : KALU
# Working on : KALV
# Working on : KAMN
# Working on : KAR
# Working on : KBAL
# Working on : KBH
# Working on : KBR
# Working on : KDP
# Working on : KE
# Working on : KELYA
# Working on : KEQU
# Working on : KEX
# Working on : KEY
# Working on : KEYS
# Working on : KFFB
# Working on : KFRC
# Working on : KFY
# Working on : KHC
# Working on : KIDS
# Working on : KIM
# Working on : KINS
# Working on : KIRK
# Working on : KKR
# Working on : KLAC
# Working on : KLIC
# Working on : KLXE
# Working on : KMB
# Working on : KMI
# Working on : KMPH
# Working on : KMPR
# Working on : KMT
# Working on : KMX
# Working on : KN
# Working on : KNSA
# Working on : KNSL
# Working on : KNX
# Working on : KO
# Working on : KOD
# Working on : KODK
# Working on : KOP
# Working on : KOPN
# Working on : KOS
# Working on : KPTI
# Working on : KR
# Working on : KRC
# Working on : KREF
# Working on : KRG
# Working on : KRNY
# Working on : KRO
# Working on : KRYS
# Working on : KSS
# Working on : KTCC
# Working on : KTOS
# Working on : KURA
# Working on : KVHI
# Working on : KW
# Working on : KWR
# Working on : KZR
# Working on : L
# Working on : LAD
# Working on : LADR
# Working on : LAKE
# Working on : LAMR
# Working on : LANC
# Working on : LAND
# Working on : LARK
# Working on : LASR
# Working on : LAUR
# Working on : LAWS
# Working on : LAZ
# Working on : LBAI
# Working on : LBC
# Working on : LBRDA
# Working on : LBRDK
# Working on : LBRT
# Working on : LBTYA
# Working on : LBTYK
# Working on : LC
# Working on : LCI
# Working on : LCII
# Working on : LCNB
# Working on : LCUT
# Working on : LDOS
# Working on : LE
# Working on : LEA
# Working on : LECO
# Working on : LEE
# Working on : LEG
# Working on : LEGH
# Working on : LEN
# Working on : LEU
# Working on : LEVI
# Working on : LFUS
# Working on : LFVN
# Working on : LGIH
# Working on : LGL
# Working on : LGND
# Working on : LH
# Working on : LHCG
# Working on : LIFE
# Working on : LII
# Working on : LILA
# Working on : LILAK
# Working on : LIN
# Working on : LINC
# Working on : LIND
# Working on : LIQT
# Working on : LITE
# Working on : LIVE
# Working on : LIVN
# Working on : LJPC
# Working on : LKFN
# Working on : LKQ
# Working on : LL
# Working on : LLNW
# Working on : LLY
# Working on : LMAT
# Working on : LMFA
# Working on : LMNR
# Working on : LMT
# Working on : LNC
# Working on : LNDC
# Working on : LNG
# Working on : LNN
# Working on : LNT
# Working on : LNTH
# Working on : LOAN
# Working on : LOB
# Working on : LOCO
# Working on : LODE
# Working on : LOOP
# Working on : LOPE
# Working on : LOVE
# Working on : LOW
# Working on : LPCN
# Working on : LPG
# Working on : LPI
# Working on : LPLA
# Working on : LPSN
# Working on : LPTH
# Working on : LPX
# Working on : LQDA
# Working on : LQDT
# Working on : LRCX
# Working on : LRN
# Working on : LSBK
# Working on : LSCC
# Working on : LSI
# Working on : LSTR
# Working on : LSXMA
# Working on : LSXMK
# Working on : LTBR
# Working on : LTC
# Working on : LTHM
# Working on : LTRPA
# Working on : LTRX
# Working on : LUB
# Working on : LULU
# Working on : LUNA
# Working on : LUV
# Working on : LVS
# Working on : LW
# Working on : LWAY
# Working on : LXP
# Working on : LXRX
# Working on : LXU
# Working on : LYB
# Working on : LYFT
# Working on : LYTS
# Working on : LYV
# Working on : LZB
# Working on : M
# Working on : MA
# Working on : MAA
# Working on : MAC
# Working on : MACK
# Working on : MAN
# Working on : MANH
# Working on : MANT
# Working on : MAR
# Working on : MARA
# Working on : MARK
# Working on : MAS
# Working on : MASI
# Working on : MAT
# Working on : MATW
# Working on : MATX
# Working on : MAYS
# Working on : MBCN
# Working on : MBI
# Working on : MBII
# Working on : MBIN
# Working on : MBIO
# Working on : MBOT
# Working on : MBUU
# Working on : MBWM
# Working on : MC
# Working on : MCB
# Working on : MCBC
# Working on : MCD
# Working on : MCFT
# Working on : MCHP
# Working on : MCHX
# Working on : MCK
# Working on : MCO
# Working on : MCRB
# Working on : MCRI
# Working on : MCS
# Working on : MCY
# Working on : MD
# Working on : MDB
# Working on : MDC
# Working on : MDGL
# Working on : MDLZ
# Working on : MDRX
# Working on : MDT
# Working on : MDU
# Working on : MED
# Working on : MEDP
# Working on : MEI
# Working on : MEIP
# Working on : MERC
# Working on : MESA
# Working on : MET
# Working on : MFA
# Working on : MG
# Working on : MGEE
# Working on : MGI
# Working on : MGM
# Working on : MGNX
# Working on : MGPI
# Working on : MGRC
# Working on : MGTA
# Working on : MGY
# Working on : MGYR
# Working on : MHH
# Working on : MHK
# Working on : MHLD
# Working on : MHO
# Working on : MIC
# Working on : MICR
# Working on : MICT
# Working on : MIDD
# Working on : MIND
# Working on : MITK
# Working on : MITT
# Working on : MKC
# Working on : MKL
# Working on : MKSI
# Working on : MKTX
# Working on : MLAB
# Working on : MLI
# Working on : MLM
# Working on : MLP
# Working on : MLR
# Working on : MLSS
# Working on : MLVF
# Working on : MMC
# Working on : MMI
# Working on : MMM
# Working on : MMS
# Working on : MMSI
# Working on : MN
# Working on : MNKD
# Working on : MNOV
# Working on : MNRL
# Working on : MNRO
# Working on : MNST
# Working on : MNTX
# Working on : MO
# Working on : MOBL
# Working on : MOD
# Working on : MODN
# Working on : MOFG
# Working on : MOH
# Working on : MORN
# Working on : MOS
# Working on : MOTS
# Working on : MOV
# Working on : MPAA
# Working on : MPB
# Working on : MPC
# Working on : MPW
# Working on : MPWR
# Working on : MPX
# Working on : MRAM
# Working on : MRC
# Working on : MRCY
# Working on : MRIN
# Working on : MRK
# Working on : MRKR
# Working on : MRNS
# Working on : MRO
# Working on : MRSN
# Working on : MRTN
# Working on : MRTX
# Working on : MRVL
# Working on : MS
# Working on : MSA
# Working on : MSBI
# Working on : MSCI
# Working on : MSEX
# Working on : MSFT
# Working on : MSI
# Working on : MSM
# Working on : MSN
# Working on : MSTR
# Working on : MTB
# Working on : MTCH
# Working on : MTD
# Working on : MTDR
# Working on : MTEM
# Working on : MTEX
# Working on : MTG
# Working on : MTH
# Working on : MTN
# Working on : MTNB
# Working on : MTOR
# Working on : MTRN
# Working on : MTRX
# Working on : MTSI
# Working on : MTW
# Working on : MTX
# Working on : MTZ
# Working on : MU
# Working on : MUR
# Working on : MUSA
# Working on : MUX
# Working on : MVBF
# Working on : MVIS
# Working on : MWA
# Working on : MXL
# Working on : MYE
# Working on : MYGN
# Working on : MYRG
# Working on : NAII
# Working on : NATH
# Working on : NATI
# Working on : NATR
# Working on : NAVB
# Working on : NAVI
# Working on : NBHC
# Working on : NBIX
# Working on : NBN
# Working on : NBR
# Working on : NBTB
# Working on : NBY
# Working on : NC
# Working on : NCBS
# Working on : NCLH
# Working on : NCMI
# Working on : NCR
# Working on : NCSM
# Working on : NDAQ
# Working on : NDLS
# Working on : NDSN
# Working on : NEE
# Working on : NEM
# Working on : NEO
# Working on : NEOG
# Working on : NEON
# Working on : NERV
# Working on : NEU
# Working on : NEWR
# Working on : NFBK
# Working on : NFG
# Working on : NFLX
# Working on : NGS
# Working on : NGVC
# Working on : NGVT
# Working on : NHC
# Working on : NHI
# Working on : NHTC
# Working on : NI
# Working on : NICK
# Working on : NINE
# Working on : NJR
# Working on : NKE
# Working on : NKSH
# Working on : NKTR
# Working on : NL
# Working on : NLS
# Working on : NLSN
# Working on : NLY
# Working on : NMIH
# Working on : NMRK
# Working on : NNBR
# Working on : NNI
# Working on : NNN
# Working on : NNVC
# Working on : NOC
# Working on : NODK
# Working on : NOG
# Working on : NOV
# Working on : NOVT
# Working on : NOW
# Working on : NP
# Working on : NPK
# Working on : NPO
# Working on : NPTN
# Working on : NR
# Working on : NRC
# Working on : NRG
# Working on : NRIM
# Working on : NRZ
# Working on : NSA
# Working on : NSC
# Working on : NSEC
# Working on : NSIT
# Working on : NSP
# Working on : NSSC
# Working on : NSTG
# Working on : NTAP
# Working on : NTCT
# Working on : NTGR
# Working on : NTIC
# Working on : NTIP
# Working on : NTLA
# Working on : NTNX
# Working on : NTRA
# Working on : NTRS
# Working on : NTWK
# Working on : NUAN
# Working on : NUE
# Working on : NURO
# Working on : NUS
# Working on : NUVA
# Working on : NVAX
# Working on : NVDA
# Working on : NVEC
# Working on : NVEE
# Working on : NVFY
# Working on : NVIV
# Working on : NVR
# Working on : NVRO
# Working on : NVT
# Working on : NVTA
# Working on : NWBI
# Working on : NWE
# Working on : NWFL
# Working on : NWL
# Working on : NWLI
# Working on : NWN
# Working on : NWPX
# Working on : NWS
# Working on : NWSA
# Working on : NX
# Working on : NXGN
# Working on : NXRT
# Working on : NXST
# Working on : NYCB
# Working on : NYMT
# Working on : NYT
# Working on : O
# Working on : OAS
# Working on : OBCI
# Working on : OBNK
# Working on : OC
# Working on : OCC
# Working on : OCFC
# Working on : OCN
# Working on : OCUL
# Working on : OCX
# Working on : ODC
# Working on : ODFL
# Working on : ODP
# Working on : OESX
# Working on : OFC
# Working on : OFED
# Working on : OFG
# Working on : OFIX
# Working on : OFLX
# Working on : OGE
# Working on : OGEN
# Working on : OGS
# Working on : OHI
# Working on : OI
# Working on : OII
# Working on : OIS
# Working on : OKE
# Working on : OKTA
# Working on : OLED
# Working on : OLLI
# Working on : OLP
# Working on : OMC
# Working on : OMCL
# Working on : OMER
# Working on : OMEX
# Working on : OMF
# Working on : OMI
# Working on : ON
# Working on : ONB
# Working on : ONCS
# Working on : ONTX
# Working on : ONVO
# Working on : OOMA
# Working on : OPGN
# Working on : OPI
# Working on : OPK
# Working on : OPOF
# Working on : OPRX
# Working on : OPTN
# Working on : OPTT
# Working on : OPY
# Working on : ORA
# Working on : ORC
# Working on : ORCL
# Working on : ORGO
# Working on : ORI
# Working on : ORLY
# Working on : ORN
# Working on : ORRF
# Working on : OSBC
# Working on : OSG
# Working on : OSIS
# Working on : OSK
# Working on : OSPN
# Working on : OSTK
# Working on : OSUR
# Working on : OTIC
# Working on : OTTR
# Working on : OUT
# Working on : OVBC
# Working on : OVLY
# Working on : OXM
# Working on : OXY
# Working on : OZK
# Working on : PACB
# Working on : PACW
# Working on : PAG
# Working on : PAHC
# Working on : PANL
# Working on : PANW
# Working on : PAR
# Working on : PARR
# Working on : PATI
# Working on : PATK
# Working on : PAYC
# Working on : PAYX
# Working on : PB
# Working on : PBF
# Working on : PBH
# Working on : PBHC
# Working on : PBI
# Working on : PBIP
# Working on : PBPB
# Working on : PBYI
# Working on : PCAR
# Working on : PCH
# Working on : PCRX
# Working on : PCSB
# Working on : PCTI
# Working on : PCTY
# Working on : PCYG
# Working on : PCYO
# Working on : PD
# Working on : PDCE
# Working on : PDCO
# Working on : PDEX
# Working on : PDFS
# Working on : PDLB
# Working on : PDM
# Working on : PEB
# Working on : PEBK
# Working on : PEBO
# Working on : PED
# Working on : PEG
# Working on : PEGA
# Working on : PEI
# Working on : PEN
# Working on : PENN
# Working on : PEP
# Working on : PESI
# Working on : PETQ
# Working on : PETS
# Working on : PFBC
# Working on : PFE
# Working on : PFG
# Working on : PFGC
# Working on : PFIE
# Working on : PFIN
# Working on : PFIS
# Working on : PFMT
# Working on : PFS
# Working on : PFSW
# Working on : PGC
# Working on : PGR
# Working on : PGRE
# Working on : PGTI
# Working on : PH
# Working on : PHAS
# Working on : PHIO
# Working on : PHM
# Working on : PHX
# Working on : PI
# Working on : PII
# Working on : PINC
# Working on : PINS
# Working on : PJT
# Working on : PK
# Working on : PKBK
# Working on : PKG
# Working on : PKI
# Working on : PKOH
# Working on : PLAB
# Working on : PLAN
# Working on : PLAY
# Working on : PLBC
# Working on : PLCE
# Working on : PLD
# Working on : PLNT
# Working on : PLOW
# Working on : PLPC
# Working on : PLSE
# Working on : PLUS
# Working on : PLYA
# Working on : PLYM
# Working on : PM
# Working on : PMD
# Working on : PMT
# Working on : PMTS
# Working on : PNBK
# Working on : PNC
# Working on : PNFP
# Working on : PNM
# Working on : PNR
# Working on : PNRG
# Working on : PNW
# Working on : PODD
# Working on : POOL
# Working on : POR
# Working on : POST
# Working on : POWI
# Working on : POWL
# Working on : PPBI
# Working on : PPC
# Working on : PPG
# Working on : PPIH
# Working on : PPL
# Working on : PPSI
# Working on : PRA
# Working on : PRAA
# Working on : PRFT
# Working on : PRGO
# Working on : PRGS
# Working on : PRI
# Working on : PRIM
# Working on : PRK
# Working on : PRLB
# Working on : PRMW
# Working on : PRO
# Working on : PROV
# Working on : PRPH
# Working on : PRTA
# Working on : PRTK
# Working on : PRTS
# Working on : PRTY
# Working on : PRU
# Working on : PRVB
# Working on : PSA
# Working on : PSB
# Working on : PSMT
# Working on : PSN
# Working on : PSTG
# Working on : PSX
# Working on : PTC
# Working on : PTCT
# Working on : PTE
# Working on : PTEN
# Working on : PTGX
# Working on : PTN
# Working on : PTSI
# Working on : PULM
# Working on : PUMP
# Working on : PVBC
# Working on : PVH
# Working on : PW
# Working on : PWOD
# Working on : PWR
# Working on : PXD
# Working on : PXLW
# Working on : PYPL
# Working on : PZG
# Working on : PZN
# Working on : PZZA
# Working on : QCOM
# Working on : QCRH
# Working on : QDEL
# Working on : QLYS
# Working on : QNST
# Working on : QRHC
# Working on : QRTEA
# Working on : QRVO
# Working on : QTRX
# Working on : QTWO
# Working on : QUAD
# Working on : QUIK
# Working on : QUMU
# Working on : QUOT
# Working on : R
# Working on : RAD
# Working on : RAIL
# Working on : RAMP
# Working on : RARE
# Working on : RAVE
# Working on : RBB
# Working on : RBBN
# Working on : RBCAA
# Working on : RBCN
# Working on : RC
# Working on : RCII
# Working on : RCKY
# Working on : RCL
# Working on : RCM
# Working on : RCMT
# Working on : RCUS
# Working on : RDFN
# Working on : RDI
# Working on : RDN
# Working on : RDNT
# Working on : RDUS
# Working on : RDVT
# Working on : RE
# Working on : REED
# Working on : REFR
# Working on : REG
# Working on : REGI
# Working on : REGN
# Working on : REI
# Working on : RELL
# Working on : RELV
# Working on : REPH
# Working on : REPL
# Working on : RES
# Working on : RESN
# Working on : RETA
# Working on : REV
# Working on : REVG
# Working on : REX
# Working on : REXR
# Working on : REZI
# Working on : RF
# Working on : RFIL
# Working on : RFL
# Working on : RFP
# Working on : RGA
# Working on : RGCO
# Working on : RGEN
# Working on : RGLD
# Working on : RGLS
# Working on : RGNX
# Working on : RGR
# Working on : RGS
# Working on : RH
# Working on : RHE
# Working on : RHI
# Working on : RHP
# Working on : RIBT
# Working on : RICK
# Working on : RIG
# Working on : RIGL
# Working on : RILY
# Working on : RIOT
# Working on : RJF
# Working on : RKDA
# Working on : RL
# Working on : RLGT
# Working on : RLGY
# Working on : RLI
# Working on : RLJ
# Working on : RM
# Working on : RMAX
# Working on : RMBS
# Working on : RMCF
# Working on : RMD
# Working on : RMR
# Working on : RMTI
# Working on : RNDB
# Working on : RNG
# Working on : RNR
# Working on : RNST
# Working on : RNWK
# Working on : ROCK
# Working on : ROG
# Working on : ROIC
# Working on : ROK
# Working on : ROKU
# Working on : ROL
# Working on : ROLL
# Working on : ROP
# Working on : ROST
# Working on : RPD
# Working on : RPM
# Working on : RPT
# Working on : RRC
# Working on : RRGB
# Working on : RRR
# Working on : RRTS
# Working on : RS
# Working on : RSG
# Working on : RUBY
# Working on : RUN
# Working on : RUSHA
# Working on : RUSHB
# Working on : RUTH
# Working on : RVI
# Working on : RVNC
# Working on : RVP
# Working on : RVSB
# Working on : RWT
# Working on : RYAM
# Working on : RYI
# Working on : RYN
# Working on : RYTM
# Working on : SABR
# Working on : SACH
# Working on : SAFE
# Working on : SAFM
# Working on : SAFT
# Working on : SAGE
# Working on : SAH
# Working on : SAIA
# Working on : SAIC
# Working on : SAIL
# Working on : SAL
# Working on : SALM
# Working on : SAM
# Working on : SAMG
# Working on : SANM
# Working on : SANW
# Working on : SASR
# Working on : SATS
# Working on : SAVE
# Working on : SBAC
# Working on : SBCF
# Working on : SBFG
# Working on : SBGI
# Working on : SBH
# Working on : SBNY
# Working on : SBOW
# Working on : SBRA
# Working on : SBSI
# Working on : SBT
# Working on : SBUX
# Working on : SCHL
# Working on : SCHN
# Working on : SCHW
# Working on : SCI
# Working on : SCL
# Working on : SCOR
# Working on : SCPL
# Working on : SCS
# Working on : SCSC
# Working on : SCVL
# Working on : SCWX
# Working on : SCX
# Working on : SCYX
# Working on : SD
# Working on : SDPI
# Working on : SEAC
# Working on : SEAS
# Working on : SEB
# Working on : SEE
# Working on : SEIC
# Working on : SELB
# Working on : SELF
# Working on : SEM
# Working on : SENEA
# Working on : SENEB
# Working on : SESN
# Working on : SF
# Working on : SFBC
# Working on : SFBS
# Working on : SFE
# Working on : SFIX
# Working on : SFM
# Working on : SFNC
# Working on : SFST
# Working on : SGA
# Working on : SGC
# Working on : SGEN
# Working on : SGH
# Working on : SGMA
# Working on : SGMO
# Working on : SGRP
# Working on : SGRY
# Working on : SHAK
# Working on : SHBI
# Working on : SHEN
# Working on : SHO
# Working on : SHOO
# Working on : SHW
# Working on : SIBN
# Working on : SIEB
# Working on : SIEN
# Working on : SIF
# Working on : SIG
# Working on : SIGA
# Working on : SIGI
# Working on : SILK
# Working on : SINT
# Working on : SIRI
# Working on : SITC
# Working on : SITE
# Working on : SIVB
# Working on : SIX
# Working on : SJI
# Working on : SJM
# Working on : SJW
# Working on : SKT
# Working on : SKX
# Working on : SKY
# Working on : SKYW
# Working on : SLAB
# Working on : SLB
# Working on : SLCA
# Working on : SLDB
# Working on : SLG
# Working on : SLGN
# Working on : SLM
# Working on : SLNO
# Working on : SLP
# Working on : SLS
# Working on : SM
# Working on : SMAR
# Working on : SMBC
# Working on : SMBK
# Working on : SMED
# Working on : SMG
# Working on : SMIT
# Working on : SMMF
# Working on : SMP
# Working on : SMPL
# Working on : SMSI
# Working on : SMTC
# Working on : SNA
# Working on : SNAP
# Working on : SNBR
# Working on : SNCR
# Working on : SND
# Working on : SNDR
# Working on : SNDX
# Working on : SNFCA
# Working on : SNOA
# Working on : SNPS
# Working on : SNV
# Working on : SNX
# Working on : SO
# Working on : SOHO
# Working on : SOI
# Working on : SON
# Working on : SONO
# Working on : SP
# Working on : SPB
# Working on : SPG
# Working on : SPGI
# Working on : SPLK
# Working on : SPOK
# Working on : SPPI
# Working on : SPR
# Working on : SPRO
# Working on : SPSC
# Working on : SPTN
# Working on : SPWH
# Working on : SPWR
# Working on : SPXC
# Working on : SQ
# Working on : SR
# Working on : SRC
# Working on : SRCE
# Working on : SRCL
# Working on : SRDX
# Working on : SRE
# Working on : SREV
# Working on : SRG
# Working on : SRI
# Working on : SRNE
# Working on : SRPT
# Working on : SRRK
# Working on : SRT
# Working on : SRTS
# Working on : SSB
# Working on : SSBI
# Working on : SSD
# Working on : SSKN
# Working on : SSNC
# Working on : SSP
# Working on : SSTI
# Working on : SSTK
# Working on : ST
# Working on : STAA
# Working on : STAG
# Working on : STAR
# Working on : STBA
# Working on : STC
# Working on : STCN
# Working on : STE
# Working on : STIM
# Working on : STKS
# Working on : STLD
# Working on : STOR
# Working on : STRA
# Working on : STRL
# Working on : STRM
# Working on : STRS
# Working on : STRT
# Working on : STT
# Working on : STWD
# Working on : STX
# Working on : STXB
# Working on : STZ
# Working on : SUI
# Working on : SUM
# Working on : SUMR
# Working on : SUNW
# Working on : SUP
# Working on : SUPN
# Working on : SVRA
# Working on : SVT
# Working on : SWAV
# Working on : SWCH
# Working on : SWK
# Working on : SWKS
# Working on : SWM
# Working on : SWN
# Working on : SWX
# Working on : SXC
# Working on : SXI
# Working on : SXT
# Working on : SYBT
# Working on : SYBX
# Working on : SYF
# Working on : SYK
# Working on : SYN
# Working on : SYNA
# Working on : SYNH
# Working on : SYNL
# Working on : SYPR
# Working on : SYRS
# Working on : SYY
# Working on : T
# Working on : TACO
# Working on : TACT
# Working on : TAIT
# Working on : TALO
# Working on : TAP
# Working on : TAST
# Working on : TAYD
# Working on : TBBK
# Working on : TBI
# Working on : TBK
# Working on : TBNK
# Working on : TBPH
# Working on : TCBI
# Working on : TCBK
# Working on : TCDA
# Working on : TCFC
# Working on : TCI
# Working on : TCMD
# Working on : TCON
# Working on : TCS
# Working on : TDC
# Working on : TDG
# Working on : TDOC
# Working on : TDS
# Working on : TDW
# Working on : TDY
# Working on : TEL
# Working on : TELL
# Working on : TEN
# Working on : TENB
# Working on : TENX
# Working on : TER
# Working on : TESS
# Working on : TEUM
# Working on : TEX
# Working on : TFSL
# Working on : TFX
# Working on : TG
# Working on : TGEN
# Working on : TGI
# Working on : TGLS
# Working on : TGNA
# Working on : TGT
# Working on : TGTX
# Working on : THC
# Working on : THFF
# Working on : THG
# Working on : THO
# Working on : THR
# Working on : THRM
# Working on : THS
# Working on : TILE
# Working on : TIPT
# Working on : TISI
# Working on : TITN
# Working on : TJX
# Working on : TKR
# Working on : TLYS
# Working on : TMDX
# Working on : TMHC
# Working on : TMO
# Working on : TMP
# Working on : TMST
# Working on : TMUS
# Working on : TNC
# Working on : TNDM
# Working on : TNET
# Working on : TNXP
# Working on : TOL
# Working on : TOWN
# Working on : TPB
# Working on : TPC
# Working on : TPH
# Working on : TPHS
# Working on : TPIC
# Working on : TPR
# Working on : TPTX
# Working on : TPX
# Working on : TR
# Working on : TRC
# Working on : TREC
# Working on : TREE
# Working on : TREX
# Working on : TRGP
# Working on : TRHC
# Working on : TRIP
# Working on : TRMB
# Working on : TRMK
# Working on : TRN
# Working on : TRNO
# Working on : TRNS
# Working on : TROW
# Working on : TROX
# Working on : TRS
# Working on : TRST
# Working on : TRT
# Working on : TRTN
# Working on : TRTX
# Working on : TRU
# Working on : TRUP
# Working on : TRV
# Working on : TRVN
# Working on : TSBK
# Working on : TSC
# Working on : TSCO
# Working on : TSE
# Working on : TSLA
# Working on : TSN
# Working on : TSQ
# Working on : TTC
# Working on : TTD
# Working on : TTEC
# Working on : TTEK
# Working on : TTGT
# Working on : TTI
# Working on : TTMI
# Working on : TTNP
# Working on : TTOO
# Working on : TUP
# Working on : TUSK
# Working on : TVTY
# Working on : TW
# Working on : TWI
# Working on : TWIN
# Working on : TWLO
# Working on : TWNK
# Working on : TWO
# Working on : TWOU
# Working on : TWST
# Working on : TWTR
# Working on : TXMD
# Working on : TXN
# Working on : TXRH
# Working on : TXT
# Working on : TYL
# Working on : TYME
# Working on : TZOO
# Working on : UA
# Working on : UAA
# Working on : UAL
# Working on : UAMY
# Working on : UBA
# Working on : UBCP
# Working on : UBER
# Working on : UBFO
# Working on : UBOH
# Working on : UBSI
# Working on : UCBI
# Working on : UCTT
# Working on : UDR
# Working on : UE
# Working on : UEC
# Working on : UEIC
# Working on : UFAB
# Working on : UFCS
# Working on : UFI
# Working on : UFPI
# Working on : UFPT
# Working on : UG
# Working on : UGI
# Working on : UHAL
# Working on : UHS
# Working on : UHT
# Working on : UIHC
# Working on : UIS
# Working on : ULBI
# Working on : ULH
# Working on : ULTA
# Working on : UMBF
# Working on : UMH
# Working on : UMPQ
# Working on : UNAM
# Working on : UNB
# Working on : UNF
# Working on : UNFI
# Working on : UNH
# Working on : UNIT
# Working on : UNP
# Working on : UNTY
# Working on : UNVR
# Working on : UONE
# Working on : UONEK
# Working on : UPLD
# Working on : UPS
# Working on : UPWK
# Working on : URBN
# Working on : URI
# Working on : USAK
# Working on : USAP
# Working on : USB
# Working on : USEG
# Working on : USFD
# Working on : USIO
# Working on : USLM
# Working on : USM
# Working on : USNA
# Working on : USPH
# Working on : USWS
# Working on : USX
# Working on : UTHR
# Working on : UTI
# Working on : UTL
# Working on : UTMD
# Working on : UUU
# Working on : UVE
# Working on : UVSP
# Working on : UVV
# Working on : V
# Working on : VAC
# Working on : VALU
# Working on : VAPO
# Working on : VBFC
# Working on : VBIV
# Working on : VBTX
# Working on : VC
# Working on : VCEL
# Working on : VCTR
# Working on : VCYT
# Working on : VEC
# Working on : VECO
# Working on : VEEV
# Working on : VERI
# Working on : VERU
# Working on : VFC
# Working on : VG
# Working on : VGR
# Working on : VHC
# Working on : VIAV
# Working on : VICI
# Working on : VICR
# Working on : VIRC
# Working on : VIRT
# Working on : VISL
# Working on : VIVO
# Working on : VKTX
# Working on : VLGEA
# Working on : VLO
# Working on : VLY
# Working on : VMC
# Working on : VMI
# Working on : VMW
# Working on : VNCE
# Working on : VNDA
# Working on : VNE
# Working on : VNO
# Working on : VNRX
# Working on : VNTR
# Working on : VOXX
# Working on : VOYA
# Working on : VPG
# Working on : VRA
# Working on : VRAY
# Working on : VREX
# Working on : VRNS
# Working on : VRNT
# Working on : VRRM
# Working on : VRS
# Working on : VRSK
# Working on : VRSN
# Working on : VRTS
# Working on : VRTV
# Working on : VRTX
# Working on : VSAT
# Working on : VSEC
# Working on : VSH
# Working on : VST
# Working on : VSTM
# Working on : VSTO
# Working on : VTNR
# Working on : VTR
# Working on : VTVT
# Working on : VUZI
# Working on : VVI
# Working on : VVV
# Working on : VXRT
# Working on : VYGR
# Working on : VZ
# Working on : W
# Working on : WAB
# Working on : WABC
# Working on : WAFD
# Working on : WAL
# Working on : WASH
# Working on : WAT
# Working on : WATT
# Working on : WBA
# Working on : WBS
# Working on : WBT
# Working on : WCC
# Working on : WD
# Working on : WDAY
# Working on : WDC
# Working on : WDFC
# Working on : WEC
# Working on : WELL
# Working on : WEN
# Working on : WERN
# Working on : WETF
# Working on : WEX
# Working on : WEYS
# Working on : WFC
# Working on : WGO
# Working on : WH
# Working on : WHD
# Working on : WHG
# Working on : WHLM
# Working on : WHLR
# Working on : WHR
# Working on : WINA
# Working on : WING
# Working on : WIRE
# Working on : WK
# Working on : WKHS
# Working on : WLDN
# Working on : WLFC
# Working on : WLK
# Working on : WLL
# Working on : WM
# Working on : WMB
# Working on : WMC
# Working on : WMK
# Working on : WMS
# Working on : WMT
# Working on : WNC
# Working on : WNEB
# Working on : WOR
# Working on : WOW
# Working on : WPC
# Working on : WRB
# Working on : WRE
# Working on : WRK
# Working on : WRLD
# Working on : WSBC
# Working on : WSBF
# Working on : WSC
# Working on : WSFS
# Working on : WSM
# Working on : WSO
# Working on : WSR
# Working on : WST
# Working on : WSTG
# Working on : WSTL
# Working on : WTBA
# Working on : WTFC
# Working on : WTI
# Working on : WTM
# Working on : WTRH
# Working on : WTS
# Working on : WTT
# Working on : WTTR
# Working on : WU
# Working on : WVE
# Working on : WVFC
# Working on : WVVI
# Working on : WW
# Working on : WWD
# Working on : WWE
# Working on : WWR
# Working on : WWW
# Working on : WY
# Working on : WYNN
# Working on : WYY
# Working on : X
# Working on : XBIT
# Working on : XEL
# Working on : XELA
# Working on : XELB
# Working on : XENT
# Working on : XERS
# Working on : XFOR
# Working on : XHR
# Working on : XNCR
# Working on : XOM
# Working on : XOMA
# Working on : XPER
# Working on : XPL
# Working on : XPO
# Working on : XRAY
# Working on : XRX
# Working on : XSPA
# Working on : XTNT
# Working on : XXII
# Working on : XYL
# Working on : Y
# Working on : YELP
# Working on : YETI
# Working on : YEXT
# Working on : YMAB
# Working on : YORW
# Working on : YTEN
# Working on : YUM
# Working on : Z
# Working on : ZBH
# Working on : ZBRA
# Working on : ZDGE
# Working on : ZEN
# Working on : ZEUS
# Working on : ZG
# Working on : ZION
# Working on : ZM
# Working on : ZNGA
# Working on : ZS
# Working on : ZSAN
# Working on : ZTS
# Working on : ZUMZ
# Working on : ZUO
# Working on : ZVO
# Working on : ZYNE
# Working on : ZYXI

# %% [markdown]
# #### Regression Time Series Example with AutoReg

# %%
def calc_projected_roi(ticker):
    a_df = get_df_from_csv(PATH, ticker)

    a_df = a_df.asfreq('d') # Change frequency to day
    a_df.index # Check frequency
    a_df = a_df.fillna(method='ffill') # Fill missing values

    # Delete unnamed column
    a_df.drop(a_df.columns[a_df.columns.str.contains('unnamed',case = False)],
          axis = 1, inplace = True)

    # Delete daily return column
    a_df = a_df.drop(['daily_return'], axis=1)
    
    # Figure out optimum lags which will be 1 or 2 for this data set
    lags = ar_select_order(a_df, maxlag=30)

    # Create our model using whole data set
    model = AutoReg(a_df['Adj Close'], lags.ar_lags)
    model_fit = model.fit()

    # Define training and testing area
    print("Length :",len(a_df)) # 1712 observations
    train_df = a_df.iloc[50:1369] # 80% minus 1st 50
    test_df = a_df.iloc[1369:] # Last 20%

    # Define training model for 500 days (Play with Number & Test)
    # and White's covariance estimator
    train_model = AutoReg(a_df['Adj Close'], 500).fit(cov_type="HC0")

    # Define start and end for prediction 
    start = len(train_df)
    end = len(train_df) + len(test_df) - 1

    prediction = train_model.predict(start=start, end=end, dynamic=True)

    # Predict 160 days into the future
    forecast = train_model.predict(start=end, end=end+60, dynamic=True)

    # Get starting price of prediction
    s_price = forecast.head(1).iloc[0]

    # Get the last price of prediction
    e_price = forecast.iloc[-1]

    # Get return over prediction
    return (e_price - s_price) / s_price

# %%
def get_proj_rois():
    # Will hold all tickers & stock rois
    ticker = []
    roi = []
    
    for x in tickers:
        print("Working on :", x)
        try:
            the_roi = calc_projected_roi(x)
        except Exception as ex:
            print("Stock Data Corrupted")
        else:
            ticker.append(x)
            print("ROI :", the_roi)
            roi.append(the_roi)
        
    return pd.DataFrame({'Ticker':ticker, 'ROI':roi})

# %%
proj_roi_df = get_proj_rois()
proj_roi_df
# Out:
# Working on : A
# Length : 1844
# ROI : 0.0014719060540988537
# Working on : AA
# Length : 1844
# ROI : 0.2244323565492685
# Working on : AAL
# Length : 1844
# ROI : -0.0895123979456121
# Working on : AAME
# Length : 1844
# ROI : 0.08079313955372754
# Working on : AAN
# Length : 422
# Stock Data Corrupted
# Working on : AAOI
# Length : 1844
# ROI : 0.12549090505442947
# Working on : AAON
# Length : 1844
# ROI : -0.041188320690333034
# Working on : AAP
# Length : 1844
# ROI : 0.07137203179693329
# Working on : AAPL
# Length : 1844
# ROI : 0.017092336509055287
# Working on : AAT
# Length : 1844
# ROI : 0.0016008331128929644
# Working on : AAWW
# Length : 1844
# ROI : -0.07963099630136374
# Working on : ABBV
# Length : 1844
# ROI : 0.07331862951781039
# Working on : ABC
# Length : 1844
# ROI : 0.08091427735465376
# Working on : ABCB
# Length : 1844
# ROI : -0.04957523061712313
# Working on : ABEO
# Length : 1844
# ROI : 0.95589255052128
# Working on : ABG
# Length : 1844
# ROI : -0.00917199689964277
# Working on : ABIO
# Length : 1844
# ROI : 0.1661257519165706
# Working on : ABM
# Length : 1844
# ROI : -0.07230135688901668
# Working on : ABMD
# Length : 1844
# ROI : -0.20231615501476655
# Working on : ABR
# Length : 1844
# ROI : -0.06134411095092473
# Working on : ABT
# Length : 1844
# ROI : 0.049345094667148016
# Working on : ABTX
# Length : 1844
# ROI : 0.0357348258846513
# Working on : AC
# Length : 1844
# ROI : -0.04519446647222567
# Working on : ACA
# Length : 1173
# Stock Data Corrupted
# Working on : ACAD
# Length : 1844
# ROI : 0.09551446548048921
# Working on : ACBI
# Length : 1844
# ROI : -0.01905494299438546
# Working on : ACC
# Length : 1844
# ROI : -0.06278879483188164
# Working on : ACCO
# Length : 1844
# ROI : -0.2105749134194969
# Working on : ACER
# Length : 1844
# ROI : 0.17250182267843137
# Working on : ACGL
# Length : 1844
# ROI : -0.02244746353438162
# Working on : ACHC
# Length : 1844
# ROI : -0.058282029235193406
# Working on : ACHV
# Length : 1844
# ROI : 0.5392353366208573
# Working on : ACIW
# Length : 1844
# ROI : -0.007895566941178638
# Working on : ACLS
# Length : 1844
# ROI : -0.02774048819106151
# Working on : ACM
# Length : 1844
# ROI : 0.08759509557772426
# Working on : ACMR
# Length : 1541
# ROI : 0.021567481399524215
# Working on : ACN
# Length : 1844
# ROI : 0.028186279720907658
# Working on : ACNB
# Length : 1844
# ROI : 0.17050622960365153
# Working on : ACOR
# Length : 1844
# ROI : -1.2851113710751108
# Working on : ACRE
# Length : 1844
# ROI : -0.1768336815142658
# Working on : ACRS
# Length : 1844
# ROI : -0.2577801399939669
# Working on : ACRX
# Length : 1844
# ROI : -0.5124655948871872
# Working on : ACTG
# Length : 1844
# ROI : -0.09016090606142557
# Working on : ACU
# Length : 1844
# ROI : -0.04462499922912619
# Working on : ADBE
# Length : 1844
# ROI : -0.11483645415912157
# Working on : ADC
# Length : 1844
# ROI : 0.039380092785990625
# Working on : ADES
# Length : 1844
# ROI : -0.0752452914360658
# Working on : ADI
# Length : 1844
# ROI : -0.005873028628323043
# Working on : ADM
# Length : 1844
# ROI : 0.06814776825319992
# Working on : ADMA
# Length : 1844
# ROI : -0.15446975190452947
# Working on : ADMP
# Length : 1844
# ROI : 0.06771739734376046
# Working on : ADNT
# Length : 1844
# ROI : 0.0015081855837961802
# Working on : ADP
# Length : 1844
# ROI : -0.052044815338248396
# Working on : ADSK
# Length : 1844
# ROI : 0.08273381381167141
# Working on : ADT
# Length : 1463
# ROI : -0.11377285403199104
# Working on : ADTN
# Length : 1844
# ROI : 0.012940482842554814
# Working on : ADUS
# Length : 1844
# ROI : 0.1596353323721566
# Working on : ADVM
# Length : 1844
# ROI : -1.2174684081674176
# Working on : ADXS
# Length : 1844
# ROI : 0.3409282867489682
# Working on : AE
# Length : 1844
# ROI : 0.2364266167204939
# Working on : AEE
# Length : 1844
# ROI : 0.0733935216180743
# Working on : AEHR
# Length : 1844
# ROI : -0.04655062699953346
# Working on : AEIS
# Length : 1844
# ROI : -0.03638202909940619
# Working on : AEL
# Length : 1844
# ROI : 0.08237288472600492
# Working on : AEMD
# Length : 1844
# ROI : -0.39639300150307777
# Working on : AEO
# Length : 1844
# ROI : -0.15423059277958068
# Working on : AEP
# Length : 1844
# ROI : 0.11213889297762937
# Working on : AERI
# Length : 1844
# ROI : 0.0028174412745208912
# Working on : AES
# Length : 1844
# ROI : 0.013146954538174634
# Working on : AEY
# Length : 1844
# ROI : -0.1429994373429216
# Working on : AFG
# Length : 1844
# ROI : -0.07066831877855888
# Working on : AFI
# Length : 1844
# ROI : -0.6791628701450421
# Working on : AFL
# Length : 1844
# ROI : -0.0572030752296419
# Working on : AGCO
# Length : 1844
# ROI : 0.06870572129967577
# Working on : AGE
# Length : 1149
# Stock Data Corrupted
# Working on : AGEN
# Length : 1844
# ROI : -0.07905259432075377
# Working on : AGFS
# Length : 1844
# ROI : 0.12756924250733456
# Working on : AGIO
# Length : 1844
# ROI : 0.10752769964089996
# Working on : AGLE
# Length : 1844
# ROI : 0.1877378944048586
# Working on : AGM
# Length : 1844
# ROI : 0.08157735691148069
# Working on : AGNC
# Length : 1844
# ROI : -0.06821847220728783
# Working on : AGO
# Length : 1844
# ROI : 0.003400229443120445
# Working on : AGR
# Length : 1844
# ROI : -0.026755691634407587
# Working on : AGRX
# Length : 1844
# ROI : 0.5245377622222849
# Working on : AGS
# Length : 1456
# ROI : 0.044293869441248315
# Working on : AGTC
# Length : 1844
# ROI : 0.4871476428053241
# Working on : AGX
# Length : 1844
# ROI : -0.04827967757938842
# Working on : AGYS
# Length : 1844
# ROI : -0.09268470764697037
# Working on : AHH
# Length : 1844
# ROI : -0.034601503464631506
# Working on : AHT
# Length : 1844
# ROI : -0.96243304949864
# Working on : AIG
# Length : 1844
# ROI : -0.0003124943541980647
# Working on : AIMC
# Length : 1844
# ROI : -0.214386928832816
# Working on : AIN
# Length : 1844
# ROI : -0.11487435582458054
# Working on : AINC
# Length : 1844
# ROI : 0.12608178862380734
# Working on : AIR
# Length : 1844
# ROI : 0.21722175484313322
# Working on : AIRG
# Length : 1844
# ROI : -0.2377152841477594
# Working on : AIRI
# Length : 1844
# ROI : 0.17812596868891842
# Working on : AIRT
# Length : 1844
# ROI : 0.4700065787247383
# Working on : AIT
# Length : 1844
# ROI : -0.07880512924690851
# Working on : AIV
# Length : 1844
# ROI : -0.18215445562984506
# Working on : AIZ
# Length : 1844
# ROI : 0.0057386251230434
# Working on : AJG
# Length : 1844
# ROI : -0.026058183991308978
# Working on : AJRD
# Length : 1844
# ROI : 0.04925159870294075
# Working on : AJX
# Length : 1844
# ROI : -0.11798335996828128
# Working on : AKAM
# Length : 1844
# ROI : 0.009124766386092692
# Working on : AKBA
# Length : 1844
# ROI : -0.04148393699243215
# Working on : AKR
# Length : 1844
# ROI : -0.09439629695974629
# Working on : AKTS
# Length : 1844
# ROI : -0.03165059113596908
# Working on : AL
# Length : 1844
# ROI : -0.08068100861597846
# Working on : ALB
# Length : 1844
# ROI : -0.20677499693812665
# Working on : ALBO
# Length : 1844
# ROI : -0.01521407443128157
# Working on : ALCO
# Length : 1844
# ROI : -0.03388500894198842
# Working on : ALDX
# Length : 1844
# ROI : -0.2725842748709315
# Working on : ALE
# Length : 1844
# ROI : 0.009468834090514335
# Working on : ALEC
# Length : 1079
# Stock Data Corrupted
# Working on : ALEX
# Length : 1844
# ROI : -0.06725189401143446
# Working on : ALG
# Length : 1844
# ROI : 0.05570676842659667
# Working on : ALGN
# Length : 1844
# ROI : -0.1493849537548182
# Working on : ALGT
# Length : 1844
# ROI : 0.032080115226240484
# Working on : ALIM
# Length : 809
# Stock Data Corrupted
# Working on : ALJJ
# Length : 1844
# ROI : -0.02412490897390284
# Working on : ALK
# Length : 1844
# ROI : -0.035027384582172395
# Working on : ALKS
# Length : 1844
# ROI : 0.268963495186973
# Working on : ALL
# Length : 1844
# ROI : -0.04041223673130982
# Working on : ALLE
# Length : 1844
# ROI : -0.019297596166750905
# Working on : ALLK
# Length : 1282
# Stock Data Corrupted
# Working on : ALLO
# Length : 1198
# Stock Data Corrupted
# Working on : ALLY
# Length : 1844
# ROI : -0.003486780228270414
# Working on : ALNA
# Length : 1541
# ROI : -0.07677921579950223
# Working on : ALNY
# Length : 1844
# ROI : -0.05163603797976104
# Working on : ALOT
# Length : 1844
# ROI : -0.07452316669061684
# Working on : ALPN
# Length : 1844
# ROI : -0.25636133720539633
# Working on : ALRM
# Length : 1844
# ROI : -0.10871928338017889
# Working on : ALSN
# Length : 1844
# ROI : 0.058089882032794256
# Working on : ALT
# Length : 1701
# ROI : -0.24880124473018228
# Working on : ALTR
# Length : 1542
# ROI : -0.11612596758227667
# Working on : ALV
# Length : 1844
# ROI : -0.042318978891600384
# Working on : ALX
# Length : 1844
# ROI : 0.021421855196294835
# Working on : AM
# Length : 1723
# ROI : 0.05757833321417899
# Working on : AMAL
# Length : 1261
# Stock Data Corrupted
# Working on : AMAT
# Length : 1844
# ROI : -0.06808943708293155
# Working on : AMBC
# Length : 1844
# ROI : 0.07586243149759356
# Working on : AMC
# Length : 1844
# ROI : -0.1002619842697386
# Working on : AMCX
# Length : 1844
# ROI : -0.14785814323698307
# Working on : AMD
# Length : 1844
# ROI : -0.21962525851005785
# Working on : AME
# Length : 1844
# ROI : 0.04864032418593909
# Working on : AMED
# Length : 1844
# ROI : -0.2929890881090178
# Working on : AMG
# Length : 1844
# ROI : -0.04877375735957362
# Working on : AMGN
# Length : 1844
# ROI : 0.03488050632448685
# Working on : AMH
# Length : 1844
# ROI : 0.0678589890081408
# Working on : AMKR
# Length : 1844
# ROI : -0.10219827107205497
# Working on : AMN
# Length : 1844
# ROI : -0.028568269276278074
# Working on : AMNB
# Length : 1844
# ROI : 0.07074728166350981
# Working on : AMOT
# Length : 1844
# ROI : -0.09315680483371172
# Working on : AMP
# Length : 1844
# ROI : 0.09740306886830398
# Working on : AMPE
# Length : 1844
# ROI : -0.09253407055906095
# Working on : AMPH
# Length : 1844
# ROI : 0.013158658416891622
# Working on : AMRC
# Length : 1844
# ROI : -0.3692362522077503
# Working on : AMRK
# Length : 1844
# ROI : -0.2078498302424599
# Working on : AMRS
# Length : 1844
# ROI : -1.0987122615999672
# Working on : AMRX
# Length : 1355
# Stock Data Corrupted
# Working on : AMS
# Length : 1844
# ROI : 0.022501050534682803
# Working on : AMSC
# Length : 1844
# ROI : -0.3243933822973168
# Working on : AMSF
# Length : 1844
# ROI : 0.02420980687397816
# Working on : AMSWA
# Length : 1844
# ROI : 0.008958565249242968
# Working on : AMT
# Length : 1844
# ROI : -0.04104870665964306
# Working on : AMTD
# Length : 900
# Stock Data Corrupted
# Working on : AMTX
# Length : 1844
# ROI : -1.943262339085376
# Working on : AMWD
# Length : 1844
# ROI : 0.19302984709514828
# Working on : AMZN
# Length : 1844
# ROI : -0.011356098135613096
# Working on : AN
# Length : 1844
# ROI : -0.11632004089783649
# Working on : ANAB
# Length : 1821
# ROI : 0.08261612555559089
# Working on : ANAT
# Length : 1844
# ROI : -0.014360530117299139
# Working on : ANDE
# Length : 1844
# ROI : 0.009825628580577441
# Working on : ANET
# Length : 1844
# ROI : -0.05988598422436334
# Working on : ANF
# Length : 1844
# ROI : -0.017615443292672124
# Working on : ANGI
# Length : 1844
# ROI : -0.15144977787089248
# Working on : ANGO
# Length : 1844
# ROI : -0.06648902544084306
# Working on : ANIK
# Length : 1844
# ROI : -0.029471435062855433
# Working on : ANIP
# Length : 1844
# ROI : 0.09835702367998043
# Working on : ANIX
# Length : 1844
# ROI : -0.06961444738635209
# Working on : ANSS
# Length : 1844
# ROI : -0.03861992997252179
# Working on : ANTM
# Length : 1844
# ROI : 0.023845373882407764
# Working on : AON
# Length : 1844
# ROI : -0.0674703285747525
# Working on : AOS
# Length : 1844
# ROI : -0.028602841156002447
# Working on : AOSL
# Length : 1844
# ROI : 0.07641982964515162
# Working on : AP
# Length : 1844
# ROI : 0.13335905310260346
# Working on : APA
# Length : 1844
# ROI : -0.126018655368087
# Working on : APAM
# Length : 1844
# ROI : -0.03663596011637988
# Working on : APD
# Length : 1844
# ROI : 0.05685275205925579
# Working on : APDN
# Length : 1844
# ROI : 0.021819573987567727
# Working on : APEI
# Length : 1844
# ROI : 0.23364113738635053
# Working on : APEN
# Length : 1844
# ROI : -0.1475058454933401
# Working on : APH
# Length : 1844
# ROI : 0.03417105116721824
# Working on : APLE
# Length : 1844
# ROI : -0.003574527239002774
# Working on : APLS
# Length : 1534
# ROI : 0.09557817470747522
# Working on : APOG
# Length : 1844
# ROI : 0.02919989433375665
# Working on : APPF
# Length : 1844
# ROI : 0.0484165486998056
# Working on : APPN
# Length : 1702
# ROI : -0.13391756755510728
# Working on : APPS
# Length : 1844
# ROI : 1.631126690297438
# Working on : APRN
# Length : 1667
# ROI : -0.23282521969310477
# Working on : APT
# Length : 1844
# ROI : 0.4024029685196013
# Working on : APTS
# Length : 1844
# ROI : 0.19144295035086906
# Working on : APTV
# Length : 1844
# ROI : -0.0741618993623503
# Working on : APVO
# Length : 1844
# ROI : 0.1950536682747965
# Working on : APYX
# Length : 1115
# Stock Data Corrupted
# Working on : AQB
# Length : 1836
# ROI : -0.3692700625975822
# Working on : AQMS
# Length : 1844
# ROI : -0.09832117817837441
# Working on : AQUA
# Length : 1541
# ROI : 0.013415587394407577
# Working on : AR
# Length : 1844
# ROI : 0.2679094512053575
# Working on : ARAV
# Length : 1844
# ROI : 0.37570733553259966
# Working on : ARAY
# Length : 1824
# ROI : -0.04331163841364161
# Working on : ARC
# Length : 1844
# ROI : 0.0718425231690171
# Working on : ARCB
# Length : 1844
# ROI : -0.18675594505007703
# Working on : ARCH
# Length : 1844
# ROI : 0.2359810001004451
# Working on : ARDX
# Length : 1844
# ROI : 0.014181609769988618
# Working on : ARE
# Length : 1844
# ROI : 0.002227099150622022
# Working on : ARES
# Length : 1844
# ROI : 0.026917808460030716
# Working on : ARGO
# Length : 1844
# ROI : 0.08443632284608259
# Working on : ARI
# Length : 1844
# ROI : -0.11263040950552385
# Working on : ARKR
# Length : 1844
# ROI : 0.15852740607468957
# Working on : ARL
# Length : 1844
# ROI : 0.13400914457436958
# Working on : ARLO
# Length : 1267
# Stock Data Corrupted
# Working on : ARMK
# Length : 1844
# ROI : 0.025519895115237952
# Working on : ARNA
# Length : 1844
# ROI : 0.488956443802709
# Working on : ARNC
# Length : 660
# Stock Data Corrupted
# Working on : AROC
# Length : 1844
# ROI : -0.06810814655601329
# Working on : AROW
# Length : 1844
# ROI : -0.08187790149851168
# Working on : ARR
# Length : 1844
# ROI : 0.012197013974774948
# Working on : ARTNA
# Length : 1844
# ROI : 0.05319524741305154
# Working on : ARTW
# Length : 1844
# ROI : 0.000982658993682892
# Working on : ARVN
# Length : 1212
# Stock Data Corrupted
# Working on : ARW
# Length : 1844
# ROI : -0.04260523753766681
# Working on : ARWR
# Length : 1844
# ROI : 0.11982343601542825
# Working on : ASB
# Length : 1844
# ROI : 0.02958419530328925
# Working on : ASGN
# Length : 1844
# ROI : -0.052123525662430795
# Working on : ASH
# Length : 1844
# ROI : -0.0916282689485389
# Working on : ASIX
# Length : 1844
# ROI : 0.02058931013617159
# Working on : ASMB
# Length : 1844
# ROI : 0.15951770433051488
# Working on : ASPN
# Length : 1844
# ROI : -0.37921165147997965
# Working on : ASRV
# Length : 1844
# ROI : 0.030820558542486925
# Working on : ASTC
# Length : 1844
# ROI : 0.09615983305116842
# Working on : ASTE
# Length : 1844
# ROI : -0.06551858524705768
# Working on : ASUR
# Length : 1844
# ROI : -0.07777995089354578
# Working on : ASYS
# Length : 1844
# ROI : -0.2528527175099771
# Working on : ATEC
# Length : 1844
# ROI : 0.2697427695310109
# Working on : ATEN
# Length : 1844
# ROI : 0.08494511280618014
# Working on : ATGE
# Length : 1844
# ROI : 0.09257711504940218
# Working on : ATHX
# Length : 1844
# ROI : 0.3564300197240785
# Working on : ATI
# Length : 1844
# ROI : 0.1586194077943201
# Working on : ATKR
# Length : 1844
# ROI : -0.10933901483850018
# Working on : ATLC
# Length : 1844
# ROI : 0.16770199279713743
# Working on : ATLO
# Length : 1844
# ROI : 0.009016848925540454
# Working on : ATNI
# Length : 1844
# ROI : 0.011041949204841415
# Working on : ATNM
# Length : 1844
# ROI : -0.024096602455833532
# Working on : ATNX
# Length : 1682
# ROI : 0.6738899987604585
# Working on : ATO
# Length : 1844
# ROI : 0.11205065341029596
# Working on : ATOS
# Length : 1844
# ROI : -0.32971206543964365
# Working on : ATR
# Length : 1844
# ROI : -0.052182990714539475
# Working on : ATRA
# Length : 1844
# ROI : -0.08924842385275496
# Working on : ATRC
# Length : 1844
# ROI : 0.11933618740123958
# Working on : ATRI
# Length : 1844
# ROI : -0.00634115921107349
# Working on : ATRO
# Length : 1844
# ROI : -0.21461348536700345
# Working on : ATRS
# Length : 1844
# ROI : -0.007927754336231016
# Working on : ATSG
# Length : 1844
# ROI : 0.03867475134760118
# Working on : ATUS
# Length : 1674
# ROI : -0.10631028938208908
# Working on : ATVI
# Length : 1844
# ROI : 0.15444133212760877
# Working on : AUBN
# Length : 1844
# ROI : 0.04769538536846496
# Working on : AUMN
# Length : 1844
# ROI : -0.030083850286824504
# Working on : AUTO
# Length : 1844
# ROI : -0.06825626349908902
# Working on : AVA
# Length : 1844
# ROI : 0.037801850211296915
# Working on : AVAV
# Length : 1844
# ROI : -0.24359851120095477
# Working on : AVB
# Length : 1844
# ROI : -0.07445035889736383
# Working on : AVD
# Length : 1844
# ROI : 0.06702625646117447
# Working on : AVEO
# Length : 1844
# ROI : 0.2393120061244174
# Working on : AVGO
# Length : 1844
# ROI : 0.10947550284061466
# Working on : AVGR
# Length : 1844
# ROI : -0.09727110251345147
# Working on : AVID
# Length : 1844
# ROI : -0.014928993059693564
# Working on : AVLR
# Length : 1316
# Stock Data Corrupted
# Working on : AVNS
# Length : 1844
# ROI : 0.11144646116188327
# Working on : AVNW
# Length : 1844
# ROI : -0.277938965064718
# Working on : AVRO
# Length : 1310
# Stock Data Corrupted
# Working on : AVT
# Length : 1844
# ROI : -0.1002982274431571
# Working on : AVTR
# Length : 980
# Stock Data Corrupted
# Working on : AVXL
# Length : 1844
# ROI : -0.12359526966384207
# Working on : AVY
# Length : 1844
# ROI : 0.006538319090147244
# Working on : AVYA
# Length : 1494
# ROI : -0.3347158524950937
# Working on : AWI
# Length : 1844
# ROI : -0.05376071777129337
# Working on : AWK
# Length : 1844
# ROI : -0.0600948994971459
# Working on : AWR
# Length : 1844
# ROI : -0.06391561283839788
# Working on : AWRE
# Length : 1844
# ROI : 0.21592297324060455
# Working on : AX
# Length : 1844
# ROI : 0.0038166080489655183
# Working on : AXAS
# Length : 1844
# ROI : -0.3975070892315987
# Working on : AXDX
# Length : 1844
# ROI : -0.1555322491817817
# Working on : AXGN
# Length : 1844
# ROI : 0.1015196962745621
# Working on : AXL
# Length : 1844
# ROI : -0.12186681686100719
# Working on : AXNX
# Length : 1178
# Stock Data Corrupted
# Working on : AXP
# Length : 1844
# ROI : -0.03978977413382249
# Working on : AXR
# Length : 1844
# ROI : 0.03309995849360741
# Working on : AXS
# Length : 1844
# ROI : 0.07789587060114486
# Working on : AXSM
# Length : 1844
# ROI : -0.4037939549704762
# Working on : AXTA
# Length : 1844
# ROI : -0.06895010546175641
# Working on : AXTI
# Length : 1844
# ROI : -0.15194787211433655
# Working on : AYI
# Length : 1844
# ROI : -0.06776583834326887
# Working on : AYX
# Length : 1764
# ROI : -0.2076247407858702
# Working on : AZO
# Length : 1844
# ROI : 0.0690675583672007
# Working on : AZPN
# Length : 1844
# ROI : -0.05041111834644169
# Working on : AZZ
# Length : 1844
# ROI : -0.12522569294481806
# Working on : B
# Length : 1844
# ROI : 0.04471100246244241
# Working on : BA
# Length : 1844
# ROI : 0.09056667858701298
# Working on : BAC
# Length : 1844
# ROI : 0.00030480449342436933
# Working on : BAH
# Length : 1844
# ROI : -0.03295080119484078
# Working on : BANC
# Length : 1844
# ROI : -0.05238606506589122
# Working on : BAND
# Length : 1534
# ROI : -0.1963532470412272
# Working on : BANF
# Length : 1844
# ROI : 0.012950672956741053
# Working on : BANR
# Length : 1844
# ROI : 0.042257951161502584
# Working on : BATRA
# Length : 1844
# ROI : -0.09723418442964274
# Working on : BATRK
# Length : 1844
# ROI : -0.08839646781149842
# Working on : BAX
# Length : 1844
# ROI : 0.07328031266217991
# Working on : BBBY
# Length : 1844
# ROI : -0.2804253980783618
# Working on : BBCP
# Length : 1614
# ROI : -0.015423885429090324
# Working on : BBGI
# Length : 1844
# ROI : -0.037967556647520474
# Working on : BBSI
# Length : 1844
# ROI : -0.07886635275616626
# Working on : BBW
# Length : 1844
# ROI : -0.11409166326088464
# Working on : BBY
# Length : 1844
# ROI : 0.10641253032836885
# Working on : BC
# Length : 1844
# ROI : -0.07799608490759372
# Working on : BCBP
# Length : 1844
# ROI : 0.08742538393119434
# Working on : BCC
# Length : 1844
# ROI : 0.01240162907019191
# Working on : BCLI
# Length : 1844
# ROI : -0.2976888547236828
# Working on : BCO
# Length : 1844
# ROI : 0.055351353201230226
# Working on : BCOR
# Length : 1844
# ROI : 0.09399160477919852
# Working on : BCOV
# Length : 1844
# ROI : 0.011726725457114512
# Working on : BCPC
# Length : 1844
# ROI : 0.051116119697369934
# Working on : BCRX
# Length : 1844
# ROI : 0.0701554948349935
# Working on : BDC
# Length : 1844
# ROI : -0.05324808876063254
# Working on : BDL
# Length : 1844
# ROI : -0.024297951895789704
# Working on : BDN
# Length : 1844
# ROI : -0.06197032139961269
# Working on : BDSI
# Length : 1844
# ROI : 0.194410546520164
# Working on : BDX
# Length : 1844
# ROI : 0.03617944073384294
# Working on : BECN
# Length : 1844
# ROI : -0.08585252129229957
# Working on : BELFA
# Length : 1844
# ROI : 0.166080058070299
# Working on : BEN
# Length : 1844
# ROI : -0.13361992918627513
# Working on : BERY
# Length : 1844
# ROI : -0.05766905514233012
# Working on : BFAM
# Length : 1844
# ROI : 0.1515344029769106
# Working on : BFIN
# Length : 1844
# ROI : 0.0077216952341721936
# Working on : BFS
# Length : 1844
# ROI : -0.03461479714221266
# Working on : BFST
# Length : 1369
# Stock Data Corrupted
# Working on : BGFV
# Length : 1844
# ROI : -0.5585445588820268
# Working on : BGS
# Length : 1844
# ROI : -0.004202962176392905
# Working on : BGSF
# Length : 1844
# ROI : 0.10076020031498627
# Working on : BH
# Length : 1844
# ROI : -0.00011269298783744681
# Working on : BHB
# Length : 1844
# ROI : 0.008790947209136653
# Working on : BHE
# Length : 1844
# ROI : -0.03549631559081916
# Working on : BHF
# Length : 1649
# ROI : 0.017848158721375167
# Working on : BHLB
# Length : 1844
# ROI : 0.12213467231269609
# Working on : BHR
# Length : 1844
# ROI : -0.15300121000144923
# Working on : BHVN
# Length : 1723
# ROI : 0.16579904254616715
# Working on : BIG
# Length : 1844
# ROI : -0.1313104024853707
# Working on : BIIB
# Length : 1844
# ROI : -0.07504667047938933
# Working on : BIO
# Length : 1844
# ROI : -0.053643171487555485
# Working on : BIOC
# Length : 1844
# ROI : 0.06476631582790798
# Working on : BIOL
# Length : 1844
# ROI : -0.08436965585171663
# Working on : BJ
# Length : 1303
# Stock Data Corrupted
# Working on : BJRI
# Length : 1844
# ROI : 0.0008249116408721401
# Working on : BK
# Length : 1844
# ROI : 0.0036322081207663475
# Working on : BKD
# Length : 1844
# ROI : -0.12850167156192938
# Working on : BKE
# Length : 1844
# ROI : 0.0042555371784077645
# Working on : BKH
# Length : 1844
# ROI : -0.028648522217159196
# Working on : BKI
# Length : 1844
# ROI : 0.12602948762026447
# Working on : BKNG
# Length : 1844
# ROI : 0.06531556393347551
# Working on : BKSC
# Length : 1844
# ROI : -0.0192840025287245
# Working on : BKTI
# Length : 1844
# ROI : -0.0012215968126146688
# Working on : BKU
# Length : 1844
# ROI : -0.05203731724798804
# Working on : BL
# Length : 1844
# ROI : -0.23816207936372896
# Working on : BLBD
# Length : 1824
# ROI : -0.38705421929360495
# Working on : BLCM
# Length : 1844
# ROI : 0.3006325800116259
# Working on : BLD
# Length : 1844
# ROI : -0.032590199201644125
# Working on : BLDR
# Length : 1844
# ROI : 0.08121947383161157
# Working on : BLFS
# Length : 1844
# ROI : -0.13848690165216554
# Working on : BLK
# Length : 1844
# ROI : -0.049439066087316304
# Working on : BLKB
# Length : 1844
# ROI : -0.04460145858774965
# Working on : BLL
# Length : 1844
# ROI : 0.06020894579366316
# Working on : BLMN
# Length : 1844
# ROI : -0.16675781985516258
# Working on : BLUE
# Length : 1844
# ROI : -0.7301536727072915
# Working on : BMI
# Length : 1844
# ROI : -0.03627462456274761
# Working on : BMRC
# Length : 1844
# ROI : 0.06867758810902823
# Working on : BMRN
# Length : 1844
# ROI : 0.06948021724704219
# Working on : BMY
# Length : 1844
# ROI : 0.008232209941865921
# Working on : BNED
# Length : 1844
# ROI : -0.14643671973327038
# Working on : BNFT
# Length : 1844
# ROI : -0.0658128669888199
# Working on : BOH
# Length : 1844
# ROI : 0.04230136923732561
# Working on : BOKF
# Length : 1844
# ROI : -0.0404417332050898
# Working on : BOOM
# Length : 1844
# ROI : -0.14490409443797445
# Working on : BOOT
# Length : 1844
# ROI : -0.07191617400575405
# Working on : BOTJ
# Length : 1844
# ROI : -0.15536801664370875
# Working on : BOX
# Length : 1844
# ROI : -0.03634483101061136
# Working on : BPMC
# Length : 1844
# ROI : -0.020726606701352134
# Working on : BPOP
# Length : 1844
# ROI : 0.08749400139616144
# Working on : BPRN
# Length : 1696
# ROI : 0.046873828705202666
# Working on : BPTH
# Length : 1844
# ROI : -0.18855960307132588
# Working on : BR
# Length : 1844
# ROI : 0.0030739733882102524
# Working on : BRC
# Length : 1844
# ROI : -0.01922036327795374
# Working on : BRG
# Length : 1844
# ROI : 0.5294242482715775
# Working on : BRID
# Length : 1844
# ROI : 0.06557651202354911
# Working on : BRKL
# Length : 1844
# ROI : -0.010157524080273119
# Working on : BRKR
# Length : 1844
# ROI : -0.10029734865284085
# Working on : BRN
# Length : 1844
# ROI : -0.04517384361450317
# Working on : BRO
# Length : 1844
# ROI : 0.006970294730705335
# Working on : BRT
# Length : 1844
# ROI : 0.03837078486631402
# Working on : BRX
# Length : 1844
# ROI : -0.09136320642210964
# Working on : BRY
# Length : 1283
# Stock Data Corrupted
# Working on : BSET
# Length : 1844
# ROI : 0.1663793257305746
# Working on : BSGM
# Length : 1844
# ROI : -0.09621423847126183
# Working on : BSQR
# Length : 1844
# ROI : 0.20186592069983225
# Working on : BSRR
# Length : 1844
# ROI : 0.018576736457128044
# Working on : BSX
# Length : 1844
# ROI : 0.04467855980115019
# Working on : BTN
# Length : 1844
# ROI : -0.008177679200036255
# Working on : BTU
# Length : 1754
# ROI : 0.14074945392585392
# Working on : BURL
# Length : 1844
# ROI : -0.13746781503789554
# Working on : BUSE
# Length : 1844
# ROI : -0.003106312814875446
# Working on : BV
# Length : 1303
# Stock Data Corrupted
# Working on : BW
# Length : 1844
# ROI : -0.09757893722711164
# Working on : BWA
# Length : 1844
# ROI : 0.002970664030995701
# Working on : BWEN
# Length : 1844
# ROI : -1.0966000362325683
# Working on : BWFG
# Length : 1844
# ROI : -0.030855761115724356
# Working on : BWXT
# Length : 1844
# ROI : 0.04713297013308952
# Working on : BXC
# Length : 1844
# ROI : -0.0731970950232967
# Working on : BXMT
# Length : 1844
# ROI : -0.07850352894196433
# Working on : BXP
# Length : 1844
# ROI : -0.01620173390304352
# Working on : BY
# Length : 1666
# ROI : -0.035088205303338005
# Working on : BYD
# Length : 1844
# ROI : -0.031243326967684486
# Working on : BYFC
# Length : 1844
# ROI : -0.1664404653009698
# Working on : BYND
# Length : 995
# Stock Data Corrupted
# Working on : BZH
# Length : 1844
# ROI : 0.024854426437285505
# Working on : C
# Length : 1844
# ROI : -0.21194962477867685
# Working on : CABO
# Length : 1844
# ROI : -0.08334287898723446
# Working on : CAC
# Length : 1844
# ROI : -0.04881289016290045
# Working on : CACC
# Length : 1844
# ROI : -0.12247020318432306
# Working on : CACI
# Length : 1844
# ROI : 0.04266419950677051
# Working on : CADE
# Length : 1844
# ROI : 0.05177019777484364
# Working on : CAG
# Length : 1844
# ROI : -0.004440867187656664
# Working on : CAH
# Length : 1844
# ROI : 0.06372805759085466
# Working on : CAKE
# Length : 1844
# ROI : -0.16995745127099518
# Working on : CAL
# Length : 1844
# ROI : -0.001844732289825878
# Working on : CALA
# Length : 1844
# ROI : 0.1860656169959822
# Working on : CALM
# Length : 1844
# ROI : 0.07113852947627484
# Working on : CALX
# Length : 1844
# ROI : 0.016491895063333855
# Working on : CAMP
# Length : 1844
# ROI : -0.17171396201082623
# Working on : CAPR
# Length : 1844
# ROI : 0.019676834414302555
# Working on : CAR
# Length : 1844
# ROI : 0.20014196319797295
# Working on : CARA
# Length : 1844
# ROI : 0.2084181396692723
# Working on : CARG
# Length : 1562
# ROI : -0.2157954810262731
# Working on : CARS
# Length : 1695
# ROI : -0.049471831687555874
# Working on : CASA
# Length : 1498
# ROI : -0.37067774482098514
# Working on : CASH
# Length : 1844
# ROI : 0.023073289353625775
# Working on : CASI
# Length : 1844
# ROI : 0.17991900602307745
# Working on : CASS
# Length : 1844
# ROI : 0.049765070472394396
# Working on : CASY
# Length : 1844
# ROI : 0.018358629024238404
# Working on : CAT
# Length : 1844
# ROI : 0.08107724302787507
# Working on : CATC
# Length : 1844
# ROI : -0.0073736680210868336
# Working on : CATO
# Length : 1844
# ROI : -0.03510325106470945
# Working on : CATY
# Length : 1844
# ROI : -0.02952239464111176
# Working on : CB
# Length : 1844
# ROI : 0.05495013647461891
# Working on : CBAN
# Length : 1844
# ROI : -0.08095910989447917
# Working on : CBAY
# Length : 1844
# ROI : 0.15976336767222285
# Working on : CBFV
# Length : 1844
# ROI : -0.04972588020609207
# Working on : CBIO
# Length : 1844
# ROI : 1.1240984224777495
# Working on : CBOE
# Length : 1844
# ROI : -0.11319052469634558
# Working on : CBRE
# Length : 1844
# ROI : 0.0918386823467561
# Working on : CBRL
# Length : 1844
# ROI : -0.010891066999501618
# Working on : CBSH
# Length : 1844
# ROI : 0.06935751416814688
# Working on : CBT
# Length : 1844
# ROI : -0.00947129239284327
# Working on : CBTX
# Length : 1535
# ROI : 0.08585671652780238
# Working on : CBU
# Length : 1844
# ROI : -0.01153426699719347
# Working on : CBZ
# Length : 1844
# ROI : 0.06700896137224088
# Working on : CC
# Length : 1844
# ROI : 0.01665013776716137
# Working on : CCBG
# Length : 1844
# ROI : -0.027607962807242453
# Working on : CCF
# Length : 1844
# ROI : -0.06452888772073531
# Working on : CCI
# Length : 1844
# ROI : 0.004484970922420142
# Working on : CCK
# Length : 1844
# ROI : 0.0958894077883843
# Working on : CCL
# Length : 1844
# ROI : -0.22049185942527957
# Working on : CCMP
# Length : 1844
# ROI : 0.0912596932955125
# Working on : CCNE
# Length : 1844
# ROI : 0.025611415642775158
# Working on : CCO
# Length : 1844
# ROI : 0.07863319813496795
# Working on : CCOI
# Length : 1844
# ROI : -0.057552285229699636
# Working on : CCRN
# Length : 1844
# ROI : -0.11160746212892868
# Working on : CCS
# Length : 1844
# ROI : 0.032632983025963264
# Working on : CCXI
# Length : 1844
# ROI : -0.3079452538756511
# Working on : CDAY
# Length : 1366
# Stock Data Corrupted
# Working on : CDE
# Length : 1844
# ROI : 0.07129919639162519
# Working on : CDEV
# Length : 1844
# ROI : 0.22735284769408318
# Working on : CDK
# Length : 1844
# ROI : 0.05043222143807303
# Working on : CDLX
# Length : 1442
# ROI : 0.0367974877928002
# Working on : CDMO
# Length : 1844
# ROI : -0.3827422786194783
# Working on : CDNA
# Length : 1844
# ROI : -0.27443695667107865
# Working on : CDNS
# Length : 1844
# ROI : 0.039979183570276564
# Working on : CDR
# Length : 1844
# ROI : 0.059103123792212095
# Working on : CDTX
# Length : 1844
# ROI : -0.0009899527756344604
# Working on : CDW
# Length : 1844
# ROI : 0.05934139209067566
# Working on : CDXC
# Length : 1844
# ROI : -1.1284639461758144
# Working on : CDXS
# Length : 1844
# ROI : -0.46023943410432944
# Working on : CDZI
# Length : 1844
# ROI : 0.24247669440888875
# Working on : CE
# Length : 1844
# ROI : 0.14395969020481794
# Working on : CECE
# Length : 1844
# ROI : 0.07812592003815745
# Working on : CEI
# Length : 1844
# ROI : 3.9965512494718802
# Working on : CEIX
# Length : 1529
# ROI : 0.21194364427975648
# Working on : CELC
# Length : 1584
# ROI : -0.39189133562935263
# Working on : CELH
# Length : 1844
# ROI : 0.06350064375223792
# Working on : CEMI
# Length : 1844
# ROI : 0.3384759331855141
# Working on : CENT
# Length : 1844
# ROI : -0.07110539758952225
# Working on : CENTA
# Length : 1844
# ROI : -0.04566245736964208
# Working on : CENX
# Length : 1844
# ROI : -0.022526855204844612
# Working on : CERN
# Length : 1844
# ROI : 0.1527848926411504
# Working on : CERS
# Length : 1844
# ROI : -0.14823555693321716
# Working on : CETX
# Length : 1844
# ROI : 0.12770236718189454
# Working on : CEVA
# Length : 1844
# ROI : -0.1944653853940251
# Working on : CF
# Length : 1844
# ROI : -0.08624779223232999
# Working on : CFBK
# Length : 1844
# ROI : -0.021377794839178572
# Working on : CFFI
# Length : 1844
# ROI : -0.03659403798248001
# Working on : CFFN
# Length : 1844
# ROI : -0.03252418460564077
# Working on : CFG
# Length : 1844
# ROI : -0.030275627170585274
# Working on : CFMS
# Length : 1844
# ROI : 0.13512917963871005
# Working on : CFR
# Length : 1844
# ROI : -0.06271426265979038
# Working on : CGNX
# Length : 1844
# ROI : -0.12353726304222283
# Working on : CHCI
# Length : 1844
# ROI : 0.07377545908348766
# Working on : CHCO
# Length : 1844
# ROI : -0.02761017959922057
# Working on : CHCT
# Length : 1844
# ROI : 0.09151475048949578
# Working on : CHD
# Length : 1844
# ROI : 0.06215229266799144
# Working on : CHDN
# Length : 1844
# ROI : 0.11100207446806319
# Working on : CHE
# Length : 1844
# ROI : 0.03630942121288519
# Working on : CHEF
# Length : 1844
# ROI : 0.035669150501143415
# Working on : CHGG
# Length : 1844
# ROI : 0.26513917362942724
# Working on : CHH
# Length : 1844
# ROI : 0.01657447457285305
# Working on : CHMA
# Length : 1676
# ROI : 0.09435064632779187
# Working on : CHMG
# Length : 1844
# ROI : -0.06538604802786746
# Working on : CHMI
# Length : 1844
# ROI : 0.043402268648900816
# Working on : CHRS
# Length : 1844
# ROI : -0.09376052322505604
# Working on : CHRW
# Length : 1844
# ROI : 0.02874872573182632
# Working on : CHS
# Length : 1844
# ROI : -0.21661003936102055
# Working on : CHTR
# Length : 1844
# ROI : -0.08267303159462817
# Working on : CHUY
# Length : 1844
# ROI : -0.24240940034550504
# Working on : CI
# Length : 1844
# ROI : 0.15866666853356873
# Working on : CIA
# Length : 1844
# ROI : -0.030039344160044976
# Working on : CIDM
# Length : 1844
# ROI : -0.5383280703644222
# Working on : CIEN
# Length : 1844
# ROI : 0.07579432494959798
# Working on : CIM
# Length : 1844
# ROI : -0.06120904408816265
# Working on : CINF
# Length : 1844
# ROI : -0.05232839723791265
# Working on : CIO
# Length : 1844
# ROI : -0.013388984081896285
# Working on : CIR
# Length : 1844
# ROI : -0.07188868507309222
# Working on : CIVB
# Length : 1844
# ROI : -0.04180788664892838
# Working on : CIX
# Length : 1844
# ROI : -0.07361656926828687
# Working on : CIZN
# Length : 1844
# ROI : -0.018958602073646646
# Working on : CKX
# Length : 1844
# ROI : -0.09474079534391584
# Working on : CL
# Length : 1844
# ROI : 0.09411967977357444
# Working on : CLAR
# Length : 1844
# ROI : -0.005138006624736306
# Working on : CLB
# Length : 1844
# ROI : -0.1526924108447273
# Working on : CLBS
# Length : 1844
# ROI : -0.07472673907858533
# Working on : CLDT
# Length : 1844
# ROI : 0.04905834946144469
# Working on : CLDX
# Length : 1844
# ROI : 0.005174015875525445
# Working on : CLF
# Length : 1844
# ROI : -0.20279094776871695
# Working on : CLFD
# Length : 1844
# ROI : 0.15684584154915795
# Working on : CLH
# Length : 1844
# ROI : -0.05743970941821834
# Working on : CLIR
# Length : 1844
# ROI : -0.22341550057681447
# Working on : CLNE
# Length : 1844
# ROI : 0.5064942853886274
# Working on : CLPR
# Length : 1806
# ROI : 0.02223704553526314
# Working on : CLR
# Length : 1844
# ROI : 0.07785771498092878
# Working on : CLRB
# Length : 1844
# ROI : 0.7954593800949177
# Working on : CLRO
# Length : 1844
# ROI : 0.2848885801169312
# Working on : CLSN
# Length : 1844
# ROI : -0.23882050778339867
# Working on : CLVS
# Length : 1844
# ROI : 0.32263823194722013
# Working on : CLW
# Length : 1844
# ROI : -0.06317938609885292
# Working on : CLX
# Length : 1844
# ROI : 0.024924226860636126
# Working on : CLXT
# Length : 1646
# ROI : -0.49114125067012726
# Working on : CMA
# Length : 1844
# ROI : 0.03842613658065979
# Working on : CMC
# Length : 1844
# ROI : 0.1491553217509495
# Working on : CMCO
# Length : 1844
# ROI : -0.11576531056971455
# Working on : CMCSA
# Length : 1844
# ROI : 0.05241626805609558
# Working on : CMCT
# Length : 1844
# ROI : 0.018308470116269827
# Working on : CME
# Length : 1844
# ROI : -0.03434649541096067
# Working on : CMG
# Length : 1844
# ROI : 0.037507828212035084
# Working on : CMI
# Length : 1844
# ROI : 0.04445272419351787
# Working on : CMP
# Length : 1844
# ROI : 0.04713048920047324
# Working on : CMRX
# Length : 1844
# ROI : 0.19453915232985472
# Working on : CMS
# Length : 1844
# ROI : 0.04262680822808796
# Working on : CMT
# Length : 1844
# ROI : 0.10137119009969334
# Working on : CMTL
# Length : 1844
# ROI : -0.05834388464076603
# Working on : CNA
# Length : 1844
# ROI : -0.1086509910823314
# Working on : CNC
# Length : 1844
# ROI : -0.049104166548472945
# Working on : CNCE
# Length : 1844
# ROI : -0.039767005648327705
# Working on : CNDT
# Length : 1844
# ROI : 0.04477303049862113
# Working on : CNFR
# Length : 1844
# ROI : 0.012094092940355648
# Working on : CNK
# Length : 1844
# ROI : -0.1634747148439353
# Working on : CNMD
# Length : 1844
# ROI : -0.0663796057971107
# Working on : CNNE
# Length : 1523
# ROI : 0.04990511001706225
# Working on : CNO
# Length : 1844
# ROI : -0.004688200510901325
# Working on : CNOB
# Length : 1844
# ROI : 0.01908314264533272
# Working on : CNP
# Length : 1844
# ROI : 0.0026488503262713887
# Working on : CNS
# Length : 1844
# ROI : 0.030716350161335088
# Working on : CNSL
# Length : 1844
# ROI : -0.13600658951328592
# Working on : CNTY
# Length : 1844
# ROI : -0.24392400862283964
# Working on : CNX
# Length : 1844
# ROI : 0.012336679796879009
# Working on : CNXN
# Length : 1844
# ROI : -0.012823172446403111
# Working on : CODA
# Length : 1844
# ROI : -0.1056302048964322
# Working on : COF
# Length : 1844
# ROI : -0.06740953577904948
# Working on : COHN
# Length : 1844
# ROI : -0.579971174209561
# Working on : COHR
# Length : 1844
# ROI : -0.09055717032649298
# Working on : COHU
# Length : 1844
# ROI : -0.0690340705683833
# Working on : COKE
# Length : 1844
# ROI : -0.013732508692548908
# Working on : COLB
# Length : 1844
# ROI : -0.04719169828697475
# Working on : COLD
# Length : 1463
# ROI : 0.033059108379814246
# Working on : COLL
# Length : 1844
# ROI : -0.07725179738077546
# Working on : COLM
# Length : 1844
# ROI : -0.1317282499445117
# Working on : COMM
# Length : 1844
# ROI : 0.05237133634039195
# Working on : CONE
# Length : 1844
# ROI : -0.02477033467138973
# Working on : CONN
# Length : 1844
# ROI : 0.08361324358759557
# Working on : COO
# Length : 1844
# ROI : 0.02166101596981261
# Working on : COOP
# Length : 1844
# ROI : 0.04514049737626469
# Working on : COP
# Length : 1844
# ROI : 0.016074838804529305
# Working on : CORR
# Length : 1844
# ROI : 0.46730573208809806
# Working on : CORT
# Length : 1844
# ROI : -0.01217968922798546
# Working on : COST
# Length : 1844
# ROI : -0.1446894542677299
# Working on : COTY
# Length : 1844
# ROI : -0.17949099150584083
# Working on : COUP
# Length : 1844
# ROI : -0.4690483509063091
# Working on : COWN
# Length : 1844
# ROI : -0.16229668121355628
# Working on : CPB
# Length : 1844
# ROI : 0.02477120272125215
# Working on : CPE
# Length : 1844
# ROI : -0.09716441860261417
# Working on : CPF
# Length : 1844
# ROI : -0.02825170556369195
# Working on : CPHC
# Length : 1844
# ROI : -0.05023328133197115
# Working on : CPIX
# Length : 1844
# ROI : -0.21147379345393266
# Working on : CPK
# Length : 1844
# ROI : -0.005014933145298376
# Working on : CPRI
# Length : 1844
# ROI : -0.02250806356848996
# Working on : CPRT
# Length : 1844
# ROI : 0.006068585866254539
# Working on : CPRX
# Length : 1844
# ROI : -0.17472604776514603
# Working on : CPS
# Length : 1844
# ROI : 0.18939102751858516
# Working on : CPSH
# Length : 1844
# ROI : 10.595433889756588
# Working on : CPSI
# Length : 1844
# ROI : -0.027090637061880418
# Working on : CPSS
# Length : 1844
# ROI : 0.47702645329638327
# Working on : CPT
# Length : 1844
# ROI : -0.015234694581413015
# Working on : CR
# Length : 1844
# ROI : -0.02207930815709509
# Working on : CRAI
# Length : 1844
# ROI : -0.1711934989174067
# Working on : CRBP
# Length : 1844
# ROI : -2.6473159970465963
# Working on : CRC
# Length : 450
# Stock Data Corrupted
# Working on : CRI
# Length : 1844
# ROI : -0.10617157560316116
# Working on : CRIS
# Length : 1844
# ROI : 0.04770109860430362
# Working on : CRK
# Length : 1844
# ROI : -0.01934130138156598
# Working on : CRL
# Length : 1844
# ROI : -0.014033888241732406
# Working on : CRM
# Length : 1844
# ROI : 0.027428166001959284
# Working on : CRMD
# Length : 1844
# ROI : 0.21117654471348926
# Working on : CRMT
# Length : 1844
# ROI : -0.06458980933753765
# Working on : CRNX
# Length : 1283
# Stock Data Corrupted
# Working on : CROX
# Length : 1844
# ROI : -0.2651502198404619
# Working on : CRS
# Length : 1844
# ROI : -0.19682941959227057
# Working on : CRTX
# Length : 988
# Stock Data Corrupted
# Working on : CRUS
# Length : 1844
# ROI : 0.08147156186062342
# Working on : CRVL
# Length : 1844
# ROI : 0.06627409078266615
# Working on : CRVS
# Length : 1844
# ROI : -0.32533585078509214
# Working on : CRWS
# Length : 1844
# ROI : -0.07519998804645343
# Working on : CSCO
# Length : 1844
# ROI : 0.024405638589662517
# Working on : CSGP
# Length : 1844
# ROI : -0.004349256160676436
# Working on : CSGS
# Length : 1844
# ROI : 0.00883652965762712
# Working on : CSII
# Length : 1844
# ROI : 0.09357758217365619
# Working on : CSL
# Length : 1844
# ROI : -0.03223318492271511
# Working on : CSPI
# Length : 1844
# ROI : 0.12957435254688332
# Working on : CSTR
# Length : 1844
# ROI : -0.07567043311209297
# Working on : CSV
# Length : 1844
# ROI : -0.025907495517587
# Working on : CSWI
# Length : 1844
# ROI : 0.043726269407275774
# Working on : CSX
# Length : 1844
# ROI : 0.007655120358843806
# Working on : CTAS
# Length : 1844
# ROI : 0.053941662703613634
# Working on : CTBI
# Length : 1844
# ROI : 0.023507832885025077
# Working on : CTG
# Length : 1844
# ROI : 0.05759283737241776
# Working on : CTHR
# Length : 1844
# ROI : -0.2589859709549699
# Working on : CTIB
# Length : 1844
# ROI : 0.004539988195866234
# Working on : CTIC
# Length : 1844
# ROI : 0.12509961972517042
# Working on : CTLT
# Length : 1844
# ROI : -0.15433426053589955
# Working on : CTMX
# Length : 1844
# ROI : -0.02752731609881175
# Working on : CTO
# Length : 1844
# ROI : -0.062309274397200826
# Working on : CTRE
# Length : 1844
# ROI : -0.04449765616526429
# Working on : CTRN
# Length : 1844
# ROI : -0.6149397645475096
# Working on : CTS
# Length : 1844
# ROI : -0.11400051064754653
# Working on : CTSH
# Length : 1844
# ROI : -0.02676490028897398
# Working on : CTSO
# Length : 1844
# ROI : 0.01376156725885094
# Working on : CTT
# Length : 1844
# ROI : 0.008488618425072415
# Working on : CTXS
# Length : 1844
# ROI : 0.07238394760190689
# Working on : CUBE
# Length : 1844
# ROI : -0.015134449745887459
# Working on : CUBI
# Length : 1844
# ROI : 0.21237877789811388
# Working on : CUE
# Length : 1480
# ROI : -0.06530696444623324
# Working on : CULP
# Length : 1844
# ROI : -0.022166822633030277
# Working on : CURO
# Length : 1506
# ROI : 0.0020033661640601486
# Working on : CUTR
# Length : 1844
# ROI : -0.3021988354171654
# Working on : CUZ
# Length : 1844
# ROI : -0.09239169972123136
# Working on : CVBF
# Length : 1844
# ROI : 0.10285127169957499
# Working on : CVCO
# Length : 1844
# ROI : -0.1370591859887436
# Working on : CVCY
# Length : 1844
# ROI : 0.009671041128386263
# Working on : CVGI
# Length : 1844
# ROI : -0.10218141304780634
# Working on : CVGW
# Length : 1844
# ROI : 0.11269138309902497
# Working on : CVI
# Length : 1844
# ROI : 0.08887945715572942
# Working on : CVLT
# Length : 1844
# ROI : 0.04350042267346502
# Working on : CVLY
# Length : 1844
# ROI : -0.028610077760731607
# Working on : CVM
# Length : 1844
# ROI : 1.0704692479858327
# Working on : CVNA
# Length : 1729
# ROI : -0.2498890237764052
# Working on : CVR
# Length : 1844
# ROI : -0.029108565275043224
# Working on : CVS
# Length : 1844
# ROI : 0.06675984712883559
# Working on : CVU
# Length : 1844
# ROI : -0.18450979175730936
# Working on : CVV
# Length : 1844
# ROI : -0.029730035985812885
# Working on : CVX
# Length : 1844
# ROI : 0.001840506250718289
# Working on : CW
# Length : 1844
# ROI : -0.12477487578251177
# Working on : CWBC
# Length : 1844
# ROI : 0.03307205817424178
# Working on : CWBR
# Length : 1498
# ROI : 0.7322691871177746
# Working on : CWEN
# Length : 1844
# ROI : -0.12062383789956041
# Working on : CWH
# Length : 1844
# ROI : -0.20106516120491613
# Working on : CWST
# Length : 1844
# ROI : -0.06389319913070957
# Working on : CWT
# Length : 1844
# ROI : -0.06855923885834728
# Working on : CXW
# Length : 1844
# ROI : -0.11186399019247646
# Working on : CYAN
# Length : 1844
# ROI : -0.02878586294590516
# Working on : CYBE
# Length : 1844
# ROI : -0.05077037779718475
# Working on : CYCC
# Length : 1844
# ROI : -0.14745463171913714
# Working on : CYH
# Length : 1844
# ROI : -0.05535986258946521
# Working on : CYRX
# Length : 1844
# ROI : 0.07441612229534118
# Working on : CYTK
# Length : 1844
# ROI : -0.2132865142619334
# Working on : CYTR
# Length : 1844
# ROI : 1.08860680384802
# Working on : CZNC
# Length : 1844
# ROI : 0.0017932584090347569
# Working on : CZR
# Length : 1844
# ROI : -0.006158448101352957
# Working on : CZWI
# Length : 1844
# ROI : 0.000962267322698322
# Working on : D
# Length : 1844
# ROI : 0.08642093776685277
# Working on : DAIO
# Length : 1844
# ROI : 0.0565682054866349
# Working on : DAKT
# Length : 1844
# ROI : -0.0685514727057068
# Working on : DAL
# Length : 1844
# ROI : 0.078261496688408
# Working on : DAN
# Length : 1844
# ROI : -0.1307601415748588
# Working on : DAR
# Length : 1844
# ROI : -0.0054854638227943234
# Working on : DARE
# Length : 1844
# ROI : 0.040706035775747364
# Working on : DBD
# Length : 1844
# ROI : -0.16653029164776292
# Working on : DBI
# Length : 1844
# ROI : -0.11109780361660024
# Working on : DBX
# Length : 1400
# ROI : 0.03021537334717473
# Working on : DCI
# Length : 1844
# ROI : 0.02302578161000801
# Working on : DCO
# Length : 1844
# ROI : -0.04510868257439046
# Working on : DCOM
# Length : 1844
# ROI : -0.04555433751088545
# Working on : DCPH
# Length : 1576
# ROI : -0.2705312659136223
# Working on : DD
# Length : 1844
# ROI : -0.04211130651230932
# Working on : DDD
# Length : 1844
# ROI : 0.12694815494617043
# Working on : DDS
# Length : 1844
# ROI : 0.05969663147403465
# Working on : DE
# Length : 1844
# ROI : 0.12351778581265921
# Working on : DEA
# Length : 1844
# ROI : 0.0015585291274393658
# Working on : DECK
# Length : 1844
# ROI : -0.09118700745082069
# Working on : DEI
# Length : 1844
# ROI : -0.07241614350749986
# Working on : DELL
# Length : 1844
# ROI : 0.015466374518847437
# Working on : DENN
# Length : 1844
# ROI : 0.05897877890140202
# Working on : DFIN
# Length : 1844
# ROI : -0.14880367781379944
# Working on : DFS
# Length : 1844
# ROI : -0.03453353101803552
# Working on : DG
# Length : 1844
# ROI : -0.030648512392776033
# Working on : DGICA
# Length : 1844
# ROI : 0.01677273177552103
# Working on : DGII
# Length : 1844
# ROI : 0.15508680350709883
# Working on : DGLY
# Length : 1844
# ROI : 0.2670166344265648
# Working on : DGX
# Length : 1844
# ROI : 0.022218897098071944
# Working on : DHI
# Length : 1844
# ROI : -0.019619010638992792
# Working on : DHIL
# Length : 1844
# ROI : 0.04117004039875891
# Working on : DHR
# Length : 1844
# ROI : -0.004716078507546981
# Working on : DHX
# Length : 1844
# ROI : -0.04483737728585499
# Working on : DIN
# Length : 1844
# ROI : -0.17098164776760624
# Working on : DIOD
# Length : 1844
# ROI : 0.027436677001022258
# Working on : DIS
# Length : 1844
# ROI : 0.04644132579827247
# Working on : DISCA
# Length : 1844
# ROI : -0.18699194514977327
# Working on : DISCK
# Length : 1844
# ROI : -0.2176360197422049
# Working on : DISH
# Length : 1844
# ROI : 0.08337034096464398
# Working on : DIT
# Length : 1844
# ROI : -0.01457815839285375
# Working on : DJCO
# Length : 1844
# ROI : 0.01806527878517614
# Working on : DK
# Length : 1844
# ROI : 0.024765376163736915
# Working on : DKS
# Length : 1844
# ROI : -0.06648872650055757
# Working on : DLA
# Length : 1844
# ROI : -0.15145004934355957
# Working on : DLB
# Length : 1844
# ROI : 0.06535486373286022
# Working on : DLHC
# Length : 1844
# ROI : 0.31348351317433587
# Working on : DLR
# Length : 1844
# ROI : -0.05953223627691864
# Working on : DLTH
# Length : 1844
# ROI : 0.028873958401147704
# Working on : DLTR
# Length : 1844
# ROI : -0.07195174333371687
# Working on : DLX
# Length : 1844
# ROI : -0.18798175454599778
# Working on : DMRC
# Length : 1844
# ROI : -0.4678686657165074
# Working on : DNLI
# Length : 1505
# ROI : -0.38803892514684946
# Working on : DNOW
# Length : 1844
# ROI : -0.21398522764179234
# Working on : DOC
# Length : 1844
# ROI : 0.040375609142560075
# Working on : DOCU
# Length : 1365
# Stock Data Corrupted
# Working on : DOMO
# Length : 1302
# Stock Data Corrupted
# Working on : DOOR
# Length : 1844
# ROI : -0.09972465834190598
# Working on : DORM
# Length : 1844
# ROI : -0.03883220829922546
# Working on : DOV
# Length : 1844
# ROI : 0.06293768441617209
# Working on : DOW
# Length : 1038
# Stock Data Corrupted
# Working on : DPZ
# Length : 1844
# ROI : -0.11608009360316487
# Working on : DRE
# Length : 1844
# ROI : 0.06073137245999456
# Working on : DRH
# Length : 1844
# ROI : 0.07199582838200817
# Working on : DRI
# Length : 1844
# ROI : -0.07356611590173423
# Working on : DRQ
# Length : 1844
# ROI : 0.048722863492807446
# Working on : DRRX
# Length : 1844
# ROI : -0.02351715359775712
# Working on : DS
# Length : 1844
# ROI : -0.18409003658367135
# Working on : DSKE
# Length : 1844
# ROI : -0.050792763457109924
# Working on : DSS
# Length : 1844
# ROI : 0.7716975341741616
# Working on : DTE
# Length : 1844
# ROI : 0.055405870392193905
# Working on : DUK
# Length : 1844
# ROI : 0.06042627018048486
# Working on : DVA
# Length : 1844
# ROI : 0.08129166094865381
# Working on : DVAX
# Length : 1844
# ROI : -0.27988848073231226
# Working on : DVN
# Length : 1844
# ROI : 0.09123149341866697
# Working on : DWSN
# Length : 1844
# ROI : -0.12172893992313233
# Working on : DX
# Length : 1844
# ROI : -0.07266614706855738
# Working on : DXC
# Length : 1844
# ROI : 0.1562701093251146
# Working on : DXCM
# Length : 1844
# ROI : -0.0857948039229885
# Working on : DXLG
# Length : 1844
# ROI : -0.2714763534013973
# Working on : DXPE
# Length : 1844
# ROI : -0.035290937988295155
# Working on : DXYN
# Length : 1844
# ROI : 0.01950452696255035
# Working on : DY
# Length : 1844
# ROI : 0.043121010566288996
# Working on : DZSI
# Length : 1844
# ROI : -0.09555954559299779
# Working on : EA
# Length : 1844
# ROI : -0.035396050936381096
# Working on : EAF
# Length : 1373
# ROI : 0.07383623593809288
# Working on : EARN
# Length : 1844
# ROI : 0.02822742683508247
# Working on : EAT
# Length : 1844
# ROI : -0.27946993234283696
# Working on : EB
# Length : 1219
# Stock Data Corrupted
# Working on : EBAY
# Length : 1844
# ROI : -0.08518964564938614
# Working on : EBF
# Length : 1844
# ROI : -0.09837804892619365
# Working on : EBIX
# Length : 1844
# ROI : -0.07456930487921225
# Working on : EBMT
# Length : 1844
# ROI : 0.06329525207701318
# Working on : EBS
# Length : 1844
# ROI : 0.35073128824156513
# Working on : EBTC
# Length : 1844
# ROI : 0.03657906998102256
# Working on : ECL
# Length : 1844
# ROI : -0.019589392035012733
# Working on : ECOL
# Length : 1844
# ROI : 0.0048719908681771175
# Working on : ECOM
# Length : 1844
# ROI : -0.1796541822413333
# Working on : ECPG
# Length : 1844
# ROI : 0.010453529217142815
# Working on : ED
# Length : 1844
# ROI : 0.0070713908680879525
# Working on : EDIT
# Length : 1844
# ROI : -0.12189263097706787
# Working on : EDUC
# Length : 1844
# ROI : -0.31241630156184447
# Working on : EEFT
# Length : 1844
# ROI : -0.08100576785800936
# Working on : EEX
# Length : 1729
# ROI : -0.3467203246125806
# Working on : EFC
# Length : 1844
# ROI : -0.07686787283165689
# ...
# Length : 1844
# ROI : -0.0797839666362742
# Working on : UAA
# Length : 1844
# ROI : -0.12182109074496017
# Working on : UAL
# Length : 1844
# ROI : 0.05778679843782617
# Working on : UAMY
# Length : 1844
# ROI : 0.23610587218671614
# Working on : UBA
# Length : 1844
# ROI : 0.010978726083295424
# Working on : UBCP
# Length : 1844
# ROI : 0.15380587210283367
# Working on : UBER
# Length : 987
# Stock Data Corrupted
# Working on : UBFO
# Length : 1844
# ROI : 0.06630491234912235
# Working on : UBOH
# Length : 1844
# ROI : -0.032781989475272784
# Working on : UBSI
# Length : 1844
# ROI : -0.10330840083959072
# Working on : UCBI
# Length : 1844
# ROI : -0.01620608534301867
# Working on : UCTT
# Length : 1844
# ROI : -0.10402552918003236
# Working on : UDR
# Length : 1844
# ROI : -0.07734517249762818
# Working on : UE
# Length : 1844
# ROI : -0.11430232369925669
# Working on : UEC
# Length : 1844
# ROI : -0.2530947649161552
# Working on : UEIC
# Length : 1844
# ROI : 0.03528499579703715
# Working on : UFAB
# Length : 1844
# ROI : -0.15926894074990786
# Working on : UFCS
# Length : 1844
# ROI : 0.18879112830710346
# Working on : UFI
# Length : 1844
# ROI : -0.11736949236377918
# Working on : UFPI
# Length : 1844
# ROI : 0.10761369045839458
# Working on : UFPT
# Length : 1844
# ROI : 0.001316612562475908
# Working on : UG
# Length : 1844
# ROI : 0.06840060182463101
# Working on : UGI
# Length : 1844
# ROI : 0.011922257966442914
# Working on : UHAL
# Length : 1844
# ROI : -0.08876623733098643
# Working on : UHS
# Length : 1844
# ROI : -0.16570794648811185
# Working on : UHT
# Length : 1844
# ROI : 0.11550265300397612
# Working on : UIHC
# Length : 1844
# ROI : -0.20532655605623243
# Working on : UIS
# Length : 1844
# ROI : -0.1467098928931977
# Working on : ULBI
# Length : 1844
# ROI : 0.1583319114715726
# Working on : ULH
# Length : 1844
# ROI : -0.09111422562514143
# Working on : ULTA
# Length : 1844
# ROI : -0.2019927138233094
# Working on : UMBF
# Length : 1844
# ROI : 0.013936603300216283
# Working on : UMH
# Length : 1844
# ROI : -0.002408134324468866
# Working on : UMPQ
# Length : 1844
# ROI : 0.007341149224748206
# Working on : UNAM
# Length : 1844
# ROI : 0.0009971612409170074
# Working on : UNB
# Length : 1844
# ROI : 0.13096233094101625
# Working on : UNF
# Length : 1844
# ROI : 0.01797071483003802
# Working on : UNFI
# Length : 1844
# ROI : -0.15980105702332503
# Working on : UNH
# Length : 1844
# ROI : 0.03335238886202012
# Working on : UNIT
# Length : 1844
# ROI : 0.12524857277929088
# Working on : UNP
# Length : 1844
# ROI : 0.035129315949862294
# Working on : UNTY
# Length : 1844
# ROI : 0.04145633123857467
# Working on : UNVR
# Length : 1844
# ROI : -0.052229136709981125
# Working on : UONE
# Length : 1844
# ROI : 0.27134964362457337
# Working on : UONEK
# Length : 1844
# ROI : -0.023464972496302496
# Working on : UPLD
# Length : 1844
# ROI : 0.24863400460101462
# Working on : UPS
# Length : 1844
# ROI : 0.08933831198944239
# Working on : UPWK
# Length : 1206
# Stock Data Corrupted
# Working on : URBN
# Length : 1844
# ROI : -0.004972227800820515
# Working on : URI
# Length : 1844
# ROI : -0.055842022928255415
# Working on : USAK
# Length : 1844
# ROI : 0.06385437300085368
# Working on : USAP
# Length : 1844
# ROI : 0.07556844934672603
# Working on : USB
# Length : 1844
# ROI : -0.10319429429994388
# Working on : USEG
# Length : 1844
# ROI : 0.26593658978220863
# Working on : USFD
# Length : 1844
# ROI : -0.0041899743839214024
# Working on : USIO
# Length : 1844
# ROI : -0.4823180484856608
# Working on : USLM
# Length : 1844
# ROI : 0.08512946812557594
# Working on : USM
# Length : 1844
# ROI : 0.05294715188674586
# Working on : USNA
# Length : 1844
# ROI : -0.05435383986474577
# Working on : USPH
# Length : 1844
# ROI : 0.2069962648668672
# Working on : USWS
# Length : 1165
# Stock Data Corrupted
# Working on : USX
# Length : 1317
# Stock Data Corrupted
# Working on : UTHR
# Length : 1844
# ROI : 0.05729135115492901
# Working on : UTI
# Length : 1844
# ROI : -0.10198397609030761
# Working on : UTL
# Length : 1844
# ROI : 0.008302128730629967
# Working on : UTMD
# Length : 1844
# ROI : -0.18449970443837488
# Working on : UUU
# Length : 1844
# ROI : -0.9860195651902762
# Working on : UVE
# Length : 1844
# ROI : 0.09724698833668566
# Working on : UVSP
# Length : 1844
# ROI : 0.025390598610839532
# Working on : UVV
# Length : 1844
# ROI : 0.03594552261494811
# Working on : V
# Length : 1844
# ROI : 0.21398749230514602
# Working on : VAC
# Length : 1844
# ROI : -0.04539028186120945
# Working on : VALU
# Length : 1844
# ROI : 0.2838404181619072
# Working on : VAPO
# Length : 1164
# Stock Data Corrupted
# Working on : VBFC
# Length : 1844
# ROI : -0.03478179570219451
# Working on : VBIV
# Length : 1844
# ROI : -0.32425759042402413
# Working on : VBTX
# Length : 1844
# ROI : -0.08936341727415753
# Working on : VC
# Length : 1844
# ROI : 0.008936190440071639
# Working on : VCEL
# Length : 1844
# ROI : -0.32006557463917035
# Working on : VCTR
# Length : 1443
# ROI : 0.007478712629079745
# Working on : VCYT
# Length : 1844
# ROI : -0.06815986809720212
# Working on : VEC
# Length : 1844
# ROI : -0.09569930617283426
# Working on : VECO
# Length : 1844
# ROI : 0.015449649338301511
# Working on : VEEV
# Length : 1844
# ROI : -0.3429739417538724
# Working on : VERI
# Length : 1715
# ROI : -0.39549087240795266
# Working on : VERU
# Length : 1844
# ROI : 2.113689524870724
# Working on : VFC
# Length : 1844
# ROI : -0.07704110424839437
# Working on : VG
# Length : 1844
# ROI : -0.05734759107604255
# Working on : VGR
# Length : 1844
# ROI : -0.15543883578962778
# Working on : VHC
# Length : 1844
# ROI : 0.1896857464741888
# Working on : VIAV
# Length : 1844
# ROI : 0.016362626550582193
# Working on : VICI
# Length : 1480
# ROI : 0.050977063868294537
# Working on : VICR
# Length : 1844
# ROI : -0.22905770972369183
# Working on : VIRC
# Length : 1844
# ROI : -0.03324228651105617
# Working on : VIRT
# Length : 1844
# ROI : 0.056160306011614515
# Working on : VISL
# Length : 1844
# ROI : 0.0653183767362982
# Working on : VIVO
# Length : 1844
# ROI : -0.23742455272041937
# Working on : VKTX
# Length : 1844
# ROI : 0.23131100863443185
# Working on : VLGEA
# Length : 1844
# ROI : 0.09090838130439638
# Working on : VLO
# Length : 1844
# ROI : -0.03863951259822034
# Working on : VLY
# Length : 1844
# ROI : -0.022407019452768677
# Working on : VMC
# Length : 1844
# ROI : 0.10007280341873505
# Working on : VMI
# Length : 1844
# ROI : -0.03704153401331461
# Working on : VMW
# Length : 1844
# ROI : 0.04359901808275863
# Working on : VNCE
# Length : 1844
# ROI : -0.0729711133148353
# Working on : VNDA
# Length : 1844
# ROI : 0.038259339981150026
# Working on : VNE
# Length : 1320
# Stock Data Corrupted
# Working on : VNO
# Length : 1844
# ROI : -0.031077090595117752
# Working on : VNRX
# Length : 1844
# ROI : 0.02196509966014678
# Working on : VNTR
# Length : 1632
# ROI : 0.11424097223437532
# Working on : VOXX
# Length : 1844
# ROI : 0.09165557075770331
# Working on : VOYA
# Length : 1844
# ROI : 0.07098852104646006
# Working on : VPG
# Length : 1844
# ROI : -0.030120772614532023
# Working on : VRA
# Length : 1844
# ROI : 0.06317202960973088
# Working on : VRAY
# Length : 1844
# ROI : 0.04851707461252773
# Working on : VREX
# Length : 1824
# ROI : -0.0901853461198951
# Working on : VRNS
# Length : 1844
# ROI : -0.11814165600154314
# Working on : VRNT
# Length : 1844
# ROI : 0.14438160792622626
# Working on : VRRM
# Length : 1764
# ROI : -0.08473143176334623
# Working on : VRS
# Length : 1844
# ROI : 0.031075722567861966
# Working on : VRSK
# Length : 1844
# ROI : -0.03931555840717279
# Working on : VRSN
# Length : 1844
# ROI : -0.11725556267001884
# Working on : VRTS
# Length : 1844
# ROI : -0.02833982722340001
# Working on : VRTV
# Length : 1844
# ROI : 0.21913315707894554
# Working on : VRTX
# Length : 1844
# ROI : 0.05502384526707694
# Working on : VSAT
# Length : 1844
# ROI : -0.13745293186743074
# Working on : VSEC
# Length : 1844
# ROI : -0.01360461918657944
# Working on : VSH
# Length : 1844
# ROI : -0.0691204026174342
# Working on : VST
# Length : 1844
# ROI : 0.03919217561591831
# Working on : VSTM
# Length : 1844
# ROI : -0.18707158366001336
# Working on : VSTO
# Length : 1844
# ROI : -0.04874607403593834
# Working on : VTNR
# Length : 1844
# ROI : -0.5352764912364201
# Working on : VTR
# Length : 1844
# ROI : -0.0008248407915466431
# Working on : VTVT
# Length : 1844
# ROI : 0.2917315042351041
# Working on : VUZI
# Length : 1844
# ROI : -0.2395295951355345
# Working on : VVI
# Length : 1844
# ROI : -0.04164540651957323
# Working on : VVV
# Length : 1844
# ROI : -0.04556235433256586
# Working on : VXRT
# Length : 1844
# ROI : -0.4197038106024976
# Working on : VYGR
# Length : 1844
# ROI : -0.5568075482171746
# Working on : VZ
# Length : 1844
# ROI : 0.07568439788207049
# Working on : W
# Length : 1844
# ROI : -0.3554206763303336
# Working on : WAB
# Length : 1844
# ROI : -0.03791662920522627
# Working on : WABC
# Length : 1844
# ROI : 0.02926883338996174
# Working on : WAFD
# Length : 1844
# ROI : -0.0566940475762894
# Working on : WAL
# Length : 1844
# ROI : 0.01860620814468208
# Working on : WASH
# Length : 1844
# ROI : 0.031150425014227608
# Working on : WAT
# Length : 1844
# ROI : -0.04232709805308734
# Working on : WATT
# Length : 1844
# ROI : 0.12141208999582342
# Working on : WBA
# Length : 1844
# ROI : 0.08059899931621012
# Working on : WBS
# Length : 1844
# ROI : 0.05049823141245893
# Working on : WBT
# Length : 1844
# ROI : -0.06703860087079962
# Working on : WCC
# Length : 1844
# ROI : -0.04092817596341129
# Working on : WD
# Length : 1844
# ROI : 0.05556283717604548
# Working on : WDAY
# Length : 1844
# ROI : -0.028557364857985892
# Working on : WDC
# Length : 1844
# ROI : -0.19567051194933371
# Working on : WDFC
# Length : 1844
# ROI : 0.18694890470896022
# Working on : WEC
# Length : 1844
# ROI : 0.058934797836542145
# Working on : WELL
# Length : 1844
# ROI : -0.06455990508415069
# Working on : WEN
# Length : 1844
# ROI : 0.1497885465814907
# Working on : WERN
# Length : 1844
# ROI : -0.006667393152538516
# Working on : WETF
# Length : 1844
# ROI : -0.023369486190251677
# Working on : WEX
# Length : 1844
# ROI : 0.09897333088887182
# Working on : WEYS
# Length : 1844
# ROI : 0.039922920021122445
# Working on : WFC
# Length : 1844
# ROI : 0.05222647669423443
# Working on : WGO
# Length : 1844
# ROI : -0.0942325680331431
# Working on : WH
# Length : 1341
# Stock Data Corrupted
# Working on : WHD
# Length : 1443
# ROI : 0.10460202344945421
# Working on : WHG
# Length : 1844
# ROI : -0.07218876337972764
# Working on : WHLM
# Length : 1844
# ROI : -0.13090924634806747
# Working on : WHLR
# Length : 1844
# ROI : 0.5043249935933374
# Working on : WHR
# Length : 1844
# ROI : 0.0022645848754967836
# Working on : WINA
# Length : 1844
# ROI : -0.15204727401278756
# Working on : WING
# Length : 1844
# ROI : 0.030802774318470904
# Working on : WIRE
# Length : 1844
# ROI : -0.11221064176697328
# Working on : WK
# Length : 1844
# ROI : -0.09588481919974735
# Working on : WKHS
# Length : 1844
# ROI : -0.8224105162875898
# Working on : WLDN
# Length : 1844
# ROI : -0.2718108808484528
# Working on : WLFC
# Length : 1844
# ROI : -0.029601327722850283
# Working on : WLK
# Length : 1844
# ROI : -0.08759968021383129
# Working on : WLL
# Length : 1844
# ROI : 0.17735622031831416
# Working on : WM
# Length : 1844
# ROI : 0.003972302611235726
# Working on : WMB
# Length : 1844
# ROI : 0.007858065386938385
# Working on : WMC
# Length : 1844
# ROI : -0.058490078732206886
# Working on : WMK
# Length : 1844
# ROI : -0.020471758562308404
# Working on : WMS
# Length : 1844
# ROI : 0.0841596526889998
# Working on : WMT
# Length : 1844
# ROI : 0.02662850964105613
# Working on : WNC
# Length : 1844
# ROI : 0.09477250942081952
# Working on : WNEB
# Length : 1844
# ROI : 0.08229778008511586
# Working on : WOR
# Length : 1844
# ROI : 0.05374640595857718
# Working on : WOW
# Length : 1682
# ROI : 0.12171690187353028
# Working on : WPC
# Length : 1844
# ROI : -0.04278018194698414
# Working on : WRB
# Length : 1844
# ROI : 0.044829718997091414
# Working on : WRE
# Length : 1844
# ROI : -0.07820586919152593
# Working on : WRK
# Length : 1844
# ROI : -0.013638776326776781
# Working on : WRLD
# Length : 1844
# ROI : 0.12505205185411453
# Working on : WSBC
# Length : 1844
# ROI : 0.12017670995123414
# Working on : WSBF
# Length : 1844
# ROI : 0.01187427173941757
# Working on : WSC
# Length : 1844
# ROI : 0.05897126524809735
# Working on : WSFS
# Length : 1844
# ROI : -0.04867121067717408
# Working on : WSM
# Length : 1844
# ROI : -0.07577443540494586
# Working on : WSO
# Length : 1844
# ROI : -0.0004963569220538871
# Working on : WSR
# Length : 1844
# ROI : 0.09506595619168075
# Working on : WST
# Length : 1844
# ROI : -0.14986333039242944
# Working on : WSTG
# Length : 1844
# ROI : 0.04057707301475406
# Working on : WSTL
# Length : 1844
# ROI : -0.02560410526290501
# Working on : WTBA
# Length : 1844
# ROI : -0.04915849397893456
# Working on : WTFC
# Length : 1844
# ROI : 0.05772848706741292
# Working on : WTI
# Length : 1844
# ROI : 0.15359843403039136
# Working on : WTM
# Length : 1844
# ROI : -0.023430746194610143
# Working on : WTRH
# Length : 1844
# ROI : -0.08937038228370452
# Working on : WTS
# Length : 1844
# ROI : 0.039551504769652975
# Working on : WTT
# Length : 1844
# ROI : 0.05123677936731359
# Working on : WTTR
# Length : 1670
# ROI : -0.1788776412241293
# Working on : WU
# Length : 1844
# ROI : 0.03224475149676282
# Working on : WVE
# Length : 1844
# ROI : 0.06294862274252085
# Working on : WVFC
# Length : 1844
# ROI : -0.017211780777536403
# Working on : WVVI
# Length : 1844
# ROI : -0.2440428555027272
# Working on : WW
# Length : 1844
# ROI : -0.07733179899890623
# Working on : WWD
# Length : 1844
# ROI : -0.09397313251204442
# Working on : WWE
# Length : 1844
# ROI : 0.1536203083770396
# Working on : WWR
# Length : 1844
# ROI : 0.4229542203908488
# Working on : WWW
# Length : 1844
# ROI : -0.06522689520147695
# Working on : WY
# Length : 1844
# ROI : -0.10979683274781528
# Working on : WYNN
# Length : 1844
# ROI : 0.09452113501020964
# Working on : WYY
# Length : 1844
# ROI : -0.5988109854968883
# Working on : X
# Length : 1844
# ROI : -0.014183865287937428
# Working on : XBIT
# Length : 1844
# ROI : -0.12205855363515693
# Working on : XEL
# Length : 1844
# ROI : 0.07487529435678791
# Working on : XELA
# Length : 1844
# ROI : -0.22003227273531462
# Working on : XELB
# Length : 1844
# ROI : -0.386774557491552
# Working on : XENT
# Length : 1844
# ROI : -0.06431086577383863
# Working on : XERS
# Length : 1310
# Stock Data Corrupted
# Working on : XFOR
# Length : 1527
# ROI : -0.12083472793470379
# Working on : XHR
# Length : 1844
# ROI : 0.10647987494572214
# Working on : XNCR
# Length : 1844
# ROI : 0.06280786520141796
# Working on : XOM
# Length : 1844
# ROI : -0.024515080764860097
# Working on : XOMA
# Length : 1844
# ROI : 0.06444649605434269
# Working on : XPER
# Length : 1844
# ROI : -0.11758774818309181
# Working on : XPL
# Length : 1844
# ROI : -0.1221455112390219
# Working on : XPO
# Length : 1844
# ROI : -0.06994971166813005
# Working on : XRAY
# Length : 1844
# ROI : -0.08499491863614868
# Working on : XRX
# Length : 1844
# ROI : 0.05304895096413669
# Working on : XSPA
# Length : 1844
# ROI : -0.03316482187498002
# Working on : XTNT
# Length : 1844
# ROI : 0.45061500702772134
# Working on : XXII
# Length : 1844
# ROI : 0.010149542094396738
# Working on : XYL
# Length : 1844
# ROI : -0.08966395462122555
# Working on : Y
# Length : 1844
# ROI : -0.020068596958903954
# Working on : YELP
# Length : 1844
# ROI : -0.025324242248996296
# Working on : YETI
# Length : 1184
# Stock Data Corrupted
# Working on : YEXT
# Length : 1744
# ROI : 0.24889431531852446
# Working on : YMAB
# Length : 1218
# Stock Data Corrupted
# Working on : YORW
# Length : 1844
# ROI : -0.028320359795679564
# Working on : YTEN
# Length : 1844
# ROI : -0.30988433491221967
# Working on : YUM
# Length : 1844
# ROI : -0.05843428582183418
# Working on : Z
# Length : 1844
# ROI : 0.7550356492297016
# Working on : ZBH
# Length : 1844
# ROI : 0.11552162486692412
# Working on : ZBRA
# Length : 1844
# ROI : -0.09615861178298733
# Working on : ZDGE
# Length : 1844
# ROI : 0.11323999684945245
# Working on : ZEN
# Length : 1844
# ROI : -0.186781352608576
# Working on : ZEUS
# Length : 1844
# ROI : 0.05485922987373823
# Working on : ZG
# Length : 1844
# ROI : 0.7773032952481557
# Working on : ZION
# Length : 1844
# ROI : -0.0780219317646697
# Working on : ZM
# Length : 1009
# Stock Data Corrupted
# Working on : ZNGA
# Length : 1844
# ROI : 0.4351660232836791
# Working on : ZS
# Length : 1407
# ROI : -0.02999391094538032
# Working on : ZSAN
# Length : 1844
# ROI : 0.2259923755797178
# Working on : ZTS
# Length : 1844
# ROI : -0.06051436591011188
# Working on : ZUMZ
# Length : 1844
# ROI : -0.01630881338997671
# Working on : ZUO
# Length : 1380
# ROI : -0.07759469460846101
# Working on : ZVO
# Length : 1012
# Stock Data Corrupted
# Working on : ZYNE
# Length : 1844
# ROI : 0.18343613087854094
# Working on : ZYXI
# Length : 1844
# ROI : -0.0019977747809209138
#      Ticker       ROI
# 0         A  0.001472
# 1        AA  0.224432
# 2       AAL -0.089512
# 3      AAME  0.080793
# 4      AAOI  0.125491
# ...     ...       ...
# 2752    ZTS -0.060514
# 2753   ZUMZ -0.016309
# 2754    ZUO -0.077595
# 2755   ZYNE  0.183436
# 2756   ZYXI -0.001998
#
# [2757 rows x 2 columns]

# %%
proj_roi_df.sort_values(by=['ROI'], ascending=False)[0:20]
# Out:
#      Ticker        ROI
# 610    CPSH  10.595434
# 480     CEI   3.996551
# 1587    MIC   3.268265
# 2577   VERU   2.113690
# 1328   JAGX   1.929462
# 1064    GME   1.874995
# 830     ENG   1.832392
# 890    EXPI   1.751400
# 189    APPS   1.631127
# 2006    PTE   1.398500
# 1309   ISIG   1.314177
# 2070   REPH   1.161583
# 1434    LCI   1.126430
# 443    CBIO   1.124098
# 692    CYTR   1.088607
# 671     CVM   1.070469
# 1009    FTK   1.014583
# 1241   IDRA   0.992284
# 13     ABEO   0.955893
# 2417   TISI   0.943080
