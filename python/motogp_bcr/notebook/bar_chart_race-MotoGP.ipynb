# %%
import pandas as pd
import bar_chart_race as bcr

# %%
df = pd.read_csv("motogp-2020-championship-standing.csv")

# %%
df.head()
# Out:
#      race  Joan Mir  Franco Morbidelli  Alex Rins  Andrea Dovizioso  \
# 0  race 1         0                 11          0                16
# 1  race 2        11                 11          6                26
# 2  race 3        11                 31         19                31
# 3  race 4        31                 31         19                56
# 4  race 5        44                 32         29                67
#
#    Pol Espargaro  Maverick Vinales  Jack Miller  Fabio Quartararo  \
# 0             10                20           13                25
# 1             19                40           13                50
# 2             19                42           20                59
# 3             19                48           36                67
# 4             35                48           56                70
#
#    Miguel Oliveira  ...  Aleix Espargaro  Cal Crutchlow  Stefan Bradl  \
# 0                8  ...                0              0             0
# ...

# %%
df = df.set_index('race')

# %%
df.head()
# Out:
#         Joan Mir  Franco Morbidelli  Alex Rins  Andrea Dovizioso  \
# race
# race 1         0                 11          0                16
# race 2        11                 11          6                26
# race 3        11                 31         19                31
# race 4        31                 31         19                56
# race 5        44                 32         29                67
#
#         Pol Espargaro  Maverick Vinales  Jack Miller  Fabio Quartararo  \
# race
# race 1             10                20           13                25
# race 2             19                40           13                50
# race 3             19                42           20                59
# race 4             19                48           36                67
# race 5             35                48           56                70
#
#         Miguel Oliveira  Takaaki Nakagami  ...  Aleix Espargaro  \
# race                                       ...
# ...

# %%
bcr.bar_chart_race(df=df, title="2020 MotoGP Championship", orientation='h', sort='desc', n_bars=10, steps_per_period=40, period_length=2000)
# Out:
# C:\Users\GRMITALY\miniconda3\envs\MainEnv\lib\site-packages\bar_chart_race\_make_chart.py:286: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(self.df_values.columns)
# C:\Users\GRMITALY\miniconda3\envs\MainEnv\lib\site-packages\bar_chart_race\_make_chart.py:287: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels([max_val] * len(ax.get_xticks()))
# <video width="980" height="504" controls autoplay loop>
#   <source type="video/mp4" src="...
